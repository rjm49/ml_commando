# %%
from copy import copy
from math import exp
from random import random, shuffle, choice, randint

from keras import Input
from numpy import array, mean
from pandas import concat
from pandas import DataFrame
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Masking


# generate a sequence of random values
def generate_sequence(n_timesteps):
    return [random() for _ in range(n_timesteps)]

def generate_student_name(n_names=2, maxl=5):
    # cons = ["B","C","CH","CK","D","F","G","GH","H","J","K","L","LL","M","N","P","PH","QU","R","RR","S","SH","SS","T","TH","V","W","WH","X","Y","Z"]
    cons = ["B","C","CH","D","F","G","H","J","K","L","M","N","P","PH","R","S","T","TH","V","W","Y"]
    verbs = ["A","E","I","O","U","Y"]#,"OO","OU","UI","AE","EI","IE","EE"]
    N = ""
    for n in range(n_names):
        L = randint(3, max(3,maxl))
        i=0
        while i < L:
            v = choice(verbs)
            N = N + ( choice(cons) if (i%2==0) else choice(verbs) )
            i+=1
        N = N + " "
    return N

def generate_scenario():
    hw_list = []
    ad_list = [] # the student dependent part!
    teacher = "MR T"
    students = ["ALICE","BOB","CERI","DARACH"]
#     students = [  generate_student_name() for _ in range(4) ]
    print(students)

    student_thetas = [2.5, 1.7, 4, 3]
    qn_betas = [1, 1.4, 1, 2.5, 2, 3.6, 3.3, 3.9, 4]

    qs_left = [i for i in range(len(qn_betas))]
    # shuffle(qs_left)
    print(qs_left)

    student_profiles = {}
    for psi in students:
        u = [0 for _ in qn_betas] # success vector
        a = [0 for _ in qn_betas] # open workbook
        x = [0 for _ in qn_betas] # practice vector
        student_profiles[psi] = [u,a,x]

    days_since_last_hw=0
    dayct = 0
    hw_intervals = []
    want_to_set = False
    ready_to_set = False
    q = None
    while True:
        for psix,psi in enumerate(students):
            prof = student_profiles[psi]
            u = prof[0]
            a = prof[1] # get the workbook
            x = prof[2]
            openqs = [ix for ix,el in enumerate(a) if el==1]
            if openqs == []:
#                 print("{} has no open qns".format(psi))
                continue
            #attempt a question
            qix_choice = choice(openqs)
            skill = student_thetas[psix]
            difficulty = qn_betas[qix_choice]
            p_pass = 1 / (1 + exp(-(skill - difficulty)))
            passed = (random() <= p_pass)
            x[qix_choice] += 1
            if passed:
                u[qix_choice] = 1
                a[qix_choice] = 2
            student_profiles[psi] = [u,a,x]
            print("{} attempting {} with ppass {} - {}".format(psi, qix_choice, p_pass, ("PASSED" if passed else "failed")))

        #probability of Mr F setting homework, p_hw = 1 - (1/(days_since_last_hw+1))
        if ad_list:
            hw_ooe = copy(hw_list[-1])
            all_done = copy(ad_list[-1])
        else:
            all_done = [0 for _ in qn_betas]
            hw_ooe = [0 for _ in qn_betas]

        if qs_left:
            p_hw = 1 - (1 / (1 + .03*days_since_last_hw))
            print("prob Mr T. wants to set homework=", p_hw)
            if random() <= p_hw:
                want_to_set = True

            if want_to_set:
                ready_to_set = True
                #check to see if students have done previous work
                for psi in students:
                    prof = student_profiles[psi]
                    a = prof[1]
#                     print("attemps at",a)
                    if 1 in a:
                        ready_to_set = False

            if ready_to_set:
                if q is not None:
                    all_done[q] = 1
                q = qs_left.pop(0)
                print("\n\nMr T. sets homework {} at day {}, {} since last".format(q, dayct, days_since_last_hw))
                for psi in students:
                    student_profiles[psi][1][q] = 1
                hw_intervals.append(days_since_last_hw)
                days_since_last_hw=0
                hw_ooe[q] = 1
        else:
            print("- - -no questions left to set")
        hw_list.append(hw_ooe)
        ad_list.append(all_done)


        days_since_last_hw += 1

        terminate=True
        for psi in students:
            prof = student_profiles[psi]
            u = prof[0]
            if 0 in u:
                terminate = False

        if terminate:
            break

        dayct+=1
    print("GAME OVER at {}".format(dayct))
    print("Homework intervals {}, avg {}".format(hw_intervals, mean(hw_intervals)))
    return hw_list, ad_list

# generate data for the lstm
def generate_data(n_timesteps):
    # generate sequence
    sequence = generate_sequence(n_timesteps)
    sequence = array(sequence)
    # create lag
    df = DataFrame(sequence)
    df = concat([df.shift(1), df], axis=1)
    # replace missing values with -1
    df.fillna(-1, inplace=True)
    values = df.values
    # specify input and output data
    X, y = values, values[:, 1]
    # reshape
    X = X.reshape(len(X), 2, 1)
    y = y.reshape(len(y), 1)
    return X, y


def generate_train_data():
    L = 70
    hw_list, ad_list = generate_scenario()
    hw_list = [h+a for a,h in zip(hw_list, ad_list)]

    width = len(hw_list[0])
    while len(hw_list) < L:
        hw_list.append([1 for _ in range(width)])
    if len(hw_list) > L:
        hw_list = hw_list[0:L]
    hw_list = array(hw_list)
    hw_list = DataFrame(hw_list)
    X = hw_list.shift(1).values
    X[0,:] = [-1 for _ in range(width)]
    y = hw_list.values
    X = X.reshape(len(X), 1,18)
    # X = X.reshape(len(X),18)
    y = y.reshape(len(y),18)
    return X,y
# Out:
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.summary API due to missing TensorBoard installation.

# %%
model = Sequential()
model.add(LSTM(18,  input_shape=(1,18)))
model.add(Dense(18,activation="sigmoid"))
model.compile(loss='binary_crossentropy', optimizer='adam')

# fit model
for i in range(100):
    X, y = generate_train_data()
    model.fit(X, y, epochs=1, batch_size=1, verbose=1)
# Out:
# ['ALICE', 'BOB', 'CERI', 'DARACH']
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
#
#
# Mr T. sets homework 0 at day 8, 8 since last
# ALICE attempting 0 with ppass 0.8175744761936437 - PASSED
# BOB attempting 0 with ppass 0.6681877721681662 - failed
# CERI attempting 0 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 0 with ppass 0.8807970779778823 - PASSED
# BOB attempting 0 with ppass 0.6681877721681662 - PASSED
#
#
# Mr T. sets homework 1 at day 10, 2 since last
# ALICE attempting 1 with ppass 0.7502601055951177 - PASSED
# BOB attempting 1 with ppass 0.574442516811659 - PASSED
# CERI attempting 1 with ppass 0.9308615796566533 - PASSED
# DARACH attempting 1 with ppass 0.8320183851339245 - PASSED
#
#
# Mr T. sets homework 2 at day 11, 1 since last
# ALICE attempting 2 with ppass 0.8175744761936437 - PASSED
# BOB attempting 2 with ppass 0.6681877721681662 - PASSED
# CERI attempting 2 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 2 with ppass 0.8807970779778823 - PASSED
#
#
# Mr T. sets homework 3 at day 12, 1 since last
# ALICE attempting 3 with ppass 0.5 - PASSED
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# CERI attempting 3 with ppass 0.8175744761936437 - PASSED
# DARACH attempting 3 with ppass 0.6224593312018546 - failed
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# DARACH attempting 3 with ppass 0.6224593312018546 - failed
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# DARACH attempting 3 with ppass 0.6224593312018546 - PASSED
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# BOB attempting 3 with ppass 0.31002551887238755 - PASSED
#
#
# Mr T. sets homework 4 at day 17, 5 since last
# ALICE attempting 4 with ppass 0.6224593312018546 - PASSED
# BOB attempting 4 with ppass 0.425557483188341 - PASSED
# CERI attempting 4 with ppass 0.8807970779778823 - PASSED
# DARACH attempting 4 with ppass 0.7310585786300049 - PASSED
#
#
# Mr T. sets homework 5 at day 18, 1 since last
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - PASSED
# CERI attempting 5 with ppass 0.598687660112452 - PASSED
# DARACH attempting 5 with ppass 0.35434369377420455 - failed
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# DARACH attempting 5 with ppass 0.35434369377420455 - PASSED
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# ALICE attempting 5 with ppass 0.24973989440488234 - PASSED
#
#
# Mr T. sets homework 6 at day 24, 6 since last
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# CERI attempting 6 with ppass 0.6681877721681662 - PASSED
# DARACH attempting 6 with ppass 0.4255574831883411 - failed
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - failed
# ALICE attempting 6 with ppass 0.31002551887238755 - PASSED
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - PASSED
# BOB attempting 6 with ppass 0.16798161486607555 - PASSED
#
#
# Mr T. sets homework 7 at day 30, 6 since last
# ALICE attempting 7 with ppass 0.19781611144141825 - PASSED
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# CERI attempting 7 with ppass 0.52497918747894 - PASSED
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - PASSED
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - PASSED
#
#
# Mr T. sets homework 8 at day 52, 22 since last
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# CERI attempting 8 with ppass 0.5 - PASSED
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - PASSED
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - PASSED
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# DARACH attempting 8 with ppass 0.2689414213699951 - PASSED
# - - -no questions left to set
# GAME OVER at 66
# Homework intervals [8, 2, 1, 1, 5, 1, 6, 6, 22], avg 5.777777777777778
# 70/70 [==============================] - 2s 2ms/step - loss: 0.6769
# ['ALICE', 'BOB', 'CERI', 'DARACH']
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
#
#
# Mr T. sets homework 0 at day 6, 6 since last
# ALICE attempting 0 with ppass 0.8175744761936437 - PASSED
# BOB attempting 0 with ppass 0.6681877721681662 - failed
# CERI attempting 0 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 0 with ppass 0.8807970779778823 - PASSED
# BOB attempting 0 with ppass 0.6681877721681662 - PASSED
#
#
# Mr T. sets homework 1 at day 8, 2 since last
# ALICE attempting 1 with ppass 0.7502601055951177 - PASSED
# BOB attempting 1 with ppass 0.574442516811659 - PASSED
# CERI attempting 1 with ppass 0.9308615796566533 - PASSED
# DARACH attempting 1 with ppass 0.8320183851339245 - failed
# DARACH attempting 1 with ppass 0.8320183851339245 - PASSED
#
#
# Mr T. sets homework 2 at day 10, 2 since last
# ALICE attempting 2 with ppass 0.8175744761936437 - PASSED
# BOB attempting 2 with ppass 0.6681877721681662 - failed
# CERI attempting 2 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 2 with ppass 0.8807970779778823 - PASSED
# BOB attempting 2 with ppass 0.6681877721681662 - failed
# BOB attempting 2 with ppass 0.6681877721681662 - PASSED
#
#
# Mr T. sets homework 3 at day 13, 3 since last
# ALICE attempting 3 with ppass 0.5 - PASSED
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# CERI attempting 3 with ppass 0.8175744761936437 - PASSED
# DARACH attempting 3 with ppass 0.6224593312018546 - failed
# BOB attempting 3 with ppass 0.31002551887238755 - PASSED
# DARACH attempting 3 with ppass 0.6224593312018546 - failed
# DARACH attempting 3 with ppass 0.6224593312018546 - failed
# DARACH attempting 3 with ppass 0.6224593312018546 - PASSED
#
#
# Mr T. sets homework 4 at day 17, 4 since last
# ALICE attempting 4 with ppass 0.6224593312018546 - PASSED
# BOB attempting 4 with ppass 0.425557483188341 - failed
# CERI attempting 4 with ppass 0.8807970779778823 - PASSED
# DARACH attempting 4 with ppass 0.7310585786300049 - PASSED
# BOB attempting 4 with ppass 0.425557483188341 - PASSED
#
#
# Mr T. sets homework 5 at day 19, 2 since last
# ALICE attempting 5 with ppass 0.24973989440488234 - PASSED
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# CERI attempting 5 with ppass 0.598687660112452 - PASSED
# DARACH attempting 5 with ppass 0.35434369377420455 - PASSED
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - PASSED
#
#
# Mr T. sets homework 6 at day 23, 4 since last
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - PASSED
# CERI attempting 6 with ppass 0.6681877721681662 - PASSED
# DARACH attempting 6 with ppass 0.4255574831883411 - PASSED
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# ALICE attempting 6 with ppass 0.31002551887238755 - PASSED
#
#
# Mr T. sets homework 7 at day 26, 3 since last
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# CERI attempting 7 with ppass 0.52497918747894 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# CERI attempting 7 with ppass 0.52497918747894 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - PASSED
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# CERI attempting 7 with ppass 0.52497918747894 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# CERI attempting 7 with ppass 0.52497918747894 - PASSED
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - PASSED
# ALICE attempting 7 with ppass 0.19781611144141825 - PASSED
#
#
# Mr T. sets homework 8 at day 32, 6 since last
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - PASSED
# CERI attempting 8 with ppass 0.5 - PASSED
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - PASSED
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - PASSED
# - - -no questions left to set
# GAME OVER at 42
# Homework intervals [6, 2, 2, 3, 4, 2, 4, 3, 6], avg 3.5555555555555554
# 70/70 [==============================] - 0s 2ms/step - loss: 0.5438
# ['ALICE', 'BOB', 'CERI', 'DARACH']
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
#
#
# Mr T. sets homework 0 at day 6, 6 since last
# ALICE attempting 0 with ppass 0.8175744761936437 - PASSED
# BOB attempting 0 with ppass 0.6681877721681662 - failed
# CERI attempting 0 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 0 with ppass 0.8807970779778823 - failed
# BOB attempting 0 with ppass 0.6681877721681662 - PASSED
# DARACH attempting 0 with ppass 0.8807970779778823 - PASSED
#
#
# Mr T. sets homework 1 at day 8, 2 since last
# ALICE attempting 1 with ppass 0.7502601055951177 - PASSED
# BOB attempting 1 with ppass 0.574442516811659 - failed
# CERI attempting 1 with ppass 0.9308615796566533 - PASSED
# DARACH attempting 1 with ppass 0.8320183851339245 - PASSED
# BOB attempting 1 with ppass 0.574442516811659 - failed
# BOB attempting 1 with ppass 0.574442516811659 - PASSED
#
#
# Mr T. sets homework 2 at day 11, 3 since last
# ALICE attempting 2 with ppass 0.8175744761936437 - PASSED
# BOB attempting 2 with ppass 0.6681877721681662 - PASSED
# CERI attempting 2 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 2 with ppass 0.8807970779778823 - PASSED
#
#
# Mr T. sets homework 3 at day 12, 1 since last
# ALICE attempting 3 with ppass 0.5 - PASSED
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# CERI attempting 3 with ppass 0.8175744761936437 - PASSED
# DARACH attempting 3 with ppass 0.6224593312018546 - PASSED
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# BOB attempting 3 with ppass 0.31002551887238755 - PASSED
#
#
# Mr T. sets homework 4 at day 19, 7 since last
# ALICE attempting 4 with ppass 0.6224593312018546 - PASSED
# BOB attempting 4 with ppass 0.425557483188341 - PASSED
# CERI attempting 4 with ppass 0.8807970779778823 - PASSED
# DARACH attempting 4 with ppass 0.7310585786300049 - failed
# DARACH attempting 4 with ppass 0.7310585786300049 - PASSED
#
#
# Mr T. sets homework 5 at day 21, 2 since last
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# CERI attempting 5 with ppass 0.598687660112452 - failed
# DARACH attempting 5 with ppass 0.35434369377420455 - failed
# ALICE attempting 5 with ppass 0.24973989440488234 - PASSED
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# CERI attempting 5 with ppass 0.598687660112452 - PASSED
# DARACH attempting 5 with ppass 0.35434369377420455 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# DARACH attempting 5 with ppass 0.35434369377420455 - PASSED
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - PASSED
#
#
# Mr T. sets homework 6 at day 39, 18 since last
# ALICE attempting 6 with ppass 0.31002551887238755 - PASSED
# BOB attempting 6 with ppass 0.16798161486607555 - PASSED
# CERI attempting 6 with ppass 0.6681877721681662 - PASSED
# DARACH attempting 6 with ppass 0.4255574831883411 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - PASSED
#
#
# Mr T. sets homework 7 at day 45, 6 since last
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# CERI attempting 7 with ppass 0.52497918747894 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# CERI attempting 7 with ppass 0.52497918747894 - PASSED
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - PASSED
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - PASSED
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - PASSED
#
#
# Mr T. sets homework 8 at day 55, 10 since last
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - PASSED
# CERI attempting 8 with ppass 0.5 - PASSED
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - PASSED
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# DARACH attempting 8 with ppass 0.2689414213699951 - PASSED
# - - -no questions left to set
# GAME OVER at 62
# Homework intervals [6, 2, 3, 1, 7, 2, 18, 6, 10], avg 6.111111111111111
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4709
# ['ALICE', 'BOB', 'CERI', 'DARACH']
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
#
#
# Mr T. sets homework 0 at day 11, 11 since last
# ALICE attempting 0 with ppass 0.8175744761936437 - failed
# BOB attempting 0 with ppass 0.6681877721681662 - PASSED
# CERI attempting 0 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 0 with ppass 0.8807970779778823 - PASSED
# ALICE attempting 0 with ppass 0.8175744761936437 - PASSED
#
#
# Mr T. sets homework 1 at day 13, 2 since last
# ALICE attempting 1 with ppass 0.7502601055951177 - PASSED
# BOB attempting 1 with ppass 0.574442516811659 - PASSED
# CERI attempting 1 with ppass 0.9308615796566533 - PASSED
# DARACH attempting 1 with ppass 0.8320183851339245 - PASSED
#
#
# Mr T. sets homework 2 at day 14, 1 since last
# ALICE attempting 2 with ppass 0.8175744761936437 - PASSED
# BOB attempting 2 with ppass 0.6681877721681662 - PASSED
# CERI attempting 2 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 2 with ppass 0.8807970779778823 - PASSED
#
#
# Mr T. sets homework 3 at day 15, 1 since last
# ALICE attempting 3 with ppass 0.5 - PASSED
# BOB attempting 3 with ppass 0.31002551887238755 - PASSED
# CERI attempting 3 with ppass 0.8175744761936437 - PASSED
# DARACH attempting 3 with ppass 0.6224593312018546 - PASSED
#
#
# Mr T. sets homework 4 at day 16, 1 since last
# ALICE attempting 4 with ppass 0.6224593312018546 - failed
# BOB attempting 4 with ppass 0.425557483188341 - PASSED
# CERI attempting 4 with ppass 0.8807970779778823 - PASSED
# DARACH attempting 4 with ppass 0.7310585786300049 - PASSED
# ALICE attempting 4 with ppass 0.6224593312018546 - PASSED
#
#
# Mr T. sets homework 5 at day 18, 2 since last
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# CERI attempting 5 with ppass 0.598687660112452 - PASSED
# DARACH attempting 5 with ppass 0.35434369377420455 - PASSED
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# ALICE attempting 5 with ppass 0.24973989440488234 - PASSED
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - PASSED
#
#
# Mr T. sets homework 6 at day 29, 11 since last
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - PASSED
# CERI attempting 6 with ppass 0.6681877721681662 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - PASSED
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# CERI attempting 6 with ppass 0.6681877721681662 - PASSED
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# ALICE attempting 6 with ppass 0.31002551887238755 - PASSED
#
#
# Mr T. sets homework 7 at day 35, 6 since last
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# CERI attempting 7 with ppass 0.52497918747894 - PASSED
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - PASSED
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - PASSED
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - PASSED
#
#
# Mr T. sets homework 8 at day 47, 12 since last
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# CERI attempting 8 with ppass 0.5 - PASSED
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - PASSED
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - PASSED
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - PASSED
# - - -no questions left to set
# GAME OVER at 58
# Homework intervals [11, 2, 1, 1, 1, 2, 11, 6, 12], avg 5.222222222222222
# 70/70 [==============================] - 0s 2ms/step - loss: 0.3912
# ['ALICE', 'BOB', 'CERI', 'DARACH']
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
#
#
# Mr T. sets homework 0 at day 11, 11 since last
# ALICE attempting 0 with ppass 0.8175744761936437 - PASSED
# BOB attempting 0 with ppass 0.6681877721681662 - PASSED
# CERI attempting 0 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 0 with ppass 0.8807970779778823 - PASSED
#
#
# Mr T. sets homework 1 at day 12, 1 since last
# ALICE attempting 1 with ppass 0.7502601055951177 - PASSED
# BOB attempting 1 with ppass 0.574442516811659 - PASSED
# CERI attempting 1 with ppass 0.9308615796566533 - PASSED
# DARACH attempting 1 with ppass 0.8320183851339245 - PASSED
#
#
# Mr T. sets homework 2 at day 13, 1 since last
# ALICE attempting 2 with ppass 0.8175744761936437 - PASSED
# BOB attempting 2 with ppass 0.6681877721681662 - PASSED
# CERI attempting 2 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 2 with ppass 0.8807970779778823 - PASSED
#
#
# Mr T. sets homework 3 at day 14, 1 since last
# ALICE attempting 3 with ppass 0.5 - PASSED
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# CERI attempting 3 with ppass 0.8175744761936437 - failed
# DARACH attempting 3 with ppass 0.6224593312018546 - PASSED
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# CERI attempting 3 with ppass 0.8175744761936437 - PASSED
# BOB attempting 3 with ppass 0.31002551887238755 - PASSED
#
#
# Mr T. sets homework 4 at day 17, 3 since last
# ALICE attempting 4 with ppass 0.6224593312018546 - PASSED
# BOB attempting 4 with ppass 0.425557483188341 - PASSED
# CERI attempting 4 with ppass 0.8807970779778823 - PASSED
# DARACH attempting 4 with ppass 0.7310585786300049 - failed
# DARACH attempting 4 with ppass 0.7310585786300049 - PASSED
#
#
# Mr T. sets homework 5 at day 19, 2 since last
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# CERI attempting 5 with ppass 0.598687660112452 - PASSED
# DARACH attempting 5 with ppass 0.35434369377420455 - failed
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# DARACH attempting 5 with ppass 0.35434369377420455 - PASSED
# ALICE attempting 5 with ppass 0.24973989440488234 - PASSED
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - PASSED
#
#
# Mr T. sets homework 6 at day 28, 9 since last
# ALICE attempting 6 with ppass 0.31002551887238755 - PASSED
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# CERI attempting 6 with ppass 0.6681877721681662 - PASSED
# DARACH attempting 6 with ppass 0.4255574831883411 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - PASSED
# DARACH attempting 6 with ppass 0.4255574831883411 - PASSED
#
#
# Mr T. sets homework 7 at day 32, 4 since last
# ALICE attempting 7 with ppass 0.19781611144141825 - PASSED
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# CERI attempting 7 with ppass 0.52497918747894 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# CERI attempting 7 with ppass 0.52497918747894 - PASSED
# DARACH attempting 7 with ppass 0.28905049737499605 - PASSED
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - PASSED
#
#
# Mr T. sets homework 8 at day 41, 9 since last
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# CERI attempting 8 with ppass 0.5 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - PASSED
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# CERI attempting 8 with ppass 0.5 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - PASSED
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# CERI attempting 8 with ppass 0.5 - PASSED
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - PASSED
# - - -no questions left to set
# GAME OVER at 48
# Homework intervals [11, 1, 1, 1, 3, 2, 9, 4, 9], avg 4.555555555555555
# 70/70 [==============================] - 0s 1ms/step - loss: 0.3643
# ['ALICE', 'BOB', 'CERI', 'DARACH']
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
#
#
# Mr T. sets homework 0 at day 5, 5 since last
# ALICE attempting 0 with ppass 0.8175744761936437 - PASSED
# BOB attempting 0 with ppass 0.6681877721681662 - failed
# CERI attempting 0 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 0 with ppass 0.8807970779778823 - PASSED
# BOB attempting 0 with ppass 0.6681877721681662 - PASSED
#
#
# Mr T. sets homework 1 at day 7, 2 since last
# ALICE attempting 1 with ppass 0.7502601055951177 - PASSED
# BOB attempting 1 with ppass 0.574442516811659 - failed
# CERI attempting 1 with ppass 0.9308615796566533 - PASSED
# DARACH attempting 1 with ppass 0.8320183851339245 - PASSED
# BOB attempting 1 with ppass 0.574442516811659 - PASSED
#
#
# Mr T. sets homework 2 at day 9, 2 since last
# ALICE attempting 2 with ppass 0.8175744761936437 - PASSED
# BOB attempting 2 with ppass 0.6681877721681662 - failed
# CERI attempting 2 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 2 with ppass 0.8807970779778823 - PASSED
# BOB attempting 2 with ppass 0.6681877721681662 - PASSED
#
#
# Mr T. sets homework 3 at day 11, 2 since last
# ALICE attempting 3 with ppass 0.5 - failed
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# CERI attempting 3 with ppass 0.8175744761936437 - PASSED
# DARACH attempting 3 with ppass 0.6224593312018546 - PASSED
# ALICE attempting 3 with ppass 0.5 - PASSED
# BOB attempting 3 with ppass 0.31002551887238755 - PASSED
#
#
# Mr T. sets homework 4 at day 13, 2 since last
# ALICE attempting 4 with ppass 0.6224593312018546 - PASSED
# BOB attempting 4 with ppass 0.425557483188341 - failed
# CERI attempting 4 with ppass 0.8807970779778823 - PASSED
# DARACH attempting 4 with ppass 0.7310585786300049 - PASSED
# BOB attempting 4 with ppass 0.425557483188341 - PASSED
#
#
# Mr T. sets homework 5 at day 15, 2 since last
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# CERI attempting 5 with ppass 0.598687660112452 - PASSED
# DARACH attempting 5 with ppass 0.35434369377420455 - failed
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# DARACH attempting 5 with ppass 0.35434369377420455 - failed
# ALICE attempting 5 with ppass 0.24973989440488234 - PASSED
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# DARACH attempting 5 with ppass 0.35434369377420455 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# DARACH attempting 5 with ppass 0.35434369377420455 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# DARACH attempting 5 with ppass 0.35434369377420455 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# DARACH attempting 5 with ppass 0.35434369377420455 - PASSED
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - PASSED
#
#
# Mr T. sets homework 6 at day 25, 10 since last
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# CERI attempting 6 with ppass 0.6681877721681662 - PASSED
# DARACH attempting 6 with ppass 0.4255574831883411 - PASSED
# ALICE attempting 6 with ppass 0.31002551887238755 - PASSED
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - PASSED
#
#
# Mr T. sets homework 7 at day 44, 19 since last
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# CERI attempting 7 with ppass 0.52497918747894 - PASSED
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - PASSED
# DARACH attempting 7 with ppass 0.28905049737499605 - PASSED
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - PASSED
#
#
# Mr T. sets homework 8 at day 49, 5 since last
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# CERI attempting 8 with ppass 0.5 - PASSED
# DARACH attempting 8 with ppass 0.2689414213699951 - PASSED
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - PASSED
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - PASSED
# - - -no questions left to set
# GAME OVER at 57
# Homework intervals [5, 2, 2, 2, 2, 2, 10, 19, 5], avg 5.444444444444445
# 70/70 [==============================] - 0s 1ms/step - loss: 0.3163
# ['ALICE', 'BOB', 'CERI', 'DARACH']
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
#
#
# Mr T. sets homework 0 at day 5, 5 since last
# ALICE attempting 0 with ppass 0.8175744761936437 - PASSED
# BOB attempting 0 with ppass 0.6681877721681662 - PASSED
# CERI attempting 0 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 0 with ppass 0.8807970779778823 - PASSED
#
#
# Mr T. sets homework 1 at day 6, 1 since last
# ALICE attempting 1 with ppass 0.7502601055951177 - PASSED
# BOB attempting 1 with ppass 0.574442516811659 - PASSED
# CERI attempting 1 with ppass 0.9308615796566533 - PASSED
# DARACH attempting 1 with ppass 0.8320183851339245 - PASSED
#
#
# Mr T. sets homework 2 at day 7, 1 since last
# ALICE attempting 2 with ppass 0.8175744761936437 - PASSED
# BOB attempting 2 with ppass 0.6681877721681662 - PASSED
# CERI attempting 2 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 2 with ppass 0.8807970779778823 - failed
# DARACH attempting 2 with ppass 0.8807970779778823 - PASSED
#
#
# Mr T. sets homework 3 at day 9, 2 since last
# ALICE attempting 3 with ppass 0.5 - PASSED
# BOB attempting 3 with ppass 0.31002551887238755 - PASSED
# CERI attempting 3 with ppass 0.8175744761936437 - PASSED
# DARACH attempting 3 with ppass 0.6224593312018546 - failed
# DARACH attempting 3 with ppass 0.6224593312018546 - PASSED
#
#
# Mr T. sets homework 4 at day 11, 2 since last
# ALICE attempting 4 with ppass 0.6224593312018546 - PASSED
# BOB attempting 4 with ppass 0.425557483188341 - failed
# CERI attempting 4 with ppass 0.8807970779778823 - PASSED
# DARACH attempting 4 with ppass 0.7310585786300049 - failed
# BOB attempting 4 with ppass 0.425557483188341 - failed
# DARACH attempting 4 with ppass 0.7310585786300049 - PASSED
# BOB attempting 4 with ppass 0.425557483188341 - PASSED
#
#
# Mr T. sets homework 5 at day 14, 3 since last
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# CERI attempting 5 with ppass 0.598687660112452 - failed
# DARACH attempting 5 with ppass 0.35434369377420455 - failed
# ALICE attempting 5 with ppass 0.24973989440488234 - PASSED
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# CERI attempting 5 with ppass 0.598687660112452 - PASSED
# DARACH attempting 5 with ppass 0.35434369377420455 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# DARACH attempting 5 with ppass 0.35434369377420455 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# DARACH attempting 5 with ppass 0.35434369377420455 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# DARACH attempting 5 with ppass 0.35434369377420455 - PASSED
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - PASSED
#
#
# Mr T. sets homework 6 at day 23, 9 since last
# ALICE attempting 6 with ppass 0.31002551887238755 - PASSED
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# CERI attempting 6 with ppass 0.6681877721681662 - PASSED
# DARACH attempting 6 with ppass 0.4255574831883411 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - PASSED
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - PASSED
#
#
# Mr T. sets homework 7 at day 31, 8 since last
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - PASSED
# CERI attempting 7 with ppass 0.52497918747894 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# CERI attempting 7 with ppass 0.52497918747894 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - PASSED
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# CERI attempting 7 with ppass 0.52497918747894 - PASSED
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - PASSED
#
#
# Mr T. sets homework 8 at day 40, 9 since last
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# CERI attempting 8 with ppass 0.5 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - PASSED
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# CERI attempting 8 with ppass 0.5 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# CERI attempting 8 with ppass 0.5 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# CERI attempting 8 with ppass 0.5 - PASSED
# DARACH attempting 8 with ppass 0.2689414213699951 - PASSED
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - PASSED
# - - -no questions left to set
# GAME OVER at 49
# Homework intervals [5, 1, 1, 2, 2, 3, 9, 8, 9], avg 4.444444444444445
# 70/70 [==============================] - 0s 1ms/step - loss: 0.2754
# ['ALICE', 'BOB', 'CERI', 'DARACH']
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
#
#
# Mr T. sets homework 0 at day 5, 5 since last
# ALICE attempting 0 with ppass 0.8175744761936437 - PASSED
# BOB attempting 0 with ppass 0.6681877721681662 - PASSED
# CERI attempting 0 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 0 with ppass 0.8807970779778823 - PASSED
#
#
# Mr T. sets homework 1 at day 6, 1 since last
# ALICE attempting 1 with ppass 0.7502601055951177 - PASSED
# BOB attempting 1 with ppass 0.574442516811659 - PASSED
# CERI attempting 1 with ppass 0.9308615796566533 - PASSED
# DARACH attempting 1 with ppass 0.8320183851339245 - PASSED
#
#
# Mr T. sets homework 2 at day 7, 1 since last
# ALICE attempting 2 with ppass 0.8175744761936437 - failed
# BOB attempting 2 with ppass 0.6681877721681662 - PASSED
# CERI attempting 2 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 2 with ppass 0.8807970779778823 - PASSED
# ALICE attempting 2 with ppass 0.8175744761936437 - PASSED
#
#
# Mr T. sets homework 3 at day 9, 2 since last
# ALICE attempting 3 with ppass 0.5 - PASSED
# BOB attempting 3 with ppass 0.31002551887238755 - PASSED
# CERI attempting 3 with ppass 0.8175744761936437 - PASSED
# DARACH attempting 3 with ppass 0.6224593312018546 - PASSED
#
#
# Mr T. sets homework 4 at day 10, 1 since last
# ALICE attempting 4 with ppass 0.6224593312018546 - PASSED
# BOB attempting 4 with ppass 0.425557483188341 - failed
# CERI attempting 4 with ppass 0.8807970779778823 - PASSED
# DARACH attempting 4 with ppass 0.7310585786300049 - PASSED
# BOB attempting 4 with ppass 0.425557483188341 - PASSED
#
#
# Mr T. sets homework 5 at day 12, 2 since last
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - PASSED
# CERI attempting 5 with ppass 0.598687660112452 - PASSED
# DARACH attempting 5 with ppass 0.35434369377420455 - PASSED
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# ALICE attempting 5 with ppass 0.24973989440488234 - PASSED
#
#
# Mr T. sets homework 6 at day 15, 3 since last
# ALICE attempting 6 with ppass 0.31002551887238755 - PASSED
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# CERI attempting 6 with ppass 0.6681877721681662 - PASSED
# DARACH attempting 6 with ppass 0.4255574831883411 - PASSED
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - PASSED
#
#
# Mr T. sets homework 7 at day 30, 15 since last
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# CERI attempting 7 with ppass 0.52497918747894 - PASSED
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - PASSED
# BOB attempting 7 with ppass 0.09975048911968513 - PASSED
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - PASSED
#
#
# Mr T. sets homework 8 at day 37, 7 since last
# ALICE attempting 8 with ppass 0.18242552380635635 - PASSED
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# CERI attempting 8 with ppass 0.5 - PASSED
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - PASSED
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# ...
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - PASSED
# - - -no questions left to set
# GAME OVER at 86
# Homework intervals [9, 2, 1, 2, 2, 2, 9, 2, 30], avg 6.555555555555555
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0390
# ['ALICE', 'BOB', 'CERI', 'DARACH']
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
#
#
# Mr T. sets homework 0 at day 1, 1 since last
# ALICE attempting 0 with ppass 0.8175744761936437 - PASSED
# BOB attempting 0 with ppass 0.6681877721681662 - PASSED
# CERI attempting 0 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 0 with ppass 0.8807970779778823 - PASSED
#
#
# Mr T. sets homework 1 at day 2, 1 since last
# ALICE attempting 1 with ppass 0.7502601055951177 - PASSED
# BOB attempting 1 with ppass 0.574442516811659 - failed
# CERI attempting 1 with ppass 0.9308615796566533 - PASSED
# DARACH attempting 1 with ppass 0.8320183851339245 - PASSED
# BOB attempting 1 with ppass 0.574442516811659 - PASSED
#
#
# Mr T. sets homework 2 at day 4, 2 since last
# ALICE attempting 2 with ppass 0.8175744761936437 - failed
# BOB attempting 2 with ppass 0.6681877721681662 - PASSED
# CERI attempting 2 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 2 with ppass 0.8807970779778823 - PASSED
# ALICE attempting 2 with ppass 0.8175744761936437 - PASSED
#
#
# Mr T. sets homework 3 at day 6, 2 since last
# ALICE attempting 3 with ppass 0.5 - PASSED
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# CERI attempting 3 with ppass 0.8175744761936437 - PASSED
# DARACH attempting 3 with ppass 0.6224593312018546 - PASSED
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# BOB attempting 3 with ppass 0.31002551887238755 - PASSED
#
#
# Mr T. sets homework 4 at day 10, 4 since last
# ALICE attempting 4 with ppass 0.6224593312018546 - PASSED
# BOB attempting 4 with ppass 0.425557483188341 - failed
# CERI attempting 4 with ppass 0.8807970779778823 - PASSED
# DARACH attempting 4 with ppass 0.7310585786300049 - PASSED
# BOB attempting 4 with ppass 0.425557483188341 - failed
# BOB attempting 4 with ppass 0.425557483188341 - failed
# BOB attempting 4 with ppass 0.425557483188341 - failed
# BOB attempting 4 with ppass 0.425557483188341 - failed
# BOB attempting 4 with ppass 0.425557483188341 - failed
# BOB attempting 4 with ppass 0.425557483188341 - PASSED
#
#
# Mr T. sets homework 5 at day 17, 7 since last
# ALICE attempting 5 with ppass 0.24973989440488234 - PASSED
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# CERI attempting 5 with ppass 0.598687660112452 - PASSED
# DARACH attempting 5 with ppass 0.35434369377420455 - PASSED
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - PASSED
#
#
# Mr T. sets homework 6 at day 22, 5 since last
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# CERI attempting 6 with ppass 0.6681877721681662 - PASSED
# DARACH attempting 6 with ppass 0.4255574831883411 - PASSED
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# ALICE attempting 6 with ppass 0.31002551887238755 - PASSED
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - PASSED
#
#
# Mr T. sets homework 7 at day 37, 15 since last
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# CERI attempting 7 with ppass 0.52497918747894 - PASSED
# DARACH attempting 7 with ppass 0.28905049737499605 - PASSED
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - PASSED
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - PASSED
#
#
# Mr T. sets homework 8 at day 56, 19 since last
# ALICE attempting 8 with ppass 0.18242552380635635 - PASSED
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# CERI attempting 8 with ppass 0.5 - PASSED
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - PASSED
# DARACH attempting 8 with ppass 0.2689414213699951 - PASSED
# - - -no questions left to set
# GAME OVER at 59
# Homework intervals [1, 1, 2, 2, 4, 7, 5, 15, 19], avg 6.222222222222222
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0483
# ['ALICE', 'BOB', 'CERI', 'DARACH']
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
#
#
# Mr T. sets homework 0 at day 8, 8 since last
# ALICE attempting 0 with ppass 0.8175744761936437 - PASSED
# BOB attempting 0 with ppass 0.6681877721681662 - PASSED
# CERI attempting 0 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 0 with ppass 0.8807970779778823 - PASSED
#
#
# Mr T. sets homework 1 at day 9, 1 since last
# ALICE attempting 1 with ppass 0.7502601055951177 - failed
# BOB attempting 1 with ppass 0.574442516811659 - PASSED
# CERI attempting 1 with ppass 0.9308615796566533 - PASSED
# DARACH attempting 1 with ppass 0.8320183851339245 - failed
# ALICE attempting 1 with ppass 0.7502601055951177 - PASSED
# DARACH attempting 1 with ppass 0.8320183851339245 - PASSED
#
#
# Mr T. sets homework 2 at day 11, 2 since last
# ALICE attempting 2 with ppass 0.8175744761936437 - PASSED
# BOB attempting 2 with ppass 0.6681877721681662 - PASSED
# CERI attempting 2 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 2 with ppass 0.8807970779778823 - PASSED
#
#
# Mr T. sets homework 3 at day 12, 1 since last
# ALICE attempting 3 with ppass 0.5 - failed
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# CERI attempting 3 with ppass 0.8175744761936437 - PASSED
# DARACH attempting 3 with ppass 0.6224593312018546 - PASSED
# ALICE attempting 3 with ppass 0.5 - PASSED
# BOB attempting 3 with ppass 0.31002551887238755 - failed
# BOB attempting 3 with ppass 0.31002551887238755 - PASSED
#
#
# Mr T. sets homework 4 at day 15, 3 since last
# ALICE attempting 4 with ppass 0.6224593312018546 - failed
# BOB attempting 4 with ppass 0.425557483188341 - failed
# CERI attempting 4 with ppass 0.8807970779778823 - PASSED
# DARACH attempting 4 with ppass 0.7310585786300049 - PASSED
# ALICE attempting 4 with ppass 0.6224593312018546 - PASSED
# BOB attempting 4 with ppass 0.425557483188341 - PASSED
#
#
# Mr T. sets homework 5 at day 17, 2 since last
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# CERI attempting 5 with ppass 0.598687660112452 - PASSED
# DARACH attempting 5 with ppass 0.35434369377420455 - PASSED
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# ALICE attempting 5 with ppass 0.24973989440488234 - PASSED
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - PASSED
#
#
# Mr T. sets homework 6 at day 29, 12 since last
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# CERI attempting 6 with ppass 0.6681877721681662 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - failed
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# CERI attempting 6 with ppass 0.6681877721681662 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - failed
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# CERI attempting 6 with ppass 0.6681877721681662 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - failed
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# CERI attempting 6 with ppass 0.6681877721681662 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - PASSED
# ALICE attempting 6 with ppass 0.31002551887238755 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# CERI attempting 6 with ppass 0.6681877721681662 - PASSED
# ALICE attempting 6 with ppass 0.31002551887238755 - PASSED
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - failed
# BOB attempting 6 with ppass 0.16798161486607555 - PASSED
#
#
# Mr T. sets homework 7 at day 38, 9 since last
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# CERI attempting 7 with ppass 0.52497918747894 - PASSED
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - PASSED
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - PASSED
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - PASSED
#
#
# Mr T. sets homework 8 at day 53, 15 since last
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# CERI attempting 8 with ppass 0.5 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# CERI attempting 8 with ppass 0.5 - PASSED
# DARACH attempting 8 with ppass 0.2689414213699951 - PASSED
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - PASSED
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - PASSED
# - - -no questions left to set
# GAME OVER at 61
# Homework intervals [8, 1, 2, 1, 3, 2, 12, 9, 15], avg 5.888888888888889
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0411

# %%
import numpy
# evaluate model on new data
w = 9
X, y = generate_train_data()
y = y[:,0:w]
yhat = model.predict(X)[:,0:w]
for i in range(len(X)):
    print('Actual   ', [el for el in y[i]], '\nPredicted', [int(round(el)) for el in yhat[i]],"\n")
# Out:
# ['ALICE', 'BOB', 'CERI', 'DARACH']
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
#
#
# Mr T. sets homework 0 at day 6, 6 since last
# ALICE attempting 0 with ppass 0.8175744761936437 - PASSED
# BOB attempting 0 with ppass 0.6681877721681662 - PASSED
# CERI attempting 0 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 0 with ppass 0.8807970779778823 - PASSED
#
#
# Mr T. sets homework 1 at day 7, 1 since last
# ALICE attempting 1 with ppass 0.7502601055951177 - failed
# BOB attempting 1 with ppass 0.574442516811659 - PASSED
# CERI attempting 1 with ppass 0.9308615796566533 - PASSED
# DARACH attempting 1 with ppass 0.8320183851339245 - PASSED
# ALICE attempting 1 with ppass 0.7502601055951177 - PASSED
#
#
# Mr T. sets homework 2 at day 9, 2 since last
# ALICE attempting 2 with ppass 0.8175744761936437 - PASSED
# BOB attempting 2 with ppass 0.6681877721681662 - PASSED
# CERI attempting 2 with ppass 0.9525741268224334 - PASSED
# DARACH attempting 2 with ppass 0.8807970779778823 - PASSED
#
#
# Mr T. sets homework 3 at day 10, 1 since last
# ALICE attempting 3 with ppass 0.5 - failed
# BOB attempting 3 with ppass 0.31002551887238755 - PASSED
# CERI attempting 3 with ppass 0.8175744761936437 - PASSED
# DARACH attempting 3 with ppass 0.6224593312018546 - PASSED
# ALICE attempting 3 with ppass 0.5 - failed
# ALICE attempting 3 with ppass 0.5 - PASSED
#
#
# Mr T. sets homework 4 at day 13, 3 since last
# ALICE attempting 4 with ppass 0.6224593312018546 - PASSED
# BOB attempting 4 with ppass 0.425557483188341 - failed
# CERI attempting 4 with ppass 0.8807970779778823 - PASSED
# DARACH attempting 4 with ppass 0.7310585786300049 - PASSED
# BOB attempting 4 with ppass 0.425557483188341 - PASSED
#
#
# Mr T. sets homework 5 at day 15, 2 since last
# ALICE attempting 5 with ppass 0.24973989440488234 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# CERI attempting 5 with ppass 0.598687660112452 - PASSED
# DARACH attempting 5 with ppass 0.35434369377420455 - PASSED
# ALICE attempting 5 with ppass 0.24973989440488234 - PASSED
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - failed
# BOB attempting 5 with ppass 0.13010847436299783 - PASSED
#
#
# Mr T. sets homework 6 at day 29, 14 since last
# ALICE attempting 6 with ppass 0.31002551887238755 - PASSED
# BOB attempting 6 with ppass 0.16798161486607555 - PASSED
# CERI attempting 6 with ppass 0.6681877721681662 - failed
# DARACH attempting 6 with ppass 0.4255574831883411 - PASSED
# CERI attempting 6 with ppass 0.6681877721681662 - PASSED
#
#
# Mr T. sets homework 7 at day 31, 2 since last
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# CERI attempting 7 with ppass 0.52497918747894 - PASSED
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# ALICE attempting 7 with ppass 0.19781611144141825 - PASSED
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# DARACH attempting 7 with ppass 0.28905049737499605 - PASSED
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - failed
# BOB attempting 7 with ppass 0.09975048911968513 - PASSED
#
#
# Mr T. sets homework 8 at day 49, 18 since last
# ALICE attempting 8 with ppass 0.18242552380635635 - failed
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# CERI attempting 8 with ppass 0.5 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# ALICE attempting 8 with ppass 0.18242552380635635 - PASSED
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# CERI attempting 8 with ppass 0.5 - PASSED
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - failed
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# BOB attempting 8 with ppass 0.09112296101485616 - PASSED
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# DARACH attempting 8 with ppass 0.2689414213699951 - failed
# - - -no questions left to set
# DARACH attempting 8 with ppass 0.2689414213699951 - PASSED
# - - -no questions left to set
# GAME OVER at 57
# Homework intervals [6, 1, 2, 1, 3, 2, 14, 2, 18], avg 5.444444444444445
# Actual    [0, 0, 0, 0, 0, 0, 0, 0, 0]
# Predicted [0, 0, 0, 0, 0, 0, 0, 0, 0]
#
# Actual    [0, 0, 0, 0, 0, 0, 0, 0, 0]
# Predicted [0, 0, 0, 0, 0, 0, 0, 0, 0]
#
# Actual    [0, 0, 0, 0, 0, 0, 0, 0, 0]
# Predicted [0, 0, 0, 0, 0, 0, 0, 0, 0]
#
# Actual    [0, 0, 0, 0, 0, 0, 0, 0, 0]
# Predicted [0, 0, 0, 0, 0, 0, 0, 0, 0]
#
# Actual    [0, 0, 0, 0, 0, 0, 0, 0, 0]
# Predicted [0, 0, 0, 0, 0, 0, 0, 0, 0]
#
# Actual    [0, 0, 0, 0, 0, 0, 0, 0, 0]
# Predicted [0, 0, 0, 0, 0, 0, 0, 0, 0]
#
# Actual    [0, 0, 0, 0, 0, 0, 0, 0, 0]
# Predicted [0, 0, 0, 0, 0, 0, 0, 0, 0]
#
# Actual    [1, 0, 0, 0, 0, 0, 0, 0, 0]
# Predicted [1, 0, 0, 0, 0, 0, 0, 0, 0]
#
# Actual    [1, 0, 0, 0, 0, 0, 0, 0, 0]
# Predicted [1, 1, 0, 0, 0, 0, 0, 0, 0]
#
# Actual    [1, 1, 0, 0, 0, 0, 0, 0, 0]
# Predicted [1, 1, 0, 0, 0, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 0, 0, 0, 0, 0, 0]
# Predicted [1, 1, 1, 0, 0, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 0, 0, 0, 0, 0, 0]
# Predicted [1, 1, 1, 0, 0, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 0, 0, 0, 0, 0, 0]
# Predicted [1, 1, 1, 0, 0, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 0, 0, 0, 0, 0]
# Predicted [1, 1, 1, 0, 0, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 0, 0, 0, 0, 0]
# Predicted [1, 1, 1, 1, 0, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 0, 0, 0, 0]
# Predicted [1, 1, 1, 1, 0, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 0, 0, 0, 0]
# Predicted [1, 1, 1, 1, 1, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 0, 0, 0, 0]
# Predicted [1, 1, 1, 1, 1, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 0, 0, 0, 0]
# Predicted [1, 1, 1, 1, 1, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 0, 0, 0, 0]
# Predicted [1, 1, 1, 1, 1, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 0, 0, 0, 0]
# Predicted [1, 1, 1, 1, 1, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 0, 0, 0, 0]
# Predicted [1, 1, 1, 1, 1, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 0, 0, 0, 0]
# Predicted [1, 1, 1, 1, 1, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 0, 0, 0, 0]
# Predicted [1, 1, 1, 1, 1, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 0, 0, 0, 0]
# Predicted [1, 1, 1, 1, 1, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 0, 0, 0, 0]
# Predicted [1, 1, 1, 1, 1, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 0, 0, 0, 0]
# Predicted [1, 1, 1, 1, 1, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 0, 0, 0, 0]
# Predicted [1, 1, 1, 1, 1, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 0, 0, 0, 0]
# Predicted [1, 1, 1, 1, 1, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 0, 0, 0]
# Predicted [1, 1, 1, 1, 1, 0, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 0, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 0, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 0, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 0, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 0]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 1]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 0]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 1]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 1]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 1]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 1]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 1]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 1]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 1]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 1]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 1]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 1]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 1]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 1]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 1]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 1]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 1]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 1]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 1]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 1]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 1]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 1]
#
# Actual    [1, 1, 1, 1, 1, 1, 1, 1, 1]
# Predicted [1, 1, 1, 1, 1, 1, 1, 1, 1]

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

yhat_round = numpy.around(yhat)
print("Accuracy:", accuracy_score(y, yhat_round))
print("Confusion matrix:\n", confusion_matrix(y.flatten(),yhat_round.flatten()))
# Out:
# Accuracy: 0.857142857143
# Confusion matrix:
#  [[228   2]
#  [  8 392]]
