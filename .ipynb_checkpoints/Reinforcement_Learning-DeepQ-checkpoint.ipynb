# %%
# Get started with interactive Python
import turtle
from collections import defaultdict

wn = turtle.Screen()
wn.setup(700,700)
wn.bgcolor("black")
wn.colormode(1)

#create pen
class Pen(turtle.Turtle):
  def __init__(self):
    turtle.Turtle.__init__(self)
    self.shape("square")
    self.color("white")
    self.penup()
    self.speed(0)
    
class Player(turtle.Turtle):
  
  def __init__(self):
    turtle.Turtle.__init__(self)
    self.shape("square")
    self.color("yellow")
    self.penup()
    self.speed(0)    
    self.wall_R = -0.75
    self.move_R = -0.04
  
  def go_up(self):
    move_to_x=player.xcor()
    move_to_y=player.ycor() + 24
    
    if (move_to_x,move_to_y) not in walls:
        self.goto(move_to_x, move_to_y)
        return self.move_R
    else:
        return self.wall_R
  
  def go_down(self):
    move_to_x=player.xcor()
    move_to_y=player.ycor() - 24
    
    if (move_to_x,move_to_y) not in walls:
        self.goto(move_to_x, move_to_y)  
        return self.move_R
    else:
        return self.wall_R
        
  def go_right(self):
    move_to_x=player.xcor() + 24
    move_to_y=player.ycor()
    
    if (move_to_x,move_to_y) not in walls:
        self.goto(move_to_x, move_to_y) 
        return self.move_R
    else:
        return self.wall_R
    
  def go_left(self):
    move_to_x=player.xcor() -24
    move_to_y=player.ycor()
    
    if (move_to_x,move_to_y) not in walls:
        self.goto(move_to_x, move_to_y) 
        return self.move_R
    else:
        return self.wall_R

#create Levels list
levels = [""]

#define first level
level_1 = [
"XXXXXXXXXXXXXXXXXXXXXXXXX",
"X                      XX",
"X P         XXXXXX  XX XX",
"X  XXXXXXX  XXXXXX  X XXX",
"X       XXXXXXX        XX",
"XXXXXX  XX  XXX        XX",
"XX   X  XX  XXXXXX  XXXXX",
"XX XXX  XX    XXXX  XXXXX",
"X  XXXX       XXXX    XXX",
"X  XXX  XXXXXXXXXXXX   XX",
"X      X  XXXXXXXXXXX   X",
"X  XX    XXX     XXXXX  X",
"X XXXXXXX XX     XXXXX  X",
"X         XXXXX  XXXXX  X",
"XXX  XXXXXXXXXX         X",
"XXX                     X",
"XXX         XXXXXXXXXXXXX",
"XXXXXXXXXX  XXXXXXXXXXXXX",
"XXXXXXXXXX              X",
"XX  GXXXXX              X",
"XX   XXXXXXXXXXXXX  XXXXX",
"XX    YXXXXXXXXXXX  XXXXX",
"XX          XXXX        X",
"XXXX                    X",
"XXXXXXXXXXXXXXXXXXXXXXXXX"
]

# level_1 = [
# "XXXXXXXXXXXXXXXXXXXXXXXXX",
# "X                      XX",
# "X           XXXXXX  XX XX",
# "X  XXXXXXX  XXXXXX  X XXX",
# "X       XXXXXXX        XX",
# "XXXXXX  XX  XXX        XX",
# "XX   X  XX  XXXXXX  XXXXX",
# "XX XXX  XX    XXXX  XXXXX",
# "X  XXXX       XXXX    XXX",
# "X  XXX  XXXXXXXXXXXX   XX",
# "X      X  XXXXXXXXXXX   X",
# "X  XX    XXX     XXXXX  X",
# "X XXXXXXX XX     XXXXX  X",
# "X         XXXXX  XXXXX  X",
# "XXX  XXXXXXXXXX         X",
# "XXX                     X",
# "XXXXXXXXXXXXXXXXXXXXXXXXX",
# "XXXXXXXXXX     X X     PX",
# "X           X           X",
# "X   XX XXXXXX  XXXXX  XXX",
# "XXXX   XXXX             X",
# "X    XX     XXXXXXXXXXX X",
# "X XXX   X               X",
# "X      GX               X",
# "XXXXXXXXXXXXXXXXXXXXXXXXX"
# ]

#Add maze to mazes list
levels.append(level_1)

#Create Level Setup Function


def setup_maze(level, draw_walls=True, goalstamp=None):
    walls = []
    playable = []
    goal = None
    for y in range(len(level)):
        for x in range(len(level[y])):
          #Get the Character at each x,y coordinate
          #NOTE the order of the y and x in the next line
            character = level[y][x]
    #       Calculate the screen x, y coordinates
            screen_x = -288 + (x * 24)
            screen_y = 288 - (y * 24)

          #Check if it is an X (representing a wall)
            if character == "X":
                if draw_walls:
                    pen.color("white")
                    pen.goto(screen_x, screen_y)
                    pen.stamp()
                walls.append((screen_x,screen_y))
            else:
                playable.append((screen_x, screen_y))

            if character == "P":
                px,py = screen_x, screen_y
                player.goto(screen_x, screen_y)

            if character == "G":
                if goalstamp is not None:
                    pen.clearstamp(goalstamp)
                goal = (screen_x, screen_y)
                pen.color("green")
                pen.goto(screen_x, screen_y)
                goalstamp = pen.stamp()

    return walls, goal, goalstamp, playable, px,py
        
def reset(px,py):
    player.goto(px,py)

def grid_to_screen(gx,gy):
    screen_x = -288 + (gx * 24)
    screen_y = 288 - (gy * 24)
    return screen_x, screen_y

def screen_to_grid(sx,sy):
    gx = (sx+288)//24
    gy = (288-sy)//24
    return gx, gy

def grid_to_onehot(gxy, oh=None):
    gx = gxy[0]
    gy = gxy[1]
    if oh is None:
        oh = numpy.zeros((24,24))
    oh[gx,gy] = 1.0
    return oh

# %%
#Create class instances
pen = Pen()
pen.speed(0)
player=Player()
player.speed(0)
trail = Pen()
trail.color("black")
# Walls

# print(walls)
#Set up the level
walls, goal, goalstamp, playable, px,py = setup_maze(levels[1])
# print(walls)
# wn.tracer(0)


#Keyboard Binding
# turtle.listen()
# turtle.onkey(player.go_left,"Left")
# turtle.onkey(player.go_right,"Right")
# turtle.onkey(player.go_up,"Up")
# turtle.onkey(player.go_down,"Down")


#Turn off screen upates

# %%
from keras import Sequential
from keras.layers import Dense, PReLU
from keras.optimizers import RMSprop, Adam, SGD

def create_model():
    model = Sequential()
    model.add(Dense(24, input_shape=(24*24,), activation="relu"))
#     model.add(Dense(4, input_shape=(576,), activation="linear"))

#     model.add(Dense(10, activation="relu"))

#     model.add(Dense((24*24)//16, activation="relu"))
#     model.add(Dense((24*24)//32, activation="relu"))
    model.add(Dense(4, activation="linear"))
    model.compile(optimizer=Adam(),loss='mse')
    return model

model = create_model()
target_model = create_model()
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0827 23:42:12.875419 140474675042112 deprecation_wrapper.py:119] From /home/rjm49/anaconda3/envs/mlc/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0827 23:42:12.892163 140474675042112 deprecation_wrapper.py:119] From /home/rjm49/anaconda3/envs/mlc/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0827 23:42:12.894971 140474675042112 deprecation_wrapper.py:119] From /home/rjm49/anaconda3/envs/mlc/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0827 23:42:12.941226 140474675042112 deprecation_wrapper.py:119] From /home/rjm49/anaconda3/envs/mlc/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
import numpy
import random
from collections import defaultdict, deque
#Main Game Loop
episode = 0
moves = 0
draw = True
gamma = 0.99
alpha = 0.9
stampcache = {}
exp_replay = deque([],500)

# %%
from keras.callbacks import EarlyStopping
es = EarlyStopping( monitor="loss", patience=10, restore_best_weights=True)

import math
mv_list = ['L','R','U','D']
last_mv = None


ohs = []
print("setting up optimistic starts")
for (sx,sy) in playable:
    gx,gy = screen_to_grid(sx,sy)
    oh = grid_to_onehot((gx,gy)).flatten()
    ohs.append(oh)
init_scores=numpy.array([[0,0,0,0] for el in ohs])
ohs = numpy.array(ohs)
model.fit(ohs, init_scores, epochs=1000, shuffle=True, verbose=2, callbacks=[es])
print("done")

target_model.set_weights(model.get_weights())

max_R = -math.inf
min_R = math.inf
for (sx,sy) in playable:
    gx,gy = screen_to_grid(sx,sy)
    oh_xy = grid_to_onehot((gx,gy))    
    poss_mvs = target_model.predict(oh_xy.reshape(1,-1))[0]
    if max(poss_mvs) > max_R:
        max_R = max(poss_mvs)
    if min(poss_mvs) < min_R:
        min_R = min(poss_mvs)
        
for (sx,sy) in playable:
    if (sx,sy)==goal:
        continue
    gx,gy = screen_to_grid(sx,sy)
    oh_xy = grid_to_onehot((gx,gy))    
    poss_mvs = target_model.predict(oh_xy.reshape(1,-1))[0]
    colval = float((numpy.max(poss_mvs) -min_R)/(max_R-min_R)) if (max_R-min_R) else 0.5
    print("COLVAL", colval)
    trail.fillcolor(colval , 0,0 )
    trail.goto(sx,sy)
    stampid = trail.stamp()
    stampcache[(sx,sy)] = stampid




# init_scores=numpy.array([[0,0,0,0] for el in playable])
# init_locations = numpy.array(playable)
# model.fit(init_locations, init_scores, epochs=1000, verbose=1)
# init_pred = model.predict(init_locations)

# input("hit return")
# Out:
# W0827 23:42:13.171136 140474675042112 deprecation_wrapper.py:119] From /home/rjm49/anaconda3/envs/mlc/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0827 23:42:13.236607 140474675042112 deprecation_wrapper.py:119] From /home/rjm49/anaconda3/envs/mlc/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# setting up optimistic starts
# Epoch 1/1000
#  - 0s - loss: 0.9729
# Epoch 2/1000
#  - 0s - loss: 0.9202
# Epoch 3/1000
#  - 0s - loss: 0.8654
# Epoch 4/1000
#  - 0s - loss: 0.8091
# Epoch 5/1000
#  - 0s - loss: 0.7499
# Epoch 6/1000
#  - 0s - loss: 0.6863
# Epoch 7/1000
#  - 0s - loss: 0.6182
# Epoch 8/1000
#  - 0s - loss: 0.5457
# Epoch 9/1000
#  - 0s - loss: 0.4696
# Epoch 10/1000
#  - 0s - loss: 0.3919
# Epoch 11/1000
#  - 0s - loss: 0.3156
# Epoch 12/1000
#  - 0s - loss: 0.2457
# Epoch 13/1000
#  - 0s - loss: 0.1852
# Epoch 14/1000
#  - 0s - loss: 0.1347
# Epoch 15/1000
#  - 0s - loss: 0.0949
# Epoch 16/1000
#  - 0s - loss: 0.0652
# Epoch 17/1000
#  - 0s - loss: 0.0442
# Epoch 18/1000
#  - 0s - loss: 0.0302
# Epoch 19/1000
#  - 0s - loss: 0.0208
# Epoch 20/1000
#  - 0s - loss: 0.0150
# Epoch 21/1000
#  - 0s - loss: 0.0111
# Epoch 22/1000
#  - 0s - loss: 0.0085
# Epoch 23/1000
#  - 0s - loss: 0.0069
# Epoch 24/1000
#  - 0s - loss: 0.0057
# Epoch 25/1000
#  - 0s - loss: 0.0049
# Epoch 26/1000
#  - 0s - loss: 0.0043
# Epoch 27/1000
#  - 0s - loss: 0.0038
# Epoch 28/1000
#  - 0s - loss: 0.0035
# Epoch 29/1000
#  - 0s - loss: 0.0032
# Epoch 30/1000
#  - 0s - loss: 0.0029
# Epoch 31/1000
#  - 0s - loss: 0.0027
# Epoch 32/1000
#  - 0s - loss: 0.0025
# Epoch 33/1000
#  - 0s - loss: 0.0024
# Epoch 34/1000
#  - 0s - loss: 0.0022
# Epoch 35/1000
#  - 0s - loss: 0.0021
# Epoch 36/1000
#  - 0s - loss: 0.0019
# Epoch 37/1000
#  - 0s - loss: 0.0018
# Epoch 38/1000
#  - 0s - loss: 0.0017
# Epoch 39/1000
#  - 0s - loss: 0.0016
# Epoch 40/1000
#  - 0s - loss: 0.0015
# Epoch 41/1000
#  - 0s - loss: 0.0014
# Epoch 42/1000
#  - 0s - loss: 0.0014
# Epoch 43/1000
#  - 0s - loss: 0.0013
# Epoch 44/1000
#  - 0s - loss: 0.0012
# Epoch 45/1000
#  - 0s - loss: 0.0011
# Epoch 46/1000
#  - 0s - loss: 0.0011
# Epoch 47/1000
#  - 0s - loss: 0.0010
# Epoch 48/1000
#  - 0s - loss: 9.7025e-04
# Epoch 49/1000
#  - 0s - loss: 9.2091e-04
# Epoch 50/1000
#  - 0s - loss: 8.7556e-04
# Epoch 51/1000
#  - 0s - loss: 8.3139e-04
# Epoch 52/1000
#  - 0s - loss: 7.9145e-04
# Epoch 53/1000
#  - 0s - loss: 7.5257e-04
# Epoch 54/1000
#  - 0s - loss: 7.1687e-04
# Epoch 55/1000
#  - 0s - loss: 6.8355e-04
# Epoch 56/1000
#  - 0s - loss: 6.5207e-04
# Epoch 57/1000
#  - 0s - loss: 6.2211e-04
# Epoch 58/1000
#  - 0s - loss: 5.9431e-04
# Epoch 59/1000
#  - 0s - loss: 5.6751e-04
# Epoch 60/1000
#  - 0s - loss: 5.4240e-04
# Epoch 61/1000
#  - 0s - loss: 5.1851e-04
# Epoch 62/1000
#  - 0s - loss: 4.9633e-04
# Epoch 63/1000
#  - 0s - loss: 4.7498e-04
# Epoch 64/1000
#  - 0s - loss: 4.5565e-04
# Epoch 65/1000
#  - 0s - loss: 4.3584e-04
# Epoch 66/1000
#  - 0s - loss: 4.1799e-04
# Epoch 67/1000
#  - 0s - loss: 4.0082e-04
# Epoch 68/1000
#  - 0s - loss: 3.8417e-04
# Epoch 69/1000
#  - 0s - loss: 3.6830e-04
# Epoch 70/1000
#  - 0s - loss: 3.5380e-04
# Epoch 71/1000
#  - 0s - loss: 3.3941e-04
# Epoch 72/1000
#  - 0s - loss: 3.2600e-04
# Epoch 73/1000
#  - 0s - loss: 3.1284e-04
# Epoch 74/1000
#  - 0s - loss: 3.0096e-04
# Epoch 75/1000
#  - 0s - loss: 2.8896e-04
# Epoch 76/1000
#  - 0s - loss: 2.7799e-04
# Epoch 77/1000
#  - 0s - loss: 2.6684e-04
# Epoch 78/1000
#  - 0s - loss: 2.5664e-04
# Epoch 79/1000
#  - 0s - loss: 2.4675e-04
# Epoch 80/1000
#  - 0s - loss: 2.3740e-04
# Epoch 81/1000
#  - 0s - loss: 2.2816e-04
# Epoch 82/1000
#  - 0s - loss: 2.1974e-04
# Epoch 83/1000
#  - 0s - loss: 2.1167e-04
# Epoch 84/1000
#  - 0s - loss: 2.0347e-04
# Epoch 85/1000
#  - 0s - loss: 1.9590e-04
# Epoch 86/1000
#  - 0s - loss: 1.8867e-04
# Epoch 87/1000
#  - 0s - loss: 1.8184e-04
# Epoch 88/1000
#  - 0s - loss: 1.7501e-04
# Epoch 89/1000
#  - 0s - loss: 1.6854e-04
# Epoch 90/1000
#  - 0s - loss: 1.6245e-04
# Epoch 91/1000
#  - 0s - loss: 1.5632e-04
# Epoch 92/1000
#  - 0s - loss: 1.5072e-04
# Epoch 93/1000
#  - 0s - loss: 1.4521e-04
# Epoch 94/1000
#  - 0s - loss: 1.4002e-04
# Epoch 95/1000
#  - 0s - loss: 1.3486e-04
# Epoch 96/1000
#  - 0s - loss: 1.2997e-04
# Epoch 97/1000
#  - 0s - loss: 1.2528e-04
# Epoch 98/1000
#  - 0s - loss: 1.2080e-04
# Epoch 99/1000
#  - 0s - loss: 1.1642e-04
# Epoch 100/1000
#  - 0s - loss: 1.1208e-04
# Epoch 101/1000
#  - 0s - loss: 1.0798e-04
# Epoch 102/1000
#  - 0s - loss: 1.0408e-04
# Epoch 103/1000
#  - 0s - loss: 1.0030e-04
# Epoch 104/1000
#  - 0s - loss: 9.6671e-05
# Epoch 105/1000
#  - 0s - loss: 9.3111e-05
# Epoch 106/1000
#  - 0s - loss: 8.9645e-05
# Epoch 107/1000
#  - 0s - loss: 8.6634e-05
# Epoch 108/1000
#  - 0s - loss: 8.3286e-05
# Epoch 109/1000
#  - 0s - loss: 8.0168e-05
# Epoch 110/1000
#  - 0s - loss: 7.7291e-05
# Epoch 111/1000
#  - 0s - loss: 7.4376e-05
# Epoch 112/1000
#  - 0s - loss: 7.1778e-05
# Epoch 113/1000
#  - 0s - loss: 6.9069e-05
# Epoch 114/1000
#  - 0s - loss: 6.6529e-05
# Epoch 115/1000
#  - 0s - loss: 6.4090e-05
# Epoch 116/1000
#  - 0s - loss: 6.1663e-05
# Epoch 117/1000
#  - 0s - loss: 5.9372e-05
# Epoch 118/1000
#  - 0s - loss: 5.7151e-05
# Epoch 119/1000
#  - 0s - loss: 5.5094e-05
# Epoch 120/1000
#  - 0s - loss: 5.2999e-05
# Epoch 121/1000
#  - 0s - loss: 5.0985e-05
# Epoch 122/1000
#  - 0s - loss: 4.9015e-05
# Epoch 123/1000
#  - 0s - loss: 4.7107e-05
# Epoch 124/1000
#  - 0s - loss: 4.5425e-05
# Epoch 125/1000
#  - 0s - loss: 4.3599e-05
# Epoch 126/1000
#  - 0s - loss: 4.1940e-05
# Epoch 127/1000
#  - 0s - loss: 4.0427e-05
# Epoch 128/1000
#  - 0s - loss: 3.8838e-05
# Epoch 129/1000
#  - 0s - loss: 3.7262e-05
# Epoch 130/1000
#  - 0s - loss: 3.5852e-05
# Epoch 131/1000
#  - 0s - loss: 3.4435e-05
# Epoch 132/1000
#  - 0s - loss: 3.3067e-05
# Epoch 133/1000
#  - 0s - loss: 3.1794e-05
# Epoch 134/1000
#  - 0s - loss: 3.0520e-05
# Epoch 135/1000
#  - 0s - loss: 2.9330e-05
# Epoch 136/1000
#  - 0s - loss: 2.8108e-05
# Epoch 137/1000
#  - 0s - loss: 2.6996e-05
# Epoch 138/1000
#  - 0s - loss: 2.5926e-05
# Epoch 139/1000
#  - 0s - loss: 2.4873e-05
# Epoch 140/1000
#  - 0s - loss: 2.3879e-05
# Epoch 141/1000
#  - 0s - loss: 2.2907e-05
# Epoch 142/1000
#  - 0s - loss: 2.1953e-05
# Epoch 143/1000
#  - 0s - loss: 2.1099e-05
# Epoch 144/1000
#  - 0s - loss: 2.0262e-05
# Epoch 145/1000
#  - 0s - loss: 1.9425e-05
# Epoch 146/1000
#  - 0s - loss: 1.8609e-05
# Epoch 147/1000
#  - 0s - loss: 1.7863e-05
# Epoch 148/1000
#  - 0s - loss: 1.7121e-05
# Epoch 149/1000
#  - 0s - loss: 1.6408e-05
# Epoch 150/1000
#  - 0s - loss: 1.5716e-05
# Epoch 151/1000
#  - 0s - loss: 1.5059e-05
# Epoch 152/1000
#  - 0s - loss: 1.4459e-05
# Epoch 153/1000
#  - 0s - loss: 1.3831e-05
# Epoch 154/1000
#  - 0s - loss: 1.3243e-05
# Epoch 155/1000
#  - 0s - loss: 1.2709e-05
# Epoch 156/1000
#  - 0s - loss: 1.2149e-05
# Epoch 157/1000
#  - 0s - loss: 1.1644e-05
# Epoch 158/1000
#  - 0s - loss: 1.1132e-05
# Epoch 159/1000
#  - 0s - loss: 1.0650e-05
# Epoch 160/1000
#  - 0s - loss: 1.0202e-05
# Epoch 161/1000
#  - 0s - loss: 9.7627e-06
# Epoch 162/1000
#  - 0s - loss: 9.3354e-06
# Epoch 163/1000
#  - 0s - loss: 8.9351e-06
# Epoch 164/1000
#  - 0s - loss: 8.5501e-06
# Epoch 165/1000
#  - 0s - loss: 8.1694e-06
# Epoch 166/1000
#  - 0s - loss: 7.8032e-06
# Epoch 167/1000
#  - 0s - loss: 7.4639e-06
# Epoch 168/1000
#  - 0s - loss: 7.1294e-06
# Epoch 169/1000
#  - 0s - loss: 6.8182e-06
# Epoch 170/1000
#  - 0s - loss: 6.5119e-06
# Epoch 171/1000
#  - 0s - loss: 6.2369e-06
# Epoch 172/1000
#  - 0s - loss: 5.9540e-06
# Epoch 173/1000
#  - 0s - loss: 5.6819e-06
# Epoch 174/1000
#  - 0s - loss: 5.4175e-06
# Epoch 175/1000
#  - 0s - loss: 5.1815e-06
# Epoch 176/1000
#  - 0s - loss: 4.9484e-06
# Epoch 177/1000
#  - 0s - loss: 4.7156e-06
# Epoch 178/1000
#  - 0s - loss: 4.4978e-06
# Epoch 179/1000
#  - 0s - loss: 4.2905e-06
# Epoch 180/1000
#  - 0s - loss: 4.1003e-06
# Epoch 181/1000
#  - 0s - loss: 3.8909e-06
# Epoch 182/1000
#  - 0s - loss: 3.7239e-06
# Epoch 183/1000
#  - 0s - loss: 3.5471e-06
# Epoch 184/1000
#  - 0s - loss: 3.3896e-06
# Epoch 185/1000
#  - 0s - loss: 3.2239e-06
# Epoch 186/1000
#  - 0s - loss: 3.0735e-06
# Epoch 187/1000
#  - 0s - loss: 2.9268e-06
# Epoch 188/1000
#  - 0s - loss: 2.7961e-06
# Epoch 189/1000
#  - 0s - loss: 2.6609e-06
# Epoch 190/1000
#  - 0s - loss: 2.5259e-06
# Epoch 191/1000
#  - 0s - loss: 2.4139e-06
# Epoch 192/1000
#  - 0s - loss: 2.2922e-06
# Epoch 193/1000
#  - 0s - loss: 2.1871e-06
# Epoch 194/1000
#  - 0s - loss: 2.0798e-06
# Epoch 195/1000
#  - 0s - loss: 1.9756e-06
# Epoch 196/1000
#  - 0s - loss: 1.8839e-06
# Epoch 197/1000
#  - 0s - loss: 1.7890e-06
# Epoch 198/1000
#  - 0s - loss: 1.7048e-06
# Epoch 199/1000
#  - 0s - loss: 1.6166e-06
# Epoch 200/1000
#  - 0s - loss: 1.5388e-06
# Epoch 201/1000
#  - 0s - loss: 1.4627e-06
# Epoch 202/1000
#  - 0s - loss: 1.3888e-06
# Epoch 203/1000
#  - 0s - loss: 1.3219e-06
# Epoch 204/1000
#  - 0s - loss: 1.2550e-06
# Epoch 205/1000
#  - 0s - loss: 1.1862e-06
# Epoch 206/1000
#  - 0s - loss: 1.1310e-06
# Epoch 207/1000
#  - 0s - loss: 1.0711e-06
# Epoch 208/1000
#  - 0s - loss: 1.0158e-06
# Epoch 209/1000
#  - 0s - loss: 9.6497e-07
# Epoch 210/1000
#  - 0s - loss: 9.1852e-07
# Epoch 211/1000
#  - 0s - loss: 8.6872e-07
# Epoch 212/1000
#  - 0s - loss: 8.2355e-07
# Epoch 213/1000
#  - 0s - loss: 7.7995e-07
# Epoch 214/1000
#  - 0s - loss: 7.4212e-07
# Epoch 215/1000
#  - 0s - loss: 7.0228e-07
# Epoch 216/1000
#  - 0s - loss: 6.6565e-07
# Epoch 217/1000
#  - 0s - loss: 6.3156e-07
# Epoch 218/1000
#  - 0s - loss: 5.9799e-07
# Epoch 219/1000
#  - 0s - loss: 5.6629e-07
# Epoch 220/1000
#  - 0s - loss: 5.3431e-07
# Epoch 221/1000
#  - 0s - loss: 5.0732e-07
# Epoch 222/1000
#  - 0s - loss: 4.7987e-07
# Epoch 223/1000
#  - 0s - loss: 4.5153e-07
# Epoch 224/1000
#  - 0s - loss: 4.2822e-07
# Epoch 225/1000
#  - 0s - loss: 4.0409e-07
# Epoch 226/1000
#  - 0s - loss: 3.8246e-07
# Epoch 227/1000
#  - 0s - loss: 3.6255e-07
# Epoch 228/1000
#  - 0s - loss: 3.4043e-07
# Epoch 229/1000
#  - 0s - loss: 3.2239e-07
# Epoch 230/1000
#  - 0s - loss: 3.0406e-07
# Epoch 231/1000
#  - 0s - loss: 2.8747e-07
# Epoch 232/1000
#  - 0s - loss: 2.7145e-07
# Epoch 233/1000
#  - 0s - loss: 2.5596e-07
# Epoch 234/1000
#  - 0s - loss: 2.4207e-07
# Epoch 235/1000
#  - 0s - loss: 2.2798e-07
# Epoch 236/1000
#  - 0s - loss: 2.1551e-07
# Epoch 237/1000
#  - 0s - loss: 2.0366e-07
# Epoch 238/1000
#  - 0s - loss: 1.9076e-07
# Epoch 239/1000
#  - 0s - loss: 1.7947e-07
# Epoch 240/1000
#  - 0s - loss: 1.6933e-07
# Epoch 241/1000
#  - 0s - loss: 1.5970e-07
# Epoch 242/1000
#  - 0s - loss: 1.5025e-07
# Epoch 243/1000
#  - 0s - loss: 1.4144e-07
# Epoch 244/1000
#  - 0s - loss: 1.3397e-07
# Epoch 245/1000
#  - 0s - loss: 1.2547e-07
# Epoch 246/1000
#  - 0s - loss: 1.1816e-07
# Epoch 247/1000
#  - 0s - loss: 1.1120e-07
# Epoch 248/1000
#  - 0s - loss: 1.0508e-07
# Epoch 249/1000
#  - 0s - loss: 9.8303e-08
# Epoch 250/1000
#  - 0s - loss: 9.2708e-08
# Epoch 251/1000
#  - 0s - loss: 8.7099e-08
# Epoch 252/1000
#  - 0s - loss: 8.2244e-08
# Epoch 253/1000
#  - 0s - loss: 7.6832e-08
# Epoch 254/1000
#  - 0s - loss: 7.2249e-08
# Epoch 255/1000
#  - 0s - loss: 6.7973e-08
# Epoch 256/1000
#  - 0s - loss: 6.3893e-08
# Epoch 257/1000
#  - 0s - loss: 5.9711e-08
# Epoch 258/1000
#  - 0s - loss: 5.6075e-08
# Epoch 259/1000
#  - 0s - loss: 5.2680e-08
# Epoch 260/1000
#  - 0s - loss: 4.9163e-08
# Epoch 261/1000
#  - 0s - loss: 4.6250e-08
# Epoch 262/1000
#  - 0s - loss: 4.3517e-08
# Epoch 263/1000
#  - 0s - loss: 4.0683e-08
# Epoch 264/1000
#  - 0s - loss: 3.8168e-08
# Epoch 265/1000
#  - 0s - loss: 3.5827e-08
# Epoch 266/1000
#  - 0s - loss: 3.3451e-08
# Epoch 267/1000
#  - 0s - loss: 3.1313e-08
# Epoch 268/1000
#  - 0s - loss: 2.9359e-08
# Epoch 269/1000
#  - 0s - loss: 2.7523e-08
# Epoch 270/1000
#  - 0s - loss: 2.5651e-08
# Epoch 271/1000
#  - 0s - loss: 2.3978e-08
# Epoch 272/1000
#  - 0s - loss: 2.2387e-08
# Epoch 273/1000
#  - 0s - loss: 2.1025e-08
# Epoch 274/1000
#  - 0s - loss: 1.9691e-08
# Epoch 275/1000
#  - 0s - loss: 1.8361e-08
# Epoch 276/1000
#  - 0s - loss: 1.7337e-08
# Epoch 277/1000
#  - 0s - loss: 1.5974e-08
# Epoch 278/1000
#  - 0s - loss: 1.4938e-08
# Epoch 279/1000
#  - 0s - loss: 1.3960e-08
# Epoch 280/1000
#  - 0s - loss: 1.3122e-08
# Epoch 281/1000
#  - 0s - loss: 1.2134e-08
# Epoch 282/1000
#  - 0s - loss: 1.1376e-08
# Epoch 283/1000
#  - 0s - loss: 1.0611e-08
# Epoch 284/1000
#  - 0s - loss: 9.8912e-09
# Epoch 285/1000
#  - 0s - loss: 9.1531e-09
# Epoch 286/1000
#  - 0s - loss: 8.5599e-09
# Epoch 287/1000
#  - 0s - loss: 7.9964e-09
# Epoch 288/1000
#  - 0s - loss: 7.4220e-09
# Epoch 289/1000
#  - 0s - loss: 6.9069e-09
# Epoch 290/1000
#  - 0s - loss: 6.4388e-09
# Epoch 291/1000
#  - 0s - loss: 5.9988e-09
# Epoch 292/1000
#  - 0s - loss: 5.5415e-09
# Epoch 293/1000
#  - 0s - loss: 5.1647e-09
# Epoch 294/1000
#  - 0s - loss: 4.8408e-09
# Epoch 295/1000
#  - 0s - loss: 4.4423e-09
# Epoch 296/1000
#  - 0s - loss: 4.1985e-09
# Epoch 297/1000
#  - 0s - loss: 3.8600e-09
# Epoch 298/1000
#  - 0s - loss: 3.5640e-09
# Epoch 299/1000
#  - 0s - loss: 3.3085e-09
# Epoch 300/1000
#  - 0s - loss: 3.0686e-09
# Epoch 301/1000
#  - 0s - loss: 2.8457e-09
# Epoch 302/1000
#  - 0s - loss: 2.6587e-09
# Epoch 303/1000
#  - 0s - loss: 2.4758e-09
# Epoch 304/1000
#  - 0s - loss: 2.2902e-09
# Epoch 305/1000
#  - 0s - loss: 2.1196e-09
# Epoch 306/1000
#  - 0s - loss: 1.9671e-09
# Epoch 307/1000
#  - 0s - loss: 1.8279e-09
# Epoch 308/1000
#  - 0s - loss: 1.6859e-09
# Epoch 309/1000
#  - 0s - loss: 1.5707e-09
# Epoch 310/1000
#  - 0s - loss: 1.4549e-09
# Epoch 311/1000
#  - 0s - loss: 1.3410e-09
# Epoch 312/1000
#  - 0s - loss: 1.2457e-09
# Epoch 313/1000
#  - 0s - loss: 1.1478e-09
# Epoch 314/1000
#  - 0s - loss: 1.0684e-09
# Epoch 315/1000
#  - 0s - loss: 9.9281e-10
# Epoch 316/1000
#  - 0s - loss: 9.0735e-10
# Epoch 317/1000
#  - 0s - loss: 8.4641e-10
# Epoch 318/1000
#  - 0s - loss: 7.8643e-10
# Epoch 319/1000
#  - 0s - loss: 7.1806e-10
# Epoch 320/1000
#  - 0s - loss: 6.6327e-10
# Epoch 321/1000
#  - 0s - loss: 6.1225e-10
# Epoch 322/1000
#  - 0s - loss: 5.6784e-10
# Epoch 323/1000
#  - 0s - loss: 5.2231e-10
# Epoch 324/1000
#  - 0s - loss: 4.8460e-10
# Epoch 325/1000
#  - 0s - loss: 4.4134e-10
# Epoch 326/1000
#  - 0s - loss: 4.0676e-10
# Epoch 327/1000
#  - 0s - loss: 3.7729e-10
# Epoch 328/1000
#  - 0s - loss: 3.4384e-10
# Epoch 329/1000
#  - 0s - loss: 3.1994e-10
# Epoch 330/1000
#  - 0s - loss: 2.9189e-10
# Epoch 331/1000
#  - 0s - loss: 2.6712e-10
# Epoch 332/1000
#  - 0s - loss: 2.4678e-10
# Epoch 333/1000
#  - 0s - loss: 2.2976e-10
# Epoch 334/1000
#  - 0s - loss: 2.0676e-10
# Epoch 335/1000
#  - 0s - loss: 1.9134e-10
# Epoch 336/1000
#  - 0s - loss: 1.7612e-10
# Epoch 337/1000
#  - 0s - loss: 1.6113e-10
# Epoch 338/1000
#  - 0s - loss: 1.4689e-10
# Epoch 339/1000
#  - 0s - loss: 1.3542e-10
# Epoch 340/1000
#  - 0s - loss: 1.2369e-10
# Epoch 341/1000
#  - 0s - loss: 1.1379e-10
# Epoch 342/1000
#  - 0s - loss: 1.0637e-10
# Epoch 343/1000
#  - 0s - loss: 9.6787e-11
# Epoch 344/1000
#  - 0s - loss: 8.7843e-11
# Epoch 345/1000
#  - 0s - loss: 8.0464e-11
# Epoch 346/1000
#  - 0s - loss: 7.3952e-11
# Epoch 347/1000
#  - 0s - loss: 6.8442e-11
# Epoch 348/1000
#  - 0s - loss: 6.1221e-11
# Epoch 349/1000
#  - 0s - loss: 5.6608e-11
# Epoch 350/1000
#  - 0s - loss: 5.2393e-11
# Epoch 351/1000
#  - 0s - loss: 4.7522e-11
# Epoch 352/1000
#  - 0s - loss: 4.3281e-11
# Epoch 353/1000
#  - 0s - loss: 3.9361e-11
# Epoch 354/1000
#  - 0s - loss: 3.6946e-11
# Epoch 355/1000
#  - 0s - loss: 3.2562e-11
# Epoch 356/1000
#  - 0s - loss: 2.9987e-11
# Epoch 357/1000
#  - 0s - loss: 2.7399e-11
# Epoch 358/1000
#  - 0s - loss: 2.4972e-11
# Epoch 359/1000
#  - 0s - loss: 2.2721e-11
# Epoch 360/1000
#  - 0s - loss: 2.0764e-11
# Epoch 361/1000
#  - 0s - loss: 1.8796e-11
# Epoch 362/1000
#  - 0s - loss: 1.7215e-11
# Epoch 363/1000
#  - 0s - loss: 1.5538e-11
# Epoch 364/1000
#  - 0s - loss: 1.4349e-11
# Epoch 365/1000
#  - 0s - loss: 1.2957e-11
# Epoch 366/1000
#  - 0s - loss: 1.1995e-11
# Epoch 367/1000
#  - 0s - loss: 1.0778e-11
# Epoch 368/1000
#  - 0s - loss: 9.7596e-12
# Epoch 369/1000
#  - 0s - loss: 8.8887e-12
# Epoch 370/1000
#  - 0s - loss: 8.0497e-12
# Epoch 371/1000
#  - 0s - loss: 7.5045e-12
# Epoch 372/1000
#  - 0s - loss: 6.6434e-12
# Epoch 373/1000
#  - 0s - loss: 5.9926e-12
# Epoch 374/1000
#  - 0s - loss: 5.4729e-12
# Epoch 375/1000
#  - 0s - loss: 5.0111e-12
# Epoch 376/1000
#  - 0s - loss: 4.4611e-12
# Epoch 377/1000
#  - 0s - loss: 4.1175e-12
# Epoch 378/1000
#  - 0s - loss: 3.7472e-12
# Epoch 379/1000
#  - 0s - loss: 3.3843e-12
# Epoch 380/1000
#  - 0s - loss: 3.0103e-12
# Epoch 381/1000
#  - 0s - loss: 2.7653e-12
# Epoch 382/1000
#  - 0s - loss: 2.4873e-12
# Epoch 383/1000
#  - 0s - loss: 2.2852e-12
# Epoch 384/1000
#  - 0s - loss: 2.0429e-12
# Epoch 385/1000
#  - 0s - loss: 1.8497e-12
# Epoch 386/1000
#  - 0s - loss: 1.6754e-12
# Epoch 387/1000
#  - 0s - loss: 1.5360e-12
# Epoch 388/1000
#  - 0s - loss: 1.3684e-12
# Epoch 389/1000
#  - 0s - loss: 1.2208e-12
# Epoch 390/1000
#  - 0s - loss: 1.1079e-12
# Epoch 391/1000
#  - 0s - loss: 9.8368e-13
# Epoch 392/1000
#  - 0s - loss: 8.9496e-13
# Epoch 393/1000
#  - 0s - loss: 8.2393e-13
# Epoch 394/1000
#  - 0s - loss: 7.3358e-13
# Epoch 395/1000
#  - 0s - loss: 6.6223e-13
# Epoch 396/1000
#  - 0s - loss: 5.9472e-13
# Epoch 397/1000
#  - 0s - loss: 5.3737e-13
# Epoch 398/1000
#  - 0s - loss: 4.9292e-13
# Epoch 399/1000
#  - 0s - loss: 4.4318e-13
# Epoch 400/1000
#  - 0s - loss: 3.9551e-13
# Epoch 401/1000
#  - 0s - loss: 3.5957e-13
# Epoch 402/1000
#  - 0s - loss: 3.1817e-13
# Epoch 403/1000
#  - 0s - loss: 2.9445e-13
# Epoch 404/1000
#  - 0s - loss: 2.6799e-13
# Epoch 405/1000
#  - 0s - loss: 2.3248e-13
# Epoch 406/1000
#  - 0s - loss: 2.1436e-13
# Epoch 407/1000
#  - 0s - loss: 1.9170e-13
# Epoch 408/1000
#  - 0s - loss: 1.7404e-13
# Epoch 409/1000
#  - 0s - loss: 1.5469e-13
# Epoch 410/1000
#  - 0s - loss: 1.4106e-13
# Epoch 411/1000
#  - 0s - loss: 1.2661e-13
# Epoch 412/1000
#  - 0s - loss: 1.1343e-13
# Epoch 413/1000
#  - 0s - loss: 1.0484e-13
# Epoch 414/1000
#  - 0s - loss: 9.2083e-14
# Epoch 415/1000
#  - 0s - loss: 8.4799e-14
# Epoch 416/1000
#  - 0s - loss: 7.5978e-14
# Epoch 417/1000
#  - 0s - loss: 6.8588e-14
# Epoch 418/1000
#  - 0s - loss: 6.1179e-14
# Epoch 419/1000
#  - 0s - loss: 5.6920e-14
# Epoch 420/1000
#  - 0s - loss: 5.0719e-14
# Epoch 421/1000
#  - 0s - loss: 4.5789e-14
# Epoch 422/1000
#  - 0s - loss: 4.2939e-14
# Epoch 423/1000
#  - 0s - loss: 4.2054e-14
# Epoch 424/1000
#  - 0s - loss: 4.8933e-14
# Epoch 425/1000
#  - 0s - loss: 3.7335e-14
# Epoch 426/1000
#  - 0s - loss: 3.3984e-14
# Epoch 427/1000
#  - 0s - loss: 2.8057e-14
# Epoch 428/1000
#  - 0s - loss: 2.5173e-14
# Epoch 429/1000
#  - 0s - loss: 2.2256e-14
# Epoch 430/1000
#  - 0s - loss: 2.0460e-14
# Epoch 431/1000
#  - 0s - loss: 1.8514e-14
# Epoch 432/1000
#  - 0s - loss: 1.7278e-14
# Epoch 433/1000
#  - 0s - loss: 1.5738e-14
# Epoch 434/1000
#  - 0s - loss: 1.4201e-14
# Epoch 435/1000
#  - 0s - loss: 1.3837e-14
# Epoch 436/1000
#  - 0s - loss: 1.2658e-14
# Epoch 437/1000
#  - 0s - loss: 1.1978e-14
# Epoch 438/1000
#  - 0s - loss: 1.0620e-14
# Epoch 439/1000
#  - 0s - loss: 1.0262e-14
# Epoch 440/1000
#  - 0s - loss: 9.8275e-15
# Epoch 441/1000
#  - 0s - loss: 9.0032e-15
# Epoch 442/1000
#  - 0s - loss: 8.6326e-15
# Epoch 443/1000
#  - 0s - loss: 7.7540e-15
# Epoch 444/1000
#  - 0s - loss: 7.6645e-15
# Epoch 445/1000
#  - 0s - loss: 7.0479e-15
# Epoch 446/1000
#  - 0s - loss: 7.0319e-15
# Epoch 447/1000
#  - 0s - loss: 6.9968e-15
# Epoch 448/1000
#  - 0s - loss: 6.7923e-15
# Epoch 449/1000
#  - 0s - loss: 6.4441e-15
# Epoch 450/1000
#  - 0s - loss: 6.1086e-15
# Epoch 451/1000
#  - 0s - loss: 5.8019e-15
# Epoch 452/1000
#  - 0s - loss: 5.3355e-15
# Epoch 453/1000
#  - 0s - loss: 5.3419e-15
# Epoch 454/1000
#  - 0s - loss: 5.3355e-15
# Epoch 455/1000
#  - 0s - loss: 5.1597e-15
# Epoch 456/1000
#  - 0s - loss: 4.9105e-15
# Epoch 457/1000
#  - 0s - loss: 4.8179e-15
# Epoch 458/1000
#  - 0s - loss: 4.7987e-15
# Epoch 459/1000
#  - 0s - loss: 4.3450e-15
# Epoch 460/1000
#  - 0s - loss: 4.3514e-15
# Epoch 461/1000
#  - 0s - loss: 4.4537e-15
# Epoch 462/1000
#  - 0s - loss: 4.1374e-15
# Epoch 463/1000
#  - 0s - loss: 4.0543e-15
# Epoch 464/1000
#  - 0s - loss: 3.8626e-15
# Epoch 465/1000
#  - 0s - loss: 3.7157e-15
# Epoch 466/1000
#  - 0s - loss: 3.6965e-15
# Epoch 467/1000
#  - 0s - loss: 3.6326e-15
# Epoch 468/1000
#  - 0s - loss: 3.5240e-15
# Epoch 469/1000
#  - 0s - loss: 3.6006e-15
# Epoch 470/1000
#  - 0s - loss: 3.3482e-15
# Epoch 471/1000
#  - 0s - loss: 3.3099e-15
# Epoch 472/1000
#  - 0s - loss: 3.1981e-15
# Epoch 473/1000
#  - 0s - loss: 3.2013e-15
# Epoch 474/1000
#  - 0s - loss: 3.0479e-15
# Epoch 475/1000
#  - 0s - loss: 2.8115e-15
# Epoch 476/1000
#  - 0s - loss: 2.8722e-15
# Epoch 477/1000
#  - 0s - loss: 2.8530e-15
# Epoch 478/1000
#  - 0s - loss: 2.9329e-15
# Epoch 479/1000
#  - 0s - loss: 2.7859e-15
# Epoch 480/1000
#  - 0s - loss: 2.8786e-15
# Epoch 481/1000
#  - 0s - loss: 2.8403e-15
# Epoch 482/1000
#  - 0s - loss: 2.6773e-15
# Epoch 483/1000
#  - 0s - loss: 2.6933e-15
# Epoch 484/1000
#  - 0s - loss: 2.4281e-15
# Epoch 485/1000
#  - 0s - loss: 2.3419e-15
# Epoch 486/1000
#  - 0s - loss: 2.4153e-15
# Epoch 487/1000
#  - 0s - loss: 2.1821e-15
# Epoch 488/1000
#  - 0s - loss: 2.2684e-15
# Epoch 489/1000
#  - 0s - loss: 2.4121e-15
# Epoch 490/1000
#  - 0s - loss: 2.3482e-15
# Epoch 491/1000
#  - 0s - loss: 2.0927e-15
# Epoch 492/1000
#  - 0s - loss: 2.1757e-15
# Epoch 493/1000
#  - 0s - loss: 2.0990e-15
# Epoch 494/1000
#  - 0s - loss: 2.1470e-15
# Epoch 495/1000
#  - 0s - loss: 2.1118e-15
# Epoch 496/1000
#  - 0s - loss: 1.8403e-15
# Epoch 497/1000
#  - 0s - loss: 1.9393e-15
# Epoch 498/1000
#  - 0s - loss: 2.0415e-15
# Epoch 499/1000
#  - 0s - loss: 1.9042e-15
# Epoch 500/1000
#  - 0s - loss: 1.8211e-15
# Epoch 501/1000
#  - 0s - loss: 1.8690e-15
# Epoch 502/1000
#  - 0s - loss: 1.9329e-15
# Epoch 503/1000
#  - 0s - loss: 1.7348e-15
# Epoch 504/1000
#  - 0s - loss: 1.8882e-15
# Epoch 505/1000
#  - 0s - loss: 1.8562e-15
# Epoch 506/1000
#  - 0s - loss: 1.4856e-15
# Epoch 507/1000
#  - 0s - loss: 1.6102e-15
# Epoch 508/1000
#  - 0s - loss: 1.6581e-15
# Epoch 509/1000
#  - 0s - loss: 1.5367e-15
# Epoch 510/1000
#  - 0s - loss: 1.8211e-15
# Epoch 511/1000
#  - 0s - loss: 1.6006e-15
# Epoch 512/1000
#  - 0s - loss: 1.5048e-15
# Epoch 513/1000
#  - 0s - loss: 1.3514e-15
# Epoch 514/1000
#  - 0s - loss: 1.5016e-15
# Epoch 515/1000
#  - 0s - loss: 1.5367e-15
# Epoch 516/1000
#  - 0s - loss: 1.4185e-15
# Epoch 517/1000
#  - 0s - loss: 1.3898e-15
# Epoch 518/1000
#  - 0s - loss: 1.3866e-15
# Epoch 519/1000
#  - 0s - loss: 1.3866e-15
# Epoch 520/1000
#  - 0s - loss: 1.2684e-15
# Epoch 521/1000
#  - 0s - loss: 1.1246e-15
# Epoch 522/1000
#  - 0s - loss: 1.2460e-15
# Epoch 523/1000
#  - 0s - loss: 1.3546e-15
# Epoch 524/1000
#  - 0s - loss: 1.2300e-15
# Epoch 525/1000
#  - 0s - loss: 1.1502e-15
# Epoch 526/1000
#  - 0s - loss: 1.3546e-15
# Epoch 527/1000
#  - 0s - loss: 1.2620e-15
# Epoch 528/1000
#  - 0s - loss: 1.1885e-15
# Epoch 529/1000
#  - 0s - loss: 1.1374e-15
# Epoch 530/1000
#  - 0s - loss: 1.0160e-15
# Epoch 531/1000
#  - 0s - loss: 9.0096e-16
# Epoch 532/1000
#  - 0s - loss: 1.1693e-15
# Epoch 533/1000
#  - 0s - loss: 1.0863e-15
# Epoch 534/1000
#  - 0s - loss: 1.0415e-15
# Epoch 535/1000
#  - 0s - loss: 1.0415e-15
# Epoch 536/1000
#  - 0s - loss: 1.0958e-15
# Epoch 537/1000
#  - 0s - loss: 9.2971e-16
# Epoch 538/1000
#  - 0s - loss: 9.1054e-16
# Epoch 539/1000
#  - 0s - loss: 9.6805e-16
# Epoch 540/1000
#  - 0s - loss: 9.0096e-16
# Epoch 541/1000
#  - 0s - loss: 1.0479e-15
# done
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 1.0
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 1.0
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.375
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 1.0
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 1.0
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 1.0
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.75
# COLVAL 0.5
# COLVAL 0.5
# COLVAL 0.75

# %%
wn.tracer(0)
episode=1

win = False
n_wins = 0
lose = False
moves = 0
global_moves = 0
seen = set()
print(px,py)
player.goto(px,py)
x,y=px,py
redraw_qs = False
reward=0
last_moves = 10
eps = 0.1
while True:
    min_Q = math.inf
    max_Q = -math.inf
#     if moves % 10 == 0:

    wn.update()
    
    if redraw_qs==True:
        redraw_qs==False
        stash = []
#         print("redrawing")
        for (sx,sy) in playable:            
            gx,gy = screen_to_grid(sx,sy)
            oh_xy = grid_to_onehot((gx,gy))    
            poss_mvs = target_model.predict(oh_xy.reshape(1,-1))[0]
            
            if max(poss_mvs) > max_Q:
                max_Q = max(poss_mvs)
            if min(poss_mvs) < min_Q:
                min_Q = min(poss_mvs)
            stash.append(((sx,sy), poss_mvs))
        for (((sx,sy), poss_mvs)) in stash:      
            if (sx,sy)==goal:
                continue
            if (sx,sy)==(x,y):
                continue
            colval = float((numpy.max(poss_mvs)-min_Q)/(max_Q-min_Q)) if (max_Q-min_Q) else 0.5
            trail.fillcolor(colval , 0,0 )
            trail.goto(sx,sy)
            if (sx,sy) in stampcache:
                trail.clearstamp( stampcache[(sx,sy)] )
            stampid = trail.stamp()
            stampcache[(sx,sy)] = stampid  
#         print("redrawn")


    
    x = (player.xcor())
    y = (player.ycor())
    s = grid_to_onehot(screen_to_grid(x,y)).reshape(1,24*24)

    R_sa = 0
    if random.random() < eps:
        mv = random.choice(mv_list)
        mv_ix = mv_list.index(mv)
#         print("{} by eps".format(mv))
    else:
        poss_mvs = model.predict(s)[0]
        mv_ix = numpy.argmax(poss_mvs)
        mv = mv_list[mv_ix]
#         print("{} from {}".format(mv,poss_mvs))

    if mv == "L":
        R_sa= player.go_left()
    elif mv == "R":
        R_sa= player.go_right()
    elif mv == "U":
        R_sa= player.go_up()
    elif mv == "D":
        R_sa= player.go_down()

    xn = (player.xcor())
    yn = (player.ycor())

    if (xn,yn) in seen:
        R_sa += -0.25
    else:
        seen.add((xn,yn))

    if (xn,yn) == goal:
        R_sa = 1.0
        win=True
    
#     print("R_sa=", R_sa)
    reward += R_sa
    
    moves+=1
    global_moves+=1
    if moves>=250:
        lose=True

    new_exp = [x,y, mv_ix, R_sa, xn,yn]
    exp_replay.append(new_exp)

    if moves % 1 == 0:
        cxs = numpy.random.choice(numpy.arange(len(exp_replay)), replace=False, size= min(20,len(exp_replay)))
        x_ohxy_list = []
        x_poss_move_list = []
        for cx in cxs:
            x,y, mv_ix, mvR, xn,yn = exp_replay[cx]
            oh_xy = grid_to_onehot(screen_to_grid(x,y)).reshape(1,-1)
            oh_xyn = grid_to_onehot(screen_to_grid(xn,yn)).reshape(1,-1)
            poss_mvs = target_model.predict(oh_xy)[0]
            if (xn,yn)==goal:
                Q_next = 0
            else:
                Q_next = max(target_model.predict(oh_xyn)[0])
            poss_mvs[mv_ix] =  mvR +(gamma*Q_next - poss_mvs[mv_ix])
            x_ohxy_list.append(oh_xy)
            x_poss_move_list.append(poss_mvs)
            
        model.fit( numpy.array(x_ohxy_list).reshape(-1,24*24), numpy.array(x_poss_move_list).reshape(-1,4), epochs=1, verbose=0, shuffle=True, callbacks=[es])

    if moves % 1 == 0:
        wgts = model.get_weights()
#         target_weights = self.target_model.get_weights()
#         for i in range(len(target_weights)):
#             target_weights[i] = weights[i]
        target_model.set_weights(wgts)
        redraw_qs=True
#         print("Update target; redraw")
        
#     print("rwd=",reward)
    
    if win or lose:
        if win:
            n_wins+=1
            if n_wins>10:
                eps = 0.01
            if n_wins>20:
                eps = 0.0
                
        print("mazes_run={}, moves_mz={}, rwd={}, wins={} | winrate={}".format(episode, moves, reward, n_wins, int(win)/moves))
        player.goto(px,py)
        win=False
        lose=False
        last_moves = moves
        moves=0
        episode+=1
        seen=set()
        reward = 0
# Out:
# -240 240
# mazes_run=1, moves_mz=250, rwd=-136.29000000000036, wins=0 | winrate=0.0
# mazes_run=2, moves_mz=250, rwd=-103.84000000000057, wins=0 | winrate=0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ac48173c39e2> in <module>
#      29             gx,gy = screen_to_grid(sx,sy)
#      30             oh_xy = grid_to_onehot((gx,gy))
# ---> 31             poss_mvs = target_model.predict(oh_xy.reshape(1,-1))[0]
#      32
#      33             if max(poss_mvs) > max_Q:
#
# ~/anaconda3/envs/mlc/lib/python3.7/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# ~/anaconda3/envs/mlc/lib/python3.7/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# ~/anaconda3/envs/mlc/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/envs/mlc/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/envs/mlc/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
