# %% [markdown]
# # Cambridge ML Commando Course

# %% [markdown]
# ## Session 2.2 Text Classification with Naïve Bayes

# %% [markdown]
# This notebook might not work properly without:
# jupyter notebook --NotebookApp.iopub_data_rate_limit=10000000
#
# _One of the most successful applications of Naïve Bayes has been within the field
# of Natural Language Processing (NLP). NLP is a field that has been much related
# to machine learning, since many of its problems can be formulated as a classification task. Usually, NLP problems have important amounts of tagged data in the form of text documents. This data can be used as a training dataset for machine
# learning algorithms.
# In this section, we will use Naïve Bayes for text classification; we will have a set of text documents with their corresponding categories, and we will train a Naïve Bayes algorithm to learn to predict the categories of new unseen instances. This simple task has many practical applications; probably the most known and widely used one is spam filtering. In this section we will try to classify newsgroup messages using a dataset that can be retrieved from within scikit-learn. This dataset consists of around 19,000 newsgroup messages from 20 different topics ranging from politics and religion to sports and science_

# %% [markdown]
# Start by importing numpy, scikit-learn, and pyplot, the Python libraries we will be using in this chapter. Show the versions we will be using (in case you have problems running the notebooks).

# %%
# %pylab inline
import IPython
import sklearn as sk
import numpy as np
from matplotlib import pyplot as plt
# print ('IPython version:', IPython.__version__)
# print ('numpy version:', np.__version__)
# print ('scikit-learn version:', sk.__version__)
# print ('matplotlib version:', matplotlib.__version__)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/rjm49/.venvs/isaac/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['clf']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# Import the newsgroup Dataset, and explore its structure and data (this could take some time, especially if sklearn has to download the 14MB dataset from the Internet).
#
# If we look at the properties of the dataset, we will find that we have the usual ones: DESCR, data, target, and target_names. The difference now is that data holds a list (of text items), instead of a numpy matrix:

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.model_selection import train_test_split

news = fetch_20newsgroups(subset='all')

X = news.data
y = news.target
y_labels = news.target_names

print(len(X), y.shape) # X is a list, y is a numpy array
for yt in set(y): print(yt, y_labels[yt])
    
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1, random_state=666)
# Out:
# 18846 (18846,)
# 0 alt.atheism
# 1 comp.graphics
# 2 comp.os.ms-windows.misc
# 3 comp.sys.ibm.pc.hardware
# 4 comp.sys.mac.hardware
# 5 comp.windows.x
# 6 misc.forsale
# 7 rec.autos
# 8 rec.motorcycles
# 9 rec.sport.baseball
# 10 rec.sport.hockey
# 11 sci.crypt
# 12 sci.electronics
# 13 sci.med
# 14 sci.space
# 15 soc.religion.christian
# 16 talk.politics.guns
# 17 talk.politics.mideast
# 18 talk.politics.misc
# 19 talk.religion.misc

# %% [markdown]
# If you look at a random instance, you will see the content of a newsgroup message, and you can get its corresponding category:

# %%
rand_ix = np.random.randint(0, len(news.data))
print (news.data[rand_ix])
category = news.target[rand_ix]
category_name = news.target_names[category]
print (category, category_name)
# Out:
# From: mam@mouse.cmhnet.org (Mike McAngus)
# Subject: Re: Christian Morality is
# Organization: The cat is on the mat
# X-Newsreader: TIN [version 1.1 PL9]
# Lines: 36
#
# On 20 Apr 93 13:38:34 GMT dps@nasa.kodak.com (Dan Schaertel,,,) wrote:
# >In article 11853@vice.ICO.TEK.COM, bobbe@vice.ICO.TEK.COM (Robert Beauchaine) writes:
# >|>
# >|>  Yet I am still not a believer.  Is god not concerned with my
# >|>  disposition?  Why is it beneath him to provide me with the
# >|>  evidence I would require to believe?  The evidence that my
# >|>  personality, given to me by this god, would find compelling?
#
# >The fact is God could cause you to believe anything He wants you to.
# >But think about it for a minute.  Would you rather have someone love
# >you because you made them love you, or because they wanted to
# >love you.     The responsibility is on you to love God and take a step toward
# >Him.  He promises to be there for you, but you have to look for yourself.
# >Those who doubt this or dispute it have not givin it a sincere effort.
#
# I and many others on a.a have described how we have tried to find god.
# Are you saying our efforts have not been sincere?  For all the effort
# I have put in, there has been no outward nor inward change that I can
# perceive.  What's a sincerely searching Agnostic or Atheist supposed to
# do when even the search turns up nothing?
#
# >Simple logic arguments are folly.  If you read the Bible you will see
# >that Jesus made fools of those who tried to trick him with "logic".
# >Our ability to reason is just a spec of creation.  Yet some think it is
# >the ultimate.  If you rely simply on your reason then you will never
# >know more than you do now.   To learn you must accept that which
# >you don't know.
#
# How do you "accept that which you don't know"?  Do you mean that I must
# believe in your god in order to believe in your god?
#
# --
# Mike McAngus         | The Truth is still the Truth
# mam@mouse.cmhnet.org | Even if you choose to ignore it.
#                      |
# (Some of the old .sig viruses are still the best)
#
# 0 alt.atheism

# %% [markdown]
# This function will serve to perform and evaluate a cross validation:

# %%
from sklearn.model_selection import cross_val_score, KFold
from scipy.stats import sem

def evaluate_cross_validation(clf, X, y, K):
    # create a k-fold croos validation iterator of k=5 folds
    print("underway...")
    k_cv = KFold(n_splits=K, shuffle=True, random_state=0)
    # by default the score used is the one returned by score method of the estimator (accuracy)
    scores = cross_val_score(clf, X, y, cv=k_cv)
    print (scores)
    print (("Mean score: {0:.3f} (+/-{1:.3f})").format(
        np.mean(scores), sem(scores)))

# %% [markdown]
# Our machine learning algorithms can work only on numeric data...
#
# Inside the `sklearn.feature_extraction.text` module, there are three classes that can transform text into numeric features: `CountVectorizer`, `HashingVectorizer`, and `TfidfVectorizer`.
# The difference between them resides in the calculations they perform to derive the numeric features:
# - `CountVectorizer` basically creates a dictionary of words from the corpus. Then, each instance is converted to a vector of numeric features where each element will be the frequency of each word in the document.
# - `HashingVectorizer`, instead of constructing and maintaining the dictionary in memory, implements a hashing function that maps tokens into feature indexes, and then computes the count as in CountVectorizer. (Sadly seems intentionally broken at the time of writing!)
# - `TfidfVectorizer` works like CountVectorizer, with a more advanced calculation called "Term Frequency - Inverse Document Frequency" (TF-IDF). This is a statistic for measuring the importance of a word in a document or corpus. Intuitively, it looks for words that are more frequent in the current document, compared with their frequency across all documents. You can see this as a way to normalize the results and avoid words that are too frequent, and thus not useful to characterise the instances.
#
# We will create a Naïve Bayes classifier that is composed of a feature vectorizer and the actual Bayes classifier. We will use the MultinomialNB class from the `sklearn.naive_bayes` module.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer, HashingVectorizer, CountVectorizer

corpus = [
    'This is the first document.',
    'This is the second second document.',
    'And the third one.',
    'Is this the first document?',
    ]
cv = CountVectorizer()
txd = cv.fit_transform(corpus)
print("\n")
print(txd)

# hv = HashingVectorizer(alternate_sign=False, norm='l2')
# txd = hv.fit_transform(corpus)
# print("\n")
# print(txd)

# tv = TfidfVectorizer()
# txd = tv.fit_transform(corpus)
# print("\n")
# print(txd)


clf_1 = Pipeline([
    ('vect', CountVectorizer()),
    ('clf', MultinomialNB()),
])
# clf_2 = Pipeline([
#     ('vect', HashingVectorizer(alternate_sign=False)),
#     ('clf', MultinomialNB()),
# ])
# clf_3 = Pipeline([
#     ('vect', TfidfVectorizer()),
#     ('clf', MultinomialNB()),
# ])
# Out:
#   (0, 8)	1
#   (0, 3)	1
#   (0, 6)	1
#   (0, 2)	1
#   (0, 1)	1
#   (1, 8)	1
#   (1, 3)	1
#   (1, 6)	1
#   (1, 1)	1
#   (1, 5)	2
#   (2, 6)	1
#   (2, 0)	1
#   (2, 7)	1
#   (2, 4)	1
#   (3, 8)	1
#   (3, 3)	1
#   (3, 6)	1
#   (3, 2)	1
#   (3, 1)	1

# %%
clfs = [clf_1, ]#, clf_2, clf_3]
for clf in clfs:
    print("for clf {}".format(clf))
    evaluate_cross_validation(clf, X_train, y_train, 5)
# Out:
# for clf Pipeline(steps=[('vect', CountVectorizer()), ('clf', MultinomialNB())])
# underway...
# [0.85411141 0.85642689 0.84316038 0.83726415 0.85023585]
# Mean score: 0.848 (+/-0.004)

# %% [markdown]
# We will keep the TF-IDF vectorizer but use a different regular expression to perform tokenization. The default regular expression: "\w\w+" considers alphanumeric characters and the underscore. Perhaps also considering the slash and the dot could improve the tokenization, and begin considering tokens as Wi-Fi and site.com. The new regular expression could be: "[a-z0-9_\-\.]+[a-z][a-z0-9_\-\.]+". If you have queries about how to define regular expressions, please refer to the Python re module documentation. Let's try our new classifier:

# %%
clf_4 = Pipeline([
    ('vect', TfidfVectorizer(
                token_pattern="[a-z0-9_\-\.]+[a-z][a-z0-9_\-\.]+",
    )),
    ('clf', MultinomialNB()),
])

# %%
print(news.data)

evaluate_cross_validation(clf_4, X_train, y_train, 5)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [0.8697318  0.87116745 0.85023585 0.85613208 0.85347877]
# Mean score: 0.860 (+/-0.004)

# %% [markdown]
# Another parameter that we can use is stop_words: this argument allows us to pass a list of words we do not want to take into account, such as too frequent words, or words we do not a priori expect to provide information about the particular topic. Let's try to improve performance filtering the stop words:

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = stopwords.words('english')
sk_stop_words = CountVectorizer(stop_words="english").get_stop_words()

print("NLTK STOPWORDS ({}):\n{}".format(len(stop_words),stop_words))
print("\nSKLEARN STOPWORDS ({}):\n{}".format(len(sk_stop_words),sk_stop_words))

combined_stop_words = set(stop_words).union(set(sk_stop_words))
print("\nCombined stop words ({}):\n{}".format(len(combined_stop_words), combined_stop_words))
# Out:
# [nltk_data] Downloading package stopwords to /home/rjm49/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# NLTK STOPWORDS (179):
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
#
# SKLEARN STOPWORDS (318):
# frozenset({'even', 'more', 'being', 'been', 'in', 'front', 'much', 'to', 'while', 'many', 'be', 'perhaps', 'was', 'nowhere', 'anyone', 'own', 'through', 'about', 'whereafter', 'side', 'well', 'neither', 'why', 'now', 'up', 'find', 'serious', 'none', 'ourselves', 'behind', 'though', 'five', 'first', 'along', 'both', 'i', 'yet', 'at', 'those', 'themselves', 'bill', 'wherein', 'his', 'have', 'its', 'itself', 'mine', 'seemed', 'whole', 'under', 'whether', 'would', 'eight', 'take', 'via', 'so', 'back', 'if', 'above', 'namely', 'thereafter', 'latter', 'where', 'un', 'whither', 'among', 'seems', 'together', 'yours', 'us', 'sincere', 'no', 'as', 'everything', 'hereafter', 'however', 'for', 'again', 'himself', 'this', 'several', 'describe', 'everyone', 'except', 'whom', 'few', 'indeed', 'six', 'must', 'hers', 'anywhere', 'not', 'whence', 'thence', 'with', 'whereby', 'keep', 'done', 'you', 'hence', 'top', 'by', 'twenty', 'move', 'least', 'may', 'detail', 'each', 'nevertheless', 'seeming', 'eg', 'already', 'four', 'inc', 'should', 'they', 'third', 'less', 'although', 'found', 'out', 'yourself', 'next', 'beforehand', 'whoever', 'fifteen', 'over', 'will', 'becomes', 'amongst', 'most', 'therefore', 'it', 'nor', 'last', 'therein', 'part', 'call', 'what', 'former', 'because', 'co', 'moreover', 'but', 'him', 'me', 'very', 'herself', 'else', 'all', 'system', 'beside', 'are', 'he', 'off', 'please', 'often', 'show', 'then', 'couldnt', 'anyhow', 'others', 'when', 'from', 'enough', 'fifty', 'wherever', 'full', 'across', 'hereupon', 'one', 'noone', 'go', 'thru', 'other', 'due', 'which', 'than', 'here', 'ten', 'into', 'these', 'formerly', 'always', 'alone', 'hasnt', 'yourselves', 'same', 'before', 'ours', 'de', 'of', 'put', 'do', 'besides', 'is', 'rather', 'somehow', 'still', 'another', 'con', 'anyway', 'our', 'sixty', 'made', 'against', 'during', 'either', 'a', 'per', 'between', 'latterly', 'might', 'thereby', 'whenever', 'three', 'who', 'everywhere', 'every', 'without', 'meanwhile', 'empty', 'towards', 'were', 'down', 'etc', 'ltd', 'their', 'bottom', 'since', 'sometimes', 'whatever', 'whereas', 'ever', 'upon', 'nine', 'nothing', 'became', 'onto', 'ie', 'the', 'toward', 'twelve', 'within', 'them', 'your', 'herein', 'thereupon', 'thin', 'how', 'on', 'only', 'name', 'my', 'somewhere', 'can', 'cannot', 'hundred', 'amoungst', 'below', 'becoming', 'almost', 'an', 'could', 'eleven', 'hereby', 'interest', 'mill', 'myself', 'someone', 'that', 'thus', 'anything', 'such', 'am', 'forty', 'amount', 'become', 'there', 'give', 'she', 'or', 'elsewhere', 'nobody', 'cry', 'mostly', 'seem', 'fire', 'two', 'afterwards', 'we', 'get', 'whereupon', 'until', 'some', 'sometime', 'throughout', 'and', 'beyond', 'after', 'had', 'has', 'once', 'cant', 'otherwise', 'further', 'her', 'also', 'whose', 'see', 'thick', 'never', 'too', 'fill', 'something', 'around', 'any', 're'})
#
# Combined stop words (378):
# {'having', "she's", 'be', 'was', 'nowhere', "shouldn't", 'side', 'now', 'up', 'serious', 'none', 'ourselves', 'behind', 'hasn', 'first', 'yet', 'at', 'those', 'themselves', 'wherein', 'itself', 'have', 'mine', 'eight', 'via', "that'll", 'so', 'back', 'if', 'namely', 'latter', "aren't", 'where', 'yours', 'un', 'whither', 'seems', 'us', 'as', 'however', "hasn't", 'for', 'wasn', 'himself', 'this', 'don', 'ain', 'few', 'indeed', 'must', 'hers', 'not', 'with', 'anywhere', 'whence', 'thence', 'whereby', 't', 'keep', 'done', 'hence', 'top', 'move', 'least', 'aren', 'weren', 'may', "mustn't", 'detail', 'nevertheless', 'seeming', 'although', 'didn', 'will', 'over', 'whoever', 'becomes', 'hadn', 'most', 'amongst', 'it', 'm', 'part', "should've", 'co', 'very', 'me', 'herself', 'else', 'all', 'system', 'please', 'are', 'then', 'anyhow', 'others', 'from', 'fifty', 'one', 'ma', 'does', 'noone', 'other', "you'll", 'due', 'which', 'couldn', 'here', 'into', 'formerly', 'always', 'alone', 'hasnt', 'same', 'whole', 'rather', 'of', 'besides', 'is', 'our', "you've", 'against', 'during', 'either', 'per', 'who', 'latterly', 'might', 'whenever', 'three', 'every', 'meanwhile', 'empty', 'were', 'down', 'etc', 'their', 'bottom', 'doing', "couldn't", 'whereas', 'ever', 'onto', 'the', 'became', 'within', 'y', 'thereupon', 'thin', 'how', 'on', 'name', "wasn't", 'just', 'somewhere', 'hundred', "doesn't", 'she', 'mustn', 'could', 'becoming', 'that', 'almost', 'thus', 'hereby', 'eleven', 'someone', 'such', 'anything', 'forty', 's', 'amount', 'become', 'o', 'give', 'or', "shan't", 'elsewhere', 'nobody', 'mostly', 'wouldn', 'seem', 'fire', 'two', 'get', 'sometime', 'has', 'had', 'mightn', "you'd", 'once', 'otherwise', 'further', 'whose', 'see', 'too', 'thick', 'never', 'fill', 'something', 'around', 're', 'even', 'more', 'being', 'been', 'in', 'front', 'to', 'much', 'while', 'many', 'perhaps', 'd', 'anyone', 'own', 'about', 'whereafter', 'well', 'neither', 'why', 'find', 'though', "you're", 'five', 'along', 'both', 'i', "didn't", 'whom', 'bill', 'his', 'its', 'seemed', "wouldn't", 'under', 'would', 'take', 'above', 'thereafter', 'among', 'together', 'sincere', 'no', "mightn't", 'won', 'did', 'hereafter', 'everything', 'again', "won't", 'several', 'describe', 'everyone', 'll', "isn't", 'except', 'six', 'you', 'twenty', 'by', 'third', 'each', 'should', 'they', 'eg', 'already', 'four', 'inc', 'yourself', 'out', 'less', 'found', 'next', 'beforehand', 'fifteen', 'therefore', 'nor', 'last', 'therein', 'what', 'call', 'former', 'because', 'moreover', 'but', 'him', 'he', 'off', 've', 'beside', 'often', 'show', 'couldnt', 'when', 'enough', 'wherever', 'full', 'across', 'hereupon', 'thru', 'go', 'than', 'ten', 'these', 'before', 'ours', 'de', 'put', 'do', 'still', 'somehow', 'another', 'theirs', 'con', 'anyway', 'sixty', 'shouldn', 'made', 'a', 'between', 'thereby', 'without', 'everywhere', 'towards', 'ltd', 'since', "don't", 'sometimes', 'whatever', 'upon', 'nine', 'nothing', 'twelve', 'your', 'ie', 'toward', 'them', 'haven', 'herein', 'only', 'my', 'can', 'cannot', 'amoungst', 'below', "needn't", 'an', "haven't", 'shan', 'interest', 'myself', 'whether', 'mill', 'am', 'there', 'we', 'cry', 'afterwards', 'whereupon', 'isn', 'until', "hadn't", 'some', 'doesn', 'needn', 'throughout', 'and', 'beyond', 'after', "weren't", 'cant', 'her', 'also', "it's", 'through', 'yourselves', 'any'}

# %%
clf_5 = Pipeline([
    ('vect', TfidfVectorizer(
                stop_words = combined_stop_words,
                token_pattern='[a-z0-9_\-\.]+[a-z][a-z0-9_\-\.]+',    
    )),
    ('clf', MultinomialNB()),
])

# %%
evaluate_cross_validation(clf_5, X_train, y_train, 5)
# Out:
# underway...
# [0.88977306 0.8932783  0.88266509 0.88295991 0.88060142]
# Mean score: 0.886 (+/-0.002)

# %% [markdown]
# Try to improve the classification.  Change the max number of features, the smoothing (alpha) parameter on the MultinomialNB classifier:

# %%
from sklearn.linear_model import LogisticRegression, SGDClassifier
clf_7 = Pipeline([
    ('vect', TfidfVectorizer(
                max_features=None,
                stop_words=combined_stop_words,
                token_pattern="[a-z0-9_\-\.]+[a-z][a-z0-9_\-\.]+",         
    )),
    ('clf', MultinomialNB(alpha=0.01)),
])

clf_8 = Pipeline([
    ('vect', TfidfVectorizer(
#                 max_features=25000,
                stop_words=combined_stop_words,
                token_pattern="[a-z0-9_\-\.]+[a-z][a-z0-9_\-\.]+",         
    )),
    ('clf', SGDClassifier()),
])

# %%
# evaluate_cross_validation(clf_7, X_train, y_train, 5)
evaluate_cross_validation(clf_8, X_train, y_train, 5)
# Out:
# underway...
# [0.92838196 0.9245283  0.92629717 0.91627358 0.9271816 ]
# Mean score: 0.925 (+/-0.002)

# %% [markdown]
# At this point, we could continue doing trials by using different values of alpha or doing new modifications of the vectorizer.

# %% [markdown]
# If we decide that we have made enough improvements in our model, we are ready to evaluate its performance on the testing set.

# %%
# correlation_matrix = numpy.corrcoef(X_train_boston.T, y_train_boston)
from sklearn.preprocessing import minmax_scale
def plot_matrix(mx, title="Some Matrix", features = None):
    fig, ax = plt.subplots()
    
    im = ax.imshow(minmax_scale(mx))

    # # We want to show all ticks...
#     ax.set_xticks(np.arange(len(boston.data.T)+1))
#     ax.set_yticks(np.arange(len(boston.data.T)+1))
    if features is not None:
        ax.set_xticks(np.arange(len(features)))
        ax.set_yticks(np.arange(len(features)))

        # # ... and label them with the respective list entries
        ax.set_xticklabels(features)
        ax.set_yticklabels(features)

        # Rotate the tick labels and set their alignment.
        plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
                 rotation_mode="anchor")

#     Loop over data dimensions and create text annotations.
    for i in range(len(mx)):
        for j in range(len(mx)):
            text = ax.text(j, i, round(mx[i, j],1),
                           ha="center", va="center", color="w")

    ax.set_title(title)
    # fig.tight_layout()
    fig.set_size_inches(6,6)
    plt.show()

# %%
from sklearn import metrics

def train_and_evaluate(clf, X_train, X_test, y_train, y_test):
    plt.set_cmap("jet")
    clf.fit(X_train, y_train)
    
    print ("Accuracy on training set:")
    print (clf.score(X_train, y_train))
    print ("Accuracy on testing set:")
    print (clf.score(X_test, y_test))
    
    y_pred = clf.predict(X_test)
    
    print ("Classification Report:")
    print (metrics.classification_report(y_test, y_pred))
    print ("Confusion Matrix:")
#     print (metrics.confusion_matrix(y_test, y_pred))
    mx = metrics.confusion_matrix(y_test, y_pred)
    plot_matrix(mx, title="Text Classif'n Confusion Mx", features = [y_labels[yt] for yt in range(20)])

# %%
train_and_evaluate(clf_8, X_train, X_test, y_train, y_test)
# Out:
# Accuracy on training set:
# 0.9905665939508284
# Accuracy on testing set:
# 0.9177718832891246
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88        93
#            1       0.87      0.83      0.85       100
#            2       0.82      0.93      0.87       112
#            3       0.90      0.82      0.86       108
#            4       0.88      0.86      0.87        80
#            5       0.91      0.86      0.88       100
#            6       0.85      0.92      0.88        95
#            7       0.94      0.93      0.93       107
#            8       0.94      0.99      0.96        95
#            9       0.99      0.96      0.97        75
#           10       0.97      1.00      0.98        86
#           11       0.98      0.98      0.98       106
#           12       0.91      0.87      0.89       101
#           13       0.92      0.97      0.94       102
#           14       0.90      0.95      0.92        99
#           15       0.92      0.97      0.94        92
#           16       0.97      0.98      0.98       108
#           17       0.97      0.99      0.98        92
#           18       0.99      0.88      0.93        76
#           19       0.89      0.72      0.80        58
#
#     accuracy                           0.92      1885
#    macro avg       0.92      0.91      0.92      1885
# weighted avg       0.92      0.92      0.92      1885
#
# Confusion Matrix:

# %% [markdown]
# As we can see, we obtained very good results, and as we would expect, the accuracy in the training set is quite better than in the testing set. We may expect, in new unseen instances, an accuracy of around 0.91.
#
# If we look inside the vectorizer, we can see which tokens have been used to create our dictionary:

# %%
len(clf_8.named_steps['vect'].get_feature_names())
# Out:
# 200911

# %%
# print(len(clf_7.named_steps['vect'].get_feature_names()))

# %% [markdown]
# ## Feeling keen?
# The NLTK code below will extract named entities from the documents.  Can you use these to drive the classifier?  Does it work better, worse?  Why do you think?

# %%
import nltk
from nltk import ne_chunk, tokenize, PorterStemmer
nltk.download('treebank')
nltk.download('maxent_ne_chunker')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('words')

entities_per_doc = [] # the i-th element gives a summary of the named entities found in the i-th document
doc_n=0
print(len(news.data))
for doc in news.data:# nltk.corpus.treebank.tagged_sents():
    doc_entities = []
    doc = nltk.sent_tokenize(doc)
    doc = [nltk.wordpunct_tokenize(sent) for sent in doc]
    doc = [nltk.pos_tag(sent) for sent in doc]
    for s in doc:        
        chunx = ne_chunk(s, binary=True)
        for chunk in chunx:
            if hasattr(chunk, 'label'):
                doc_entities.extend([c[0] for c in chunk])
    print(doc_entities)
    entities_per_doc.append(" ".join(doc_entities))
# Out:
# [nltk_data] Downloading package treebank to /home/rjm49/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/rjm49/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package punkt to /home/rjm49/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/rjm49/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package words to /home/rjm49/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# 18846
# ['Carnegie', 'Mellon', 'Pittsburgh', 'PA', 'Lines', 'NNTP', 'Devils', 'PIttsburghers', 'Pens', 'Man', 'Jagr', 'Bowman', 'JAgr', 'Jersey', 'PENS', 'RULE']
# ['Matthew', 'Which', 'VLB', 'VLB', 'Nntp', 'University', 'Oklahoma', 'Norman', 'OK', 'USA', 'Keywords', 'VESA', 'Does', 'Diamond', 'Stealth', 'Pro', 'Local', 'Bus', 'Orchid', 'ATI', 'Graphics', 'Ultra', 'Pro', 'VLB', 'Lawson', 'Nebuchadnezzar', 'Nebuchadnezzar', 'Babylon']
# ['Hilmi', 'Eren', 'ARMENIA', 'TURKISH', 'Henrik', 'Nntp', 'Reply', 'Hilmi', 'Eren', 'Computer', 'Systems', 'Sciences', 'Stockholm', 'University', 'Davidian', 'Davidian', 'Karabakh', 'Black', 'Sea', 'Mediterranean', 'Mediterranean', 'Azeris', 'Karabakh', 'Azerbaijan', 'Elchibey', 'Lake', 'Sevan', 'July', 'USA', 'Elchibey', 'Karabakh', 'Aghdam', 'Elchibey', 'Karabakh', 'Fizuli', 'Armenia', 'THE', 'MENTIONED', 'IS', 'TRUE', 'BUT', 'TRUE', 'SHALL', 'AZERI', 'WOMEN', 'AND', 'CHILDREN', 'THE', 'KILLED', 'TORTURED', 'ARMENIANS', 'HAVE', 'GENEVA', 'YOU', 'FACIST', 'Ohhh', 'Kurds', 'Turks', 'Ankara', 'Armenia', 'Iran', 'Armenian', 'New', 'York', 'Times', 'Armenian', 'Azeri', 'Turkish', 'Baku', 'Real', 'Ohhhh', 'RedCross', 'Search', 'Turkish', 'Ozal', 'Azerbaijan', 'Turkey', 'Search', 'Turkish', 'Turkey', 'Azerbadjan', 'Armenia', 'Karabag', 'Azeris', 'Armenians', 'Azerbadjan', 'Turkish', 'Nice', 'Shoot', 'Armenian', 'Russian', 'Hilmi', 'Eren', 'Stockholm', 'University']
# ['Guy', 'Dawson', 'SCSI', 'DMA', 'IBM', 'Austin', 'Lines', 'Wayne', 'Smith', 'Richard', 'Krehbiel', 'OS', 'SCSI', 'CD', 'ROM', 'DMA', 'CPU', 'CPU', 'SCSI', 'DMA', 'ISA', 'IBM', 'CPU', 'ISA', 'SCSI', 'SCSI', 'ISA', 'Think', 'SCSI', 'DMA', 'SCSI', 'DMA', 'SCSI', 'SCSI', 'SCSI', 'IBM', 'FDD', 'System', 'Board', 'DMA', 'PC', 'FDD', 'DMA', 'PC', 'Dawson', 'Hoskyns', 'Group', 'Plc', 'Tel', 'Hoskyns', 'UK', 'Tel', 'USA']
# ['Alexander', 'Samuel', 'Organization', 'Mechanical', 'Engineering', 'Carnegie', 'Mellon', 'Pittsburgh', 'PA', 'Lines', 'NNTP', 'Jasmine']
# ['Stephen', 'Tell', 'University', 'North', 'Carolina', 'Chapel', 'Hill', 'Lines', 'NNTP', 'COM', 'COM', 'Bob', 'Myers', 'Might', 'Bell', 'Labs', 'Bob', 'Myers', 'Steve', 'Steve', 'Tell', 'Park', 'UNC', 'Chapel', 'Hill', 'Computer', 'Science', 'Carrboro', 'Hitchhiker', 'Galaxy']
# ['Louis', 'Paul', 'Adams', 'Applied', 'Engineering', 'Organization', 'College', 'Station', 'NNTP', 'Applied', 'Engineering', 'AE', 'Dallas', 'Tech', 'Good']
# ['Deepak', 'Chhabra', 'Atlanta', 'Hockey', 'Hell', 'Nntp', 'ISTS', 'Lines', 'Mamatha', 'Devineni', 'Ratnam', 'ABC', 'Move', 'Canada', 'NJ', 'PITT', 'ABC', 'LA', 'CAL', 'CBC', 'BUFF', 'BOS', 'TSN', 'FOX', 'MON', 'QUE', 'CBC', 'MON', 'QUE', 'BOS', 'BUFF', 'Btw', 'IMO']
# ['Deepak', 'Chhabra', 'Nntp', 'ISTS', 'Lines', 'EG8', 'Valerie', 'Fuhr', 'Sabres', 'Bruin', 'Sabre', 'Fuhr']
# ['Ken', 'Arromdee', 'Johns', 'Hopkins', 'University', 'CS', 'Dept', 'E4z', 'Jesus', 'Christian', 'Christian', 'Jesus', 'Jesus', 'Christian', 'Turkey', 'Casserole', 'Leftover', 'Turkey', 'Turkey', 'Wings', 'Ken', 'Arromdee']
# ['Kent', 'Sandvik', 'Please', 'Endangered', 'Species', 'List', 'Hmm', 'Kent', 'ALink', 'KSAND']
# ['Steve', 'Brinich', 'Clipper', 'Initiative', 'Greenbelt', 'MD', 'USA', 'Lines', 'NNTP']
# ['Thyagi', 'Thyagi', 'Morgoth', 'Oriental', 'Templars', 'Organization', 'Portal', 'System', 'Honestly', 'Sin', 'Hymenaeus', 'Beta', 'Frater', 'Superior', 'Merlinus', 'Reuss', 'Karl', 'Kellner', 'Austrian', 'Mason', 'Ordo', 'Templi', 'Orientis', 'Kellner', 'East', 'Kellner', 'Franz', 'Hartmann', 'Heinrich', 'Klein', 'Order', 'Reuss', 'Masonic', 'Kellner', 'Reuss', 'Outer', 'Head', 'Jubilee', 'Order', 'Born', 'Augsburg', 'Masonry', 'Prussian', 'Socialist', 'League', 'Karl', 'Marx', 'Reuss', 'William', 'Wynn', 'Westcott', 'Golden', 'Dawn', 'John', 'Yarker', 'Yarker', 'Reuss', 'Mizraim', 'Germany', 'Masonic', 'Rites', 'Reuss', 'Order', 'Reuss', 'Papus', 'France', 'Rudolph', 'Steiner', 'Berlin', 'USA', 'Reuss', 'Crowley', 'Crowley', 'Reuss', 'Crowley', 'Reuss', 'Crowley', 'Supreme', 'Holy', 'King', 'English', 'Equinox', 'Reuss', 'Outer', 'Head', '_The', 'Book', 'Law_', 'German', 'Manyk', 'Crowley', 'Reuss', 'New', 'Aeon', '_An', 'Introduction', 'Hymenaeus', 'Beta', 'Frater', 'Superior', 'Rex', 'Summus', 'Sanctissimus', 'Caliph', 'United', 'States', 'America', 'Samuel', 'Weiser', '_Equinox', 'Will', 'Masonry', 'Caliph', 'OTO', 'Merlinus', 'Please', 'Reuss', 'Order', 'Ordo', 'Templi', 'Orientis', 'Order', 'Hymenaeus', 'Beta', 'Gnostic', 'Mass', 'Merlinus', 'Love', 'Frater', 'Nigris', 'DCLXVI']
# ['VINCI', 'Krillean', 'Photography', 'News', 'European', 'Organization', 'Nuclear', 'Research', 'CERN', 'Lines', 'Joseph', 'Francis', 'Brian', 'Kirlian', 'FAQ', 'Filipe', 'Santos', 'CERN', 'European', 'Laboratory', 'Particle', 'Physics', 'Switzerland']
# ['CWRU', 'Keith', 'Scientific', 'Predictions', 'Atheism', 'Western', 'Reserve', 'University', 'Lines', 'NNTP', 'Fred', 'Rice', 'Qur']
# ['David', 'Davidian', 'Adriatic', 'Sea', 'Great', 'Wall', 'China', 'Center', 'Regional', 'Studies', 'Lines', '_Turkey', 'Eyes', 'Regional', 'Role_', 'ANKARA', 'Turkey', 'AP', 'Turanist', 'Ozal', 'Turanist', 'Turkish', 'Turanist', 'Turkic', 'Adriatic', 'Great', 'Wall', 'China', 'Turkic', 'Empire', 'Balkans', 'Caucasus', 'Turkey', 'Turkey', 'Grey', 'Wolf', 'Teeth', 'Adriatic', 'China', 'Turkey', 'David', 'Davidian', 'Armenia', 'Center', 'Regional', 'Studies', 'Turkish', 'Turgut', 'Ozal']
# ['UPDATE', 'Organization', 'University', 'Warwick', 'UK', 'Lines', 'NNTP', 'BBC', 'Rec', 'JVC', 'Michael', 'Brown']
# ['Lead', 'Acid', 'Nntp', 'Adelphi', 'University', 'Garden', 'City', 'NY', 'MATGBB', 'LATROBE', 'BYRNES', 'Graham', 'WD', 'Explosive', 'WD', 'Honda', 'Graham', 'WD40', 'John', 'Schmidt', 'WBAU', 'Adelphi', 'University', 'Garden', 'City', 'New', 'York']
# ['Perry', 'White', 'House', 'America', 'Free', 'Drug', 'Robert', 'Ward', 'US', 'American', 'American', 'Supreme', 'Court', 'Second', 'Amendment', 'Arms', 'Supreme', 'Court', 'Uerdugo', 'Uriquidez', 'Miller', 'Second', 'United', 'States', 'Subcommittee', 'Committee', 'United', 'States', 'Senate', 'Second', 'Session', 'Militia', 'Supreme', 'Court', 'United', 'States', 'Miller', 'Thomas', 'Jefferson', 'Proposal', 'Virginia', 'Constitution', 'Ed', 'Thomas', 'Jefferson', 'William', 'Smith', 'Jefferson', 'Europe', 'America', 'United', 'States', 'Noah', 'Webster', 'Pamphlets', 'United', 'States', 'Perry', 'Metzger', 'Le']
# ['Mike', 'Sixsmith', 'East', 'Anglia', 'Lines', 'Green', 'Pixel', 'Cruncher', 'Mike', 'Sixsmith', 'BMF', 'Don']
# ['Chevy', 'Opinions', 'Hewlett', 'Packard', 'Idaho', 'TIN', 'NH', 'USA', 'BBB', 'Chevrolet', 'Chevrolet', 'RPM', 'Chevrolet']
# ['Carl', 'Schmidtmann', 'STOP', 'Nntp', 'Inc', 'Distribution', 'Mike', 'Hoswell', 'Resources', 'Sorry', 'ICCCM', 'CONTROL', 'ICCCM', 'Mike', 'Mike', 'Hoswell', 'Bagels', 'Global', 'Dynamics', 'PO', 'Box', 'Boulder', 'CO', '_______________________________________________________________________________', 'Carl', 'Schmidtmann', 'Faultline', 'Software', 'Group', 'Inc']
# ['Milan', 'University', 'Lines', 'Imagine', 'Amiga', 'Amiga', 'Bit', 'Riccione', 'Italy', 'Italian', 'Computer', 'Graphics', 'Contest', 'SoftImage', 'Silicon', 'Graphics', 'Imagine', 'Amiga', 'VERY', 'Sorry', 'Activa', 'International', 'Amiga', 'PC', 'MS', 'Silicon', 'Indigo', 'Unix', 'Ciao', 'Sergio', 'Sergio', 'Ruocco']
# ['Jody', 'Levine', 'Near', 'Hit', 'Organization', 'Hydro', 'Research', 'Division', 'EDU', 'Jetta', 'Levine', 'Ontario', 'Canada']
# ['SHAWN', 'LUDDINGTON', 'NHL', 'Draft', 'Organization', 'Toronto', 'Canada', 'Lines', 'MAINE', 'MAINE', 'EDU', 'MAINE', 'EDU', 'NFL', 'ESPN', 'Paul', 'Kariya', 'TSN', 'ESPN', 'Ottawa', 'Alexander', 'Daigle', 'Montreal', 'Quebec', 'Kariya', 'NCAA', 'Daigle', 'San', 'Jose', 'Kariya', 'Tampa', 'Bay', 'Chris', 'Gratton', 'Chris', 'Pridham', 'Draft', 'Order', 'San', 'Tampa', 'Bay', 'South', 'Florida', 'South', 'Florida', 'Kariya', 'Shawn', 'THANKS', 'ST', 'LOUIS', 'RON', 'CARON', 'SCOTT']
# ['Manned', 'Lunar', 'Exploration', 'Crystal', 'City', 'Greenbelt', 'MD', 'USA', 'Lines', 'NNTP', 'ST', 'Lunar', 'Exploration', 'Crystal', 'City', 'Virginia', 'AIAA', 'Does', 'Anyone']
# ['Ken', 'Mcvay', 'Old', 'Frog', 'Almanac', 'Canadian', 'UPI', 'FBI', 'Koresh', 'Coincidence', 'Hear', 'Old', 'Frog', 'Almanac', 'Ryugen', 'Fisher', 'British', 'Columbia', 'CANADA', 'Central', 'Vancouver', 'Island', 'UseNet']
# ['Geoffrey', 'Hansen', 'MIND', 'LINK', 'British', 'Columbia', 'Canada', 'Lines', 'VMODE', 'VMODE', 'VESA', 'VMODE', 'VESA']
# ['Jason', 'Weitek', 'ET4k', 'IDE', 'Organization', 'Texas', 'NNTP', 'Sale', 'G486PLB', 'Local', 'Bus', 'Motherboard', 'SIMMS', 'Host4000', 'Local', 'Bus', 'ET4000', 'Video', 'Card', 'Tseng', 'Labs', 'ET4000', 'RAMDAC', 'CGA', 'EGA', 'VGA', 'MDA', 'Software', 'Symphony', 'Autocad', 'Autoshade', 'Windows', 'Wordperfect', 'VESA', 'Floppy', 'Disk', 'Parallel', 'AutoCad', 'Local', 'Bus', 'Weitek', 'VERY', 'CAD', 'Weitek', 'Autocad', 'Jason', 'Tobias']
# ['Organization', 'John', 'Johnson', 'Christian', 'Morality', 'Frank', 'Sorry', 'John', 'Johnson', 'J5J', 'Psychology', 'Penn', 'State', 'DuBois', 'Campus']
# ['Organization', 'Anybody', 'Honda', 'Civic', 'Toyota', 'Tercels', 'Boyd', 'Johnson', 'San', 'Diego', 'California']
# ['David', 'Feustel', 'Organization', 'Waco', 'Dave', 'Feustel']
# ['UUCP', 'William', 'Steer', 'Organization', 'Windows', 'NT', 'Bill', 'Steer', 'Westinghouse']
# ['Organization', 'Washington', 'University', 'Mark', 'Kornbluh', 'NETNEWS', 'Mike', 'Silverman', 'Lankford', 'Ray', 'Lankford', 'Cards', 'Mark', 'Kornbluh']
# ['Melissa', 'ME', 'Virginia', 'Public', 'Education', 'Network', 'Radford', 'Sumatriptin', 'Doesn']
# ['UC525655', 'Eaton', 'IIsi', 'Nntp', 'Missouri', 'Lines', 'Mac', 'IIsi', 'Personal', 'IIsi', 'IIsi', 'Mark']
# ['Brian', 'V', 'Reply', 'Dartmouth', 'Dartmouth', 'College', 'Hanover', 'NH', 'Disclaimer', 'Moderator', 'Info', 'Lines', 'Digital', 'Eclipse', 'Someone', 'DESI', 'MacWEEK', 'Digital', 'Eclipse', 'DESI']
# ['ACME', 'Products', 'Lines', 'AA08789', 'US', 'Blue', 'Cross', 'Massachusetts', 'Canada', 'Blue', 'Cross', 'Earth', 'Sean', '_The', 'White', 'Plague_', 'Frank', 'Herbert']
# ['Nick', 'Pettefar', 'Nntp', 'Maidenhead', 'UK', 'TIN', 'David', 'Karr', 'Russell', 'Hughes', 'Knicker', 'Twister', 'Nick', 'Pettefar', 'DoD', 'David', 'Karr', 'Cynical', 'Old', 'Biker', 'Nick', 'Pettefar', 'Contractor', 'BNR', 'United', 'Kingdom', 'PBWASOH']
# ['Ken', 'Snyder', 'GGRRRrrr', 'Article', 'Hewlett', 'Packard', 'Santa', 'Clara', 'Site', 'Lines', 'NNTP', 'TIN', 'Don', '_______________________', 'UN2', 'Hewlett', 'Packard', 'Co']
# ['Keith', 'Allan', 'Universe', 'Black', 'Holes', 'California', 'Institute', 'Technology', 'Pasadena', 'Lines', 'NNTP', 'Bruce', 'Salem', 'Paradox', 'Zeno', 'Exp']
# ['Daniel', 'Geometry', 'Johns', 'Hopkins', 'University', 'Baltimore', 'USA', 'Lines', 'NNTP', 'Does', 'Dan', 'Naiman', 'Department', 'Mathematical', 'Sciences', 'Johns', 'Hopkins', 'University']
# ['Peter', 'Neilson', 'Organization', 'UUCP', 'Peter', 'Dan', 'Eldred', 'John', 'Ruckstuhl', 'MEK', 'Dan', 'ACETONE', 'WIFE', 'AROUND', 'Nasal', 'Chromatograph', 'ASCII', 'MEK', 'MEK', 'CH3', 'Acetone', 'MEK', 'MEK', 'Use', 'Nail', 'Quote']
# ['COM', 'Autos', 'Archive', 'Server', 'Keywords', 'Reply', 'New', 'York', 'State', 'Institute', 'Sebastian', 'Cabot', 'Studies', 'Lines', 'Archive', 'Automotive', 'Articles', 'Archive', 'Server', 'Carroll', 'Smith']
# ['Carl', 'Gritter', 'NHL', 'Purdue', 'University', 'Department', 'Computer', 'Sciences', 'Lines', 'NNTP', 'NHL', 'Joseph', 'Achkar', 'Carl', 'Gordie', 'Howe', 'Det', 'Wayne', 'Gretzky', 'Edm', 'Marcel', 'Dionne', 'Det', 'LA', 'Phil', 'Esposito', 'Chi', 'Bos', 'Bobby', 'Hull', 'Chi', 'Wpg', 'Mike', 'Gartner', 'Wsh', 'Min', 'Mike', 'Bossy', 'Guy', 'Lafleur', 'Mtl', 'NYR', 'Johnny', 'Bucyk', 'Det', 'Maurice', 'Richard', 'Stan', 'Mikita', 'Frank', 'Mahovlich', 'Tor', 'Det', 'Michel', 'Goulet', 'Que', 'Jari', 'Kurri', 'Edm', 'Bryan', 'Trottier', 'NYI', 'Gilbert', 'Perreault', 'Jean', 'Beliveau', 'Lanny', 'McDonald', 'Tor', 'Col', 'Jean', 'Ratelle', 'NYR', 'Norm', 'Ullman', 'Det', 'Dino', 'Ciccarelli', 'Min', 'Wsh', 'Darryl', 'Sittler', 'Tor', 'Phi', 'Mario', 'Lemieux', 'Glenn', 'Anderson', 'Edm', 'Alex', 'Delvecchio', 'Mark', 'Messier', 'Edm', 'Dale', 'Hawerchuk', 'Wpg', 'Rick', 'Middleton', 'NYR', 'Steve', 'Yzerman', 'Rick', 'Vaive', 'Van', 'Tor', 'Chi', 'Joe', 'Mullen', 'StL', 'Cgy', 'Yvan', 'Cournoyer', 'Dave', 'Taylor', 'Steve', 'Shutt', 'Mtl', 'Denis', 'Savard', 'Chi', 'Bill', 'Barber', 'Brian', 'Propp', 'Phi', 'Bos', 'Gary', 'Unger', 'Tor', 'Det', 'StL', 'Atl', 'LA', 'Rod', 'Gilbert', 'Steve', 'Larmer', 'John', 'Ogrodnick', 'Det', 'Que', 'Bernie', 'Nicholls', 'LA', 'NYR', 'Edm', 'Pat', 'LaFontaine', 'NYI', 'Brian', 'Bellows', 'Min', 'NYR', 'Buf', 'Dave', 'Christian', 'Wpg', 'Wsh', 'Bos', 'StL', 'Paul', 'Coffey', 'Edm', 'Pit', 'LA', 'NYI', 'Cam', 'Neely', 'Van', 'NYR', 'LA', 'Bos', 'Ashton', 'Van', 'Col', 'NJ', 'Min', 'Que', 'Det', 'Wpg', 'Bos', 'Doug', 'Gilmour', 'Stl', 'Cgy', 'Kevin', 'Dineen', 'Hfd', 'NYR', 'Mtl', 'Brian', 'Mullen', 'Wpg', 'NYR', 'SJ', 'Tor', 'Wpg', 'Kirk', 'Muller', 'NJ', 'Edm', 'Wayne', 'Gretzky', 'Edm', 'Gordie', 'Howe', 'Det', 'Marcel', 'Dionne', 'Det', 'LA', 'Phil', 'Esposito', 'Chi', 'Bos', 'Stan', 'Mikita', 'Bryan', 'Trottier', 'NYI', 'Johnny', 'Bucyk', 'Det', 'Guy', 'Lafleur', 'Mtl', 'NYR', 'Gilbert', 'Perreault', 'Alex', 'Delvecchio', 'Jean', 'Ratelle', 'NYR', 'Mark', 'Messier', 'Edm', 'Norm', 'Ullman', 'Det', 'Jean', 'Beliveau', 'Dale', 'Hawerchuk', 'Wpg', 'Bobby', 'Clarke', 'Paul', 'Coffey', 'Edm', 'Pit', 'LA', 'Denis', 'Savard', 'Chi', 'Jari', 'Kurri', 'Edm', 'Mario', 'Lemieux', 'Bobby', 'Hull', 'Chi', 'Wpg', 'Bernie', 'Federko', 'Mike', 'Bossy', 'Michel', 'Goulet', 'Que', 'Darryl', 'Sittler', 'Tor', 'Phi', 'Mike', 'Gartner', 'Wsh', 'Min', 'Frank', 'Mahovlich', 'Tor', 'Det', 'Dave', 'Taylor', 'Denis', 'Potvin', 'Henri', 'Richard', 'Steve', 'Yzerman', 'Bobby', 'Smith', 'Min', 'Rod', 'Gilbert', 'Glenn', 'Anderson', 'Edm', 'Lanny', 'McDonald', 'Tor', 'Col', 'Rick', 'Middleton', 'NYR', 'Dave', 'Keon', 'Tor', 'Bernie', 'Nicholls', 'LA', 'NYR', 'Edm', 'Brian', 'Propp', 'Phi', 'Bos', 'Andy', 'Bathgate', 'NYR', 'Tor', 'Det', 'Maurice', 'Richard', 'Larry', 'Robinson', 'Mtl', 'Dino', 'Ciccarelli', 'Min', 'Wsh', 'Steve', 'Larmer', 'Joe', 'Mullen', 'StL', 'Cgy', 'Bobby', 'Orr', 'Bos', 'Brad', 'Park', 'NYR', 'Bos', 'Butch', 'Goring', 'LA', 'NYI', 'Bill', 'Barber', 'Dennis', 'Maruk', 'Cal', 'Cle', 'Wsh', 'Ivan', 'Boldirev', 'Bos', 'Cal', 'Chi', 'Atl', 'Van', 'Yvan', 'Cournoyer', 'Dean', 'NYR', 'Bos', 'Det', 'Pit', 'Ted', 'Lindsay', 'Det', 'Tom', 'Lysiak', 'Atl', 'Dale', 'Hunter', 'Que', 'John', 'Tonelli', 'NYI', 'Cgy', 'LA', 'Chi', 'Jacques', 'Lemaire', 'Larry', 'Murphy', 'LA', 'Wsh', 'Min', 'John', 'Ogrodnick', 'Det', 'Que', 'Doug', 'Wilson', 'Chi', 'Doug', 'Gilmour', 'Stl', 'Cgy', 'Red', 'Kelly', 'Det', 'Pierre', 'Larouche', 'Pit', 'Mtl', 'Hfd', 'Bernie', 'Geoffrion', 'Mtl', 'Steve', 'Shutt', 'Mtl', 'Phil', 'Housley', 'Buf', 'Wilf', 'Paiment', 'KC', 'Col', 'Tor', 'Que', 'NYR', 'Buf', 'Peter', 'Bos', 'Van', 'Brian', 'Bellows', 'Min', 'Dave', 'Andreychuk', 'Buf', 'Pit', 'Martin', 'Det', 'Bos', 'Chi', 'NYI', 'Ken', 'Linesman', 'Phi', 'Edm', 'Gary', 'Unger', 'Tor', 'Det', 'StL', 'Atl', 'LA', 'Ken', 'Hodge', 'Bos', 'Neal', 'Broten', 'Wayne', 'Cashman', 'Rick', 'Vaive', 'Van', 'Tor', 'Chi', 'Borje', 'Salming', 'T ...
# ['EISA', 'Video', 'Cards', 'Organization', 'CBI', 'Larry', 'Snyder', 'EISA', 'Larry', 'Snyder', 'EISA', 'Orchid', 'EISA', 'ISA', 'EISA', 'VLB', 'David', 'Wexelblat', 'Laurel', 'Ave', 'Middletown', 'Love', 'Love', 'Oxygen']
# ['Matthew', 'Arizona', 'CS', 'Dept', 'Tucson', 'Lines', 'TurboComm', 'PCMag', 'THANKS', 'Matthew', 'Gibson']
# ['Dennis', 'SA', 'New', 'Hampshire', 'Durham', 'NH', 'Lines', 'NNTP']
# ['Servalan', 'NNTP', 'Perry', 'Qualcomm', 'DSPs', 'CDMA', 'Qualcomm', 'Japan', 'CDMA', 'NOT', 'Qualcomm', 'Qualcomm', 'US', 'International', 'Traffic', 'Arms', 'Regulations', 'Qualcomm', 'ASK', 'Don', 'Washington', 'Qualcomm', 'Cylink', 'Hah', 'No', 'Cylink', 'Qualcomm', 'Cylink', 'WILL', 'Better', 'EFFORT', 'Servalan']
# ['Rob', 'Philips', 'Research', 'Laboratories', 'Eindhoven', 'Netherlands', 'Lines', 'Symantec', 'Coporatoin', 'Norton', 'Desktop', 'IST', 'Building', 'WL', 'Netherlands']
# ['Tony', 'Ian', 'Hawkins', 'Vishay', 'SOT', 'Select', 'Test', 'Winnipeg']
# ['COM', 'John', 'Fox', 'SunExpress', 'IR', 'Grand', 'Runner', 'Organization', 'Inc', 'Reply', 'COM', 'NNTP', 'IGw', 'Jonathan', 'Edwards', 'Jeep', 'Wheel', 'Drive', 'THe', 'Toyota', 'SUV', 'Explorer', 'Trooper', 'Blazer', 'Montero', 'Land', 'Cruiser', 'Bear', 'John', 'John']
# ['Hewlett', 'Packard', 'Company', 'Chelmsford', 'MA', 'Lines', 'Very', 'Old', 'Freshman', 'VOF', 'FBI', 'Bill', 'Clinton', 'Janett', 'Reno']
# ['Michael', 'Feeley', 'Clipper', 'Pennsylvania', 'Lines', 'Nntp', 'Clipper', 'Chip']
# ['Grayson', 'Walker', 'Geico', 'GEICO', 'Organization', 'Lawrence', 'EDU', 'Jeffrey', 'Hoffmeister', 'Wayne', 'Smith', 'David', 'Geico', 'Geico', 'GEICO', 'LIDAR', 'GEICO', 'Florida', 'Highway', 'Patrol', 'County', 'Sheriff', 'GEICO', 'AFTER', 'GEICO', 'LIDAR', 'RATES', 'FOR', 'NSL', 'NSL']
# ['Richard', 'Pierson', 'Nntp', 'Norman', 'Hamer', 'Dropped', 'Don', 'Gee', 'Hull', 'Ottowa', 'NAVY', 'SUBMARINES', 'TARGETS', 'XS1100LH', 'Richard', 'Pierson', 'E06584']
# ['Simon', 'Clippingdale', 'Nntp', 'Computer', 'Science', 'Warwick', 'University', 'England', 'Lines', 'Mozumder', 'Navy', 'Bobby', 'Bobby', 'Bobby', 'Bobby', 'Bobby', 'Keith', 'Allah', 'Allah', 'Bobby', 'Mozumder', 'Allah', 'Doesn', 'Bobby', 'Mozumder', 'Allah', 'Quran', 'Allah', 'Bobby', 'Mozumder', 'Allah', 'Navy', 'Compare', 'Bobby', 'Quality', 'New', 'Voice', 'Islam', 'Cheers', 'Simon', 'Computer', 'Science', 'Tel', 'Warwick', 'Coventry']
# ['Ravikuma', 'Venkateswar', 'Illinois', 'Urbana', 'Lines', 'Ray', 'Fischer', 'Dave', 'Kitabjian', 'Motorola', 'Pentium', 'Pentium', 'PowerPC', 'Pentium', 'PowerPC', 'Alpha', 'SPECfp92', 'Computer', 'Note']
# ['Paul', 'Harvey', 'Christian', 'Morality', 'Duck', 'Pond', 'Jon', 'Livesey', 'Greatest', 'Salesman', 'Jesus', 'Bob', 'Bob', 'Paul', 'Jesus', 'Holywood', 'Paradox', 'Afro', 'Asians', 'Jesus', 'Con', 'Holywood', 'Jesus', 'Hendrix', 'Joplin', 'Morrison', 'Lennon', 'Marley', 'Tosh']
# ['Berkeley', 'Michael', 'Robinson', 'Cognitive', 'Studies', 'Berkeley', 'NNTP', 'Chris', 'Kryptonite', 'Krypto', 'Kryptonite', 'Kryptonite', 'Kryptonite', 'Kryptonite', 'Kryptonite', 'Krypto', 'Kryptonite', 'Kryptonite', 'Kryptonite', 'Taiwan', 'Kryptonite', 'TORQUE', 'Aviation', 'Michael', 'Robinson']
# ['John', 'Franjione', 'Nntp', 'Colorado', 'Boulder', 'Lines', 'Edward', 'Kim', 'AL', 'Morris', 'Milwaukee', 'AL', 'Morris', 'XXX', 'XXX', 'XXX', 'Jack', 'Morris', 'Mike', 'Trmbley', 'Needs', 'AAA', 'John', 'Franjione', 'Department', 'Chemical', 'Engineering', 'University', 'Colorado', 'Boulder']
# ['Steve', 'Bollinger', 'Stereo', 'Inc', 'Sound', 'Driver', 'Sound', 'Manager', 'SndPlay', 'BufferCmds', 'CallBacks', 'Sound', 'Driver', 'Sound', 'Manager', 'DON', 'Sound', 'Manager', 'Callbacks', 'QHead', 'IM', 'SndPlay', 'BufferCmd', 'SndDoCommand', 'Spectre', 'Spectre', 'CPU', 'Sound', 'Manager', 'IIsi', 'Sound', 'Manager', 'Steve']
# ['Helmut', 'Dotzlaw', 'Anti', 'Nntp', 'Manitoba', 'Lines', 'POVRay', 'POV', 'Helmut', 'Dotzlaw', 'Dept', 'Biochemistry', 'Molecular', 'Biology', 'University', 'Manitoba', 'Winnipeg', 'Canada']
# ['Walter', 'Hower', 'PARAMETRIC', 'Koblenz', 'Germany', 'Lines', 'NNTP', 'Wed', 'Jahir', 'Pabon', 'Robert', 'Young', 'Methodology', 'American', 'Society', 'Mechanical', 'Engineers', 'ASME', 'Fumihiko', 'Kimura', 'Michael', 'Turner', 'North', 'Holland', 'Netherlands', 'Expanded', 'Papers', 'IFIP', 'NSF', 'Working', 'Conference', 'Geometric', 'Modeling', 'Rensselaerville', 'NY', 'Joseph', 'Robert', 'Thijs', 'Sluiter', 'CAD', 'Robotics', 'Future', 'CARS', 'FOF', 'Michigan', 'USA', 'Springer', 'Verlag', 'Berlin', 'Hiromasa', 'Suzuki', 'Toshio', 'Sata', 'Constraint', 'Propagation', 'Product', 'Modelling', 'CIRP', 'OPTmonth', 'Kinosada', 'CIRP', 'Chung', 'Martin', 'Variational', 'Parametric', 'Design', 'Michigan', 'USA', 'Robert', 'Young', 'Walid', 'Keirouz', 'Features', 'Variational', 'Modeling', 'Conceptual', 'Design', 'Systems', 'Automation', 'Applications', 'SARA', 'OPTmonth', 'Heinemann', 'Nikola', 'Guid', 'Aleksander', 'Vesel', 'Neue', 'Konzepte', 'CAD', 'Systeme', 'Frank', 'Lothar', 'Krause', 'Detlev', 'Ruland', 'Helmut', 'Jansen', 'Springer', 'Verlag', 'Berlin', 'Fachtagung', 'Berlin', 'Masamichi', 'Shimura', 'AAAI', 'Eighth', 'National', 'Conference', 'Artificial', 'American', 'Association', 'Artificial', 'Intelligence', 'AAAI', 'Press', 'Menlo', 'Park', 'CA', 'Boston', 'MA']
# ['David', 'Davidian', 'Armenian', 'Center', 'Regional', 'Studies', 'Lines', 'EDU', 'KAAN', 'TIMUCIN', 'KAAN', 'David', 'Davidian', 'KAAN', 'DAVID', 'No', 'Come', 'KAAN', 'United', 'States', 'Freedom', 'Speech', 'KAAN', 'DON', 'TURC', 'KAAN', 'KAAN', 'Turkish', 'English', 'Turkish', 'Don', 'David', 'Davidian', 'Turkish', 'Center', 'Regional', 'Studies', 'Armenian', 'Cambridge', 'Turkish', 'MP']
# ['Free', 'Radical', 'Nntp', 'Northeastern', 'ACNS', 'ColoState', 'EDU', 'ColoState', 'E', 'Mail', 'Note', 'TEMPEST', 'TEMPEST', 'Jim', 'RA', 'Rogue', 'Agent', 'NSA']
# ['Barton', 'Oleksy', 'Organization', 'Ashley', 'Howland', 'Wood', 'Lines', 'UAlberta', 'Yadallee', 'Dave', 'Oilers', 'MIGHT', 'Hamilton', 'Porklington', 'Puck', 'Dave', 'Oilers', 'Edmonton', 'Selfish', 'Oilers', 'Bart']
# ['Steve', 'Gardner', 'Escrow', 'Database', 'Nntp', 'CONVEX', 'Computer', 'Corp', 'CONVEX', 'Computer', 'Corp', 'CONVEX', 'InF', 'David', 'Sternlight', 'Waco', 'Massacre', 'David', 'Ours', 'Power', 'David']
# ['Ronald', 'Queloz', 'UNIX', 'Organization', 'Swiss', 'Federal', 'Institute', 'Technology', 'ETH', 'CH', 'Lines', 'Does', 'Macintosh', 'Hypercard', 'UNIX']
# ['David', 'Farley', 'Windows', 'Reply', 'Chicago', 'Lines', 'Aron', 'Bonar', 'David', 'Farley', 'JFq', 'Andre', 'Boivert', 'PhotoShop', 'Mac', 'Mac', 'Info', 'PhotoStyler', 'PhotoShop', 'David', 'Quadra', 'RAM', 'David', 'David', 'Farley', 'The', 'University', 'Chicago', 'JRL', 'Chicago']
# ['Dwayne', 'Bailey', 'Serial', 'Redford', 'Michigan', 'Lines', 'COM1', 'COM4', 'SW5', 'SW6', 'COM', 'SW5', 'IRQ3', 'SW5', 'IRQ4', 'SW6', 'IRQ5', 'MULTI', 'UUCP', 'Dwayne', 'Bailey', 'Strategic', 'Software', 'Michigan']
# ['Tim', 'Clock', 'Bosnian', 'Nntp', 'California', 'Irvine', 'Keywords', 'EDU', 'Mohammed', 'ILYESS', 'BDIRA', 'ISLAMABAD', 'UPI', 'Bosnia', 'Herzegovina', 'Bosnian', 'Serbs', 'Clock', 'Ph', 'UCI', 'Society', 'California', 'Irvine', 'Home']
# ['Sale', 'Nntp', 'Rochester', 'New', 'York', 'Gross', 'Misconduct', 'Metal', 'Giants', 'Aerosmith', 'Mountain', 'Blue', 'Oyster', 'Cult', 'Judus', 'Priest', 'Metal', 'Church', 'Blessings', 'Disguise', 'Slayer', 'Hell', 'Awaits', 'Anthrax', 'Pain', 'Dream', 'Words', 'Exodus', 'Fabulous', 'Disaster', 'Ultra', 'Violence', 'Hence', 'CD', 'Please']
# ['UUCP', 'Thierry', 'Lach', 'Henry', 'Spencer', 'Reply', 'UUCP', 'Thierry', 'Lach', 'Henry', 'Spencer', 'Toronto', 'Zoology', 'Henry', 'Spencer', 'Cnews', 'Thierry', 'Lach']
# ['Darin', 'Wilkins', 'CUBED', 'Maxwell', 'Labs', 'San', 'Diego', 'CA', 'Lines', 'M3s', 'Timothy', 'AP', 'Carl', 'Stern', 'Justice', 'Department', 'Matthew', 'CONVEEEENIENT', 'Convenient', 'Centigrade', 'US', '________________________________']
# ['SHAFER', 'NASA', 'Dryden', 'Edwards', 'Cal', 'Reply', 'Tue', 'Phil', 'NASA', 'Look', 'Fly', 'Wire', 'Phil', 'WWII', 'NACA', 'NASA', 'NACA', 'Dryden', 'Area', 'Digital', 'Phil', 'NASA', 'NASA', 'Richard', 'Whitcomb', 'Jones', 'Langley', 'Research', 'Center', 'Dryden', 'KC', 'YF', 'YF', 'KC', 'Air', 'Force', 'Dryden', 'General', 'Dynamics', 'Avro', 'Arrow', 'Phil', 'NASA', 'Edwards', 'Air', 'Force', 'Base', 'KotFR', 'NASA', 'Dryden', 'Flight', 'Research', 'Facility', 'Edwards', 'NASA', 'US']
# ['Devils', 'Nntp', 'Manitoba', 'Winnipeg', 'Canada', 'Lines', 'Rex', 'Wang', 'Man', 'Math', 'Man', 'Devils', 'Islanders', 'Say', 'Islanders', 'Devils', 'John']
# ['John', 'Grant', 'Mines', 'Resources', 'Ottawa', 'Lines', 'REALLY', 'OS', 'OLE2', 'IBM', 'Microsoft', 'OLE2', 'John', 'Grant', 'Geophysics', 'Geological', 'Survey', 'Canada', 'Ottawa']
# ['David', 'Arndt', 'Johnny', 'Hart', 'Organization', 'Johnny', 'Hart', 'Good', 'Easter', 'Remarkable', 'Dave', 'Arndt', 'St']
# ['ESPN', 'Nntp', 'Delaware', 'Lines', 'Susan', 'Dart', 'ESPN', 'BUffalo', 'ESPN', 'Baseball', 'Penguine', 'NHl', 'NHL', 'ESPN', 'Hope', 'COBRA', '___', '____']
# ['Steven', 'Organization', 'Ames', 'IA', 'Lines', 'Randy', 'Agee', 'Car', 'Driver', 'Steven', 'Knapp', 'Computer', 'Cyclone', 'Amateur', 'Radio', 'Club', 'Iowa', 'State', 'University', 'Ames', 'IA', 'USA', 'Durham', 'Center', 'Operations', 'Staff']
# ['Infiniti', 'Organization', 'NNTP', 'STCLOUD', 'MSUS', 'EDU', 'Nissan', 'GS300', 'ES300', 'SC300', 'GS300', 'SC300', 'ES300']
# ['David', 'Young', 'Organization', 'MIT', 'Media', 'Laboratory', 'Lines', 'Macintosh']
# ['UUCP', 'Peter', 'Vermont', 'EMBA', 'Computer', 'Facility', 'Lines', 'Princeton', 'EDU', 'Ira', 'Fuchs']
# ['Nntp', 'Reply', 'Corp', 'CA', 'Lines', 'Home', 'Office', 'Voic', 'Mail', 'Box']
# ['PETCH', 'Chuck', 'Verse', 'Lines', 'Christ', 'New', 'International', 'Version', 'Hebrew', 'Greek', 'God', 'Bless', 'Chuck', 'Petch']
# ['Inc', 'NNTP', 'Scott', 'Feel', 'Non', 'OR']
# ['Sharon', 'Srebrenica', 'Hell', 'WITHOUT', 'Brookline', 'MA', 'Lines', 'SREBRENICA', 'Laura', 'Pitter', 'TUZLA', 'Bosnia', 'Reuter', 'Neret', 'Mujanovic', 'Muslim', 'Srebrenica', 'Bosnia', 'Tuzla', 'Muslim', 'Serb', 'Srebrenica', 'Srebrenica', 'Mujanovic', 'Tuzla', 'Tuzla', 'Srebrenica', 'Half', 'Mujanovic', 'Blood', 'Mujanovic', 'Belgian', 'Medecins', 'Sans', 'Frontieres', 'Mujanovic', 'Bosnian', 'Serbs', 'Between', 'Mujanovic', 'Srebrenica', 'Mujanovic', 'Srebrenica', 'Tuzla', 'Sharon', 'Machlis', 'Gartenberg', 'Framingham', 'MA']
# ['Green', 'Pixel', 'Cruncher', 'RTP', 'NC', 'Lines', 'Reply', 'NNTP', 'Jean', 'Noel', 'Moyne', 'Highway', 'Patrol', 'Dunno', 'Ninjaite', 'Green', 'COM', 'DoD', 'Grateful', 'Dead']
# ['Paul', 'Hudson', 'Jr', 'Georgia', 'Athens', 'Lines', 'Scripture', 'Collosions', 'Sabbath', 'Paul', 'Christ', 'New', 'Testament', 'Paul', 'Link', 'Hudson']
# ['Western', 'Kentucky', 'University', 'Bowling', 'Green', 'KY', 'Lines', 'JsC', 'Mark', 'Singer', 'Bob', 'Gajarsky', 'Hobokenite', 'Lopez', 'Olson', 'Olson', 'MLB', 'Lopez', 'Wasn', 'Ivan', 'Rodriguez', 'AA', 'Sandy', 'Alomar', 'Wasn', 'Benito', 'Santiago', 'Perhaps', 'Braves', 'Mark', 'Singer', 'Cabaniss', 'Tommy', 'Lord', 'Western', 'Kentucky', 'University', 'Gaylord', 'Perry']
# ['Paul', 'Harvey', 'Duck', 'Pond', 'Paul', 'Hudson', 'Jr', 'AqC', 'Jesus', 'Jesus', 'Jewish', 'Christians', 'Sabbath', 'Jesus', 'Has', 'Jesus', 'Ten', 'Commandments', 'Jesus']
# ['Rodger', 'PastorTalk', 'Organization', 'Zeisler', 'Plano', 'PASTORTALK', 'Carl', 'Wilkes', 'Startext', 'MC344578', 'Supreme', 'Court', 'Rensselaer', 'Bibles', 'REL65', 'Gideons', 'Bible', 'Bibles', 'ACLU', 'Barry', 'Lynn', 'Lynn', 'Gideons', 'Bibles', 'Bibles', 'Russia', 'Bible', 'March', 'Bible', 'Gideon', 'Moscow', 'University', 'Moscow', 'Bibles', 'Lenin', 'MAIL', 'Good', 'John', 'Hightower', 'John', 'WRITER', 'Legacy', 'Drive', 'Baptist', 'Church', 'Plano']
# ['PacBell', 'COM', 'Ken', 'Keirnan', 'ATI', 'Graphic', 'Ultra', 'ATI', 'Ken', 'Keirnan', 'Keirnan', 'Pacific', 'Bell', 'PacBell', 'San', 'Ramon', 'California']
# ['UUCP', 'Serdar', 'Argic', 'Reply', 'UUCP', 'Serdar', 'Argic', 'Eduard', 'Wiener', 'Russia', 'Ukraine', 'Ukrainians', 'Tatars', 'Bulgarians', 'Bashkirs', 'Iranians', 'Owieneramus', 'Always', 'ASALA', 'Source', 'II', 'Muslim', 'Armenian', 'Republic', 'Rawlinson', 'British', 'Erzurum', 'United', 'States', 'Harbord', 'Kazim', 'Karabekir', 'Armenian', 'Karabekir', 'Muslim', 'Shuraghel', 'Akpazar', 'Zarshad', 'Childir', 'Muslim', 'Kars', 'Gumru', 'Muslims', 'Armenian', 'Muslim', 'Muslims', 'Muslims', 'Serdar', 'Argic', 'Turks', 'Ohanus', 'Appressian', 'Soviet', 'Armenia', 'Turkish', 'Sahak', 'Melkonian']
# ['Morris', 'Port', 'Nntp', 'MITRE', 'Corporation', 'Bedford', 'MA', 'Lines', 'Mike', 'Sprague', 'LPT1', 'IRQ7', 'LPT1', 'DOS', 'ISA', 'IRQ', 'IRQ', 'Incidentally', 'IRQ', 'Non', 'DOS', 'NT', 'Unix', 'SB16', 'Joe', 'Morris']
# ['Matt', 'Jacobson', 'Stanford', 'University', 'USA', 'Lines', 'W4W2', 'TURN', 'CMOS', 'PLEASE', 'EMAIL', 'Chet', 'Pager']
# ['Thomas', 'Menner', 'Hockey', 'Equip', 'Tom', 'Software', 'Engineering', 'Carnegie', 'Mellon', 'University', 'Pittsburgh', 'Fabulous', 'Furry', 'Freak', 'Bros']
# ['Scott', 'Cattanach', 'Waco', 'CSTaR', 'Lines', 'NNTP', 'Peter', 'Cash', 'COM', 'COM', 'Children', 'CS', 'BDs', 'Dan', 'Quayle']
# ['Unisys', 'Open', 'Systems', 'Group', 'San', 'Jose', 'COM']
# ['Emran', 'Qureshi', 'Europe', 'Muslim', 'Bosnians', 'Organization', 'Bell', 'Northern', 'Research', 'Ottawa', 'Canada', 'Lines', 'Satya', 'Prabhakar', 'Joseph', 'Biden', 'Yugoslavia', 'Bosinan', 'Muslims', 'Nazis', 'Muslims', 'Indian', 'Emran']
# ['Ryou', 'Seong', 'Joon', 'Multi', 'GIF', 'Organization', 'Science', 'Technology', 'PL3', 'Lines', 'Multi', 'Unix']
# ['Nntp', 'Iowa', 'Image', 'Analysis', 'Facility', 'Lines', 'Brett', 'Harper', 'Object', 'Oriented', 'Application', 'Framework', 'Glockenspeil', 'Motif', 'OS2', 'OS2', 'Motif', 'ID_OK', 'Motif', 'Dialog1_OK', 'Motif', 'CommonView', 'Iowa', '______']
# ['Alberto', 'Adolfo', 'Pinkas', 'Israel', 'Organization', 'Maryland', 'College', 'Park', 'Lines', 'NNTP', 'Joseph', 'Askew', 'Alberto', 'Adolfo', 'Pinkas', 'Jewish', 'AAP']
# ['Bruce', 'Salem', 'Albert', 'Sabin', 'Earth', 'Sciences', 'Lines', 'NNTP', 'Mike', 'Cobb']
# ['Dale', 'Fraser', 'XXXVIII', 'Organization', 'Newfoundland', 'Lines', 'Droopy', 'Pete', 'Raymond', 'Moncton', 'Halifax', 'Halifax', 'Halifax', 'Metro', 'Center', 'Leafs', 'Home', 'Halifax', 'Metro', 'Center', 'Moncton', 'Moncton', 'Halifax', 'Metro', 'Center', 'Moncton', 'NHL', 'Quebec', 'ASN', 'ASN', 'ASN', 'John', 'Hey', 'GO', 'Dale', 'Memorial', 'University', 'Newfoundland', 'CS', 'Undergrad', 'BELONG', 'TO', 'ME']
# ['Adam', 'Samuel', 'Nash', 'Stanford', 'University', 'USA', 'Lines', 'IIvx', 'Rumor']
# ['Paul', 'Havemann', 'Clinton', 'HSH', 'Associates', 'Lines', 'AtlantaGA', 'COM', 'AtlantaGA', 'COM', 'Mark', 'Wilson', 'Clinton', 'Clinton', 'Jobs', 'MAKE', 'Clinton', 'Isn', 'Clinton', 'Clinton', 'Clinton', 'Clinton', 'LBJ', 'Same', 'Minimum', 'Daily']
# ['Jean', 'Andrews', 'Industrial', 'Administr', 'Pittsburgh', 'PA', 'Lines', 'NNTP', 'Pittsburgh']
# ['Steven', 'Hong', 'ORGANIZER', 'Distribution', 'Pennsylvania', 'Philadelphia', 'PA', 'USA', 'Lines', 'Nntp', 'ORGANIZER', 'Lotus', 'Organizer', 'Shareware', 'Please', 'Steven', 'Hong', 'Email', 'Address', 'Pennsylvania', 'Engineering', 'Class']
# ['Stuart', 'Electrical', 'Engineering', 'Heriot', 'Watt', 'University', 'Scotland', 'Lines', 'Stuart', 'Heriot', 'Watt', 'BLACK', 'Edinburgh', 'FAX', 'God', 'Harley', 'Mail', 'Pope']
# ['Article', 'ZOWIE', 'Space', 'Science', 'Astrophysics', 'Lines', 'NNTP', 'Brad', 'Thone', 'SAE', 'Modern', 'DON', 'DILUTE']
# ['David', 'Washington', 'Post', 'Article', 'SSF', 'Redesign', 'News', 'Nntp', 'NASA', 'Lewis', 'Research', 'Center', 'Ohio', 'Lines', 'Space', 'Station', 'Redesign', 'Leader', 'Cost', 'Goal', 'Washington', 'Post', 'NASA', 'Connor', 'NASA', 'Russian', 'Mir', 'Post', 'Kathy', 'Sawyer', 'White', 'House', 'SSF', 'Bus', 'MSFC', 'Single', 'Launch', 'Core', 'SSF', 'Sawyer', 'Russian', 'Mir', 'Skylab', 'Freedom']
# ['Richard', 'Verhoeven', 'Technology', 'Netherlands', 'Lines', 'NNTP', 'Tobias', 'XCreateWindow', 'USPosition', 'USSize', 'PPosition', 'Sorry', 'XMapWindow', 'Richard']
# ['UUCP', 'Serdar', 'Argic', 'Armenian', 'Philosophy', 'Reply', 'UUCP', 'Serdar', 'Argic', 'CRAP', 'Nagarno', 'Karabagh', 'ALWAYS', 'PART', 'ARMENIA', 'AZERIS', 'HISTORY', 'Karabag', 'Turkish', 'Turks', 'Turkish', 'Armenians', 'Nazis', 'Nazi', 'Russia', 'Soviet', 'Armenia', 'Arab', 'Jewish', 'Jewish', 'Zionist', 'Communist', 'Soviet', 'John', 'Roy', 'Carlson', 'Arthur', 'Derounian', 'Damascus', 'New', 'York', 'Armenian', 'Racial', 'Patriots', 'Dashnaktzoutun', 'Boston', 'ASALA', 'Armenian', 'Tzeghagron', 'Armenian', 'Racial', 'Patriots', 'Garegin', 'Nezhdeh', 'Hitler', 'United', 'States', 'Central', 'Committee', 'Dashnaktzoutun', 'American', 'Armenian', 'Nezhdeh', 'Armenian', 'Tzeghagrons', 'Armenian', 'Nezhdeh', 'Racial', 'Religious', 'Race', 'Race', 'John', 'Roy', 'Carlson', 'Arthur', 'Derounian', 'Armenian', 'Displaced', 'Persons', 'Armenian', 'Affairs', 'GRUESOME', 'Azeris', 'Hojali', 'Azerbaijan', 'Nagorny', 'Karabakh', 'Azeri', 'Hojali', 'Baku', 'Armenian', 'Nagorny', 'Karabakh', 'Rome', 'Communist', 'Baku', 'Armenian', 'Azerbaijan', 'Aydin', 'Rasulov', 'Azerbaijan', 'Elman', 'Memmedov', 'Hojali', 'Baku', 'May', 'Leila', 'Yunusova', 'Azeri', 'Ministry', 'Defence', 'FranCois', 'Zen', 'Ruffinen', 'International', 'Red', 'Cross', 'Baku', 'Muslim', 'Agdam', 'Hojali', 'Don', 'Soviet', 'Baku', 'Popular', 'Front', 'Hojali', 'Armenia', 'Rafiq', 'Youssifov', 'Muslims', 'Gunshots', 'Exposure', 'Thirty', 'Rasulov', 'Towfiq', 'Manafov', 'Hojali', 'Hojali', 'Nakhchivanik', 'Armenians', 'Hojali', 'Armenian', 'INDEPENDENT', 'London', 'Serdar', 'Argic', 'Turks', 'Ohanus', 'Appressian', 'Soviet', 'Armenia', 'Turkish', 'Sahak', 'Melkonian']
# ['David', 'Davidian', 'Russian', 'Azerbaijan', 'Organization', 'Center', 'Regional', 'Studies', 'Lines', 'Russian', 'Azerbaijan_', 'MOSCOW', 'UPI', 'Russia', 'Armenia', 'Azerbaijani', 'Baku', 'Azeri', 'Abulfaz', 'Elchibey', 'Russian', 'Itar', 'Russian', 'Moscow', 'Azeri', 'Kelbadzhar', 'Azerbaijan', 'Nagorno', 'Karabakh', 'Armenia', 'Supreme', 'Court', 'Baku', 'Russian', 'Armenian', 'Yerevan', 'Armenian', 'Azeri', 'Nagorno', 'Karabakh', 'Azeri', 'Russian', 'Russian', 'Armenian', 'Nagorno', 'Karabakh', 'Armenian', 'Azerbaijan', 'Baku', 'Yerevan', 'Russian', 'Soviet', 'Union', 'Moscow', 'Russian', 'Azerbaijani', 'Russian', 'Boris', 'Yeltsin', 'Itar', 'David', 'Davidian', 'Armenia', 'Center', 'Regional', 'Studies', 'Turkish', 'Turgut', 'Ozal']
# ['BOARD', 'Layout', 'Help', 'EH1QC', 'New', 'York', 'Lines', 'Anton']
# ['Kirill', 'Shklovsky', 'Northeastern', 'University', 'Distribution', 'Ross', 'Anderson', 'Tempest', 'TEMPEST', 'CRTs', 'Dave']
# ['Mark', 'Horan', 'Article', 'Nebraska', 'Lincoln', 'Lines', 'NNTP', 'Ted', 'Frank', 'Alomar', 'Sandberg', 'Alomar', 'Sandberg', 'Sandberg', 'Alomar', 'Alomar', 'Sandberg', 'Alomar', 'Sandberg', 'Sandberg', 'Alomar', 'Alomar', 'Alomar', 'Sandberg', 'Sandberg', 'Sandberg', 'Sandberg', 'Alomar', 'Sandberg', 'Ripken', 'Boggs', 'Gwynn', 'Sandberg', 'Alomar', 'National', 'Larry', 'Mark', 'Horan']
# ['Xxmessage', 'A7FD9E6FD7012056', 'Applied', 'Electronics', 'Michigan', 'State', 'University', 'SYSTEMS', 'POWERBOOK', 'RAM', 'Lars', 'Applied', 'Electronics', 'Fax']
# ['Mohammad', 'Al', 'EISA', 'Organization', 'Indiana', 'University', 'Computer', 'Science', 'Bloomington', 'Lines', 'EISA', 'DX2', 'OPTI', 'Micron', 'EISA', 'Micronics', 'Cache', 'Micron', 'Edge', 'Technologies', 'Micron', 'Does', 'Has', 'Cache', 'Micron', 'Micronics', 'Ansari']
# ['David', 'Vanderbyl', 'ACid', 'Batteries', 'Part', 'Nntp', 'Reply', 'David', 'Vanderbyl', 'PbO2', 'Sulfuric', 'Acid', 'Lead', 'Sulfate', 'Water', 'PbSO4', 'ACID', 'PbSO4', 'H2SO4', 'SO4', 'PbSO4', 'H2SO4', 'H30', 'PbSO4', 'SO4', 'PbSO4', 'FALLS', 'THE', 'BATTERY', 'INDEED', 'LeChatelier', 'LeChatelier', 'Canada']
# ['Puneet', 'WordBasic', 'Visual', 'Basic', 'Macros', 'Organization', 'Ohio', 'State', 'University', 'Lines', 'NNTP', 'Visual', 'Basic', 'Visual', 'Basic', 'MS', 'Word', 'WordBasic', 'Macros', 'Visual', 'Basic', 'MyOwn', 'INI', 'VB', 'INI', 'INI', 'WordBasic', 'INI', 'MyOwn', 'INI', 'WordBasic']
# ['Zero', 'Nntp', 'John', 'Thomson', 'Joseph', 'Chiu', 'SouthWestern', 'Bell', 'dB', 'Amp', 'AMP', 'Amphenol', 'AMPERE', 'AMP', 'AMP', 'AMPERE', 'Ohmite', 'Ohms', 'Bell', 'Chiu', 'Hertz']
# ['Cat', 'Factory', 'Mushroom', 'Farm', 'Lines', 'AA25231', 'Michael', 'Justice', 'Dillon', 'Blue', 'Bankrupt', 'HCI', 'HCI', 'HCI', 'NRA', 'Jerry', 'Hollombe', 'CDP', 'Citicorp', 'Laws', 'Ocean', 'Park', 'Blvd', 'Santa', 'Monica']
# ['Leslie', 'Jones', 'MacWeek', 'News', 'Tennessee', 'Computing', 'Center', 'Lines', 'EDU', 'Adam', 'Samuel', 'Nash', 'MacWeek', 'MacWeek', 'Canada', 'Mexico', 'Leslie', 'Jones']
# ['Convex', 'UNIX', 'WinQVT', 'Reply']
# ['Yap', 'Nntp', 'Bryan', 'Smale', 'Biggest', 'Biggest', 'Washington', 'Capitals', 'Hatcher', 'Bondra', 'Poetic']
# ['Mark', 'Zenier', 'CD4052', 'Organization', 'Inc', 'WA', 'TIN', 'Anyone', 'Maximum', 'Static', 'Voltage', 'Across', 'Switch', 'TTL', 'CMOS', 'Mark', 'Zenier']
# ['Kenneth', 'Hinckley', 'Reply', 'Kenneth', 'Hinckley', 'Virginia', 'Lines', 'HP730', 'UNIX', 'UNIX', 'Ken', 'P', 'IBM', 'PC', 'Ken', 'Hinckley', 'Virginia', 'Neurosurgical', 'Visualization', 'Laboratory']
# ['Tim', 'Clock', 'Nntp', 'California', 'Irvine', 'Lines', 'Steven', 'Berson', 'EDU', 'Thomas', 'Sorry', 'Bill', 'Rights', 'Jefferson', 'Cheers', 'Berson', 'UCI', 'Society', 'California', 'Irvine', 'Home']
# ['Hayes', 'THE', 'TRINITY', 'Lines', 'Andrew', 'Byler', 'Athanasian', 'Creed', 'DAB', 'Christian', 'Trinity', 'DAB', 'DAB', 'DAB', 'Catholic', 'Church', 'Lutheran', 'DAB', 'Orthodox', 'Orthodox', 'Churches', 'Western', 'Orthodox', 'Churches', 'Faith', 'Nicene', 'Creed', 'Steve', 'Hayes', 'Department', 'Missiology', 'University', 'South', 'Africa']
# ['Ron', 'Phillips', 'Armed', 'Citizen', 'Nntp', 'Reply', 'Intergraph', 'Electronics', 'Mountain', 'View', 'Colin', 'Kendall', 'THE', 'ARMED']
# ['Riston', 'Tapp', 'Waterloo', 'Lines', 'Richard', 'Wernick', 'Boston', 'Sinden', 'Boston', 'Esposito', 'Ratelle', 'How', 'Ratelle', 'Middleton', 'Bruins', 'Brad', 'Park', 'Vadnais', 'Montreal', 'Esposito', 'Boston', 'Riston', 'Riston']
# ['Reply', 'VESA', 'Local', 'Bus', 'BusLogic', 'BT445', 'SCSI', 'BT545S', 'ISA', 'Micropolis', 'BT445', 'BusLogic']
# ['Peter', 'Garfiel', 'Freeman', 'Reply', 'Peter', 'Garfiel', 'Freeman', 'Columbia', 'University', 'Lines', 'Frank', 'Benson', 'Hey']
# ['Eric', 'Bosco', 'Nntp', 'Reply', 'Oracle', 'Corporation', 'Oracle', 'Ardie', 'Mack', 'Eric', 'DOS', 'Anybody', 'Eric']
# ['Bruce', 'Schneier', 'Clinton', 'Organization', 'Chinet', 'Public', 'Access', 'UNIX', 'Lines', 'David', 'Sternlight', 'Clipper', 'NSA']
# ['Robert', 'Compaq', 'XT', 'Organization', 'Aerospace', 'Corporation', 'CA', 'Lines', 'NNTP', 'Miniscribe', 'Compaq', 'XT', 'Compaq', 'SETUP', 'Did', 'XT', 'SETUP', 'Robert', 'Robert', 'Luke', 'Aerospace', 'Corporation', 'Danger', 'Will', 'Robinson']
# ['Speedy', 'Mercer', 'Dog', 'Organization', 'NNTP', 'Blaine', 'Gardner', 'BONG', 'BONG', 'Eric', 'Bong', 'Swedish', 'Mouser', 'Technician', 'Speed', 'Student']
# ['Jeffrey', 'Clark', 'Dan', 'Bissell', 'Nntp', 'Griffith', 'University', 'Brisbane', 'Australia', 'Lines', 'DAN', 'Jesus', 'Messiah', 'Godhood', 'Roman', 'Moslem', 'Jewish', 'NAZI', 'WWII', 'Wouldn', 'Napoleon', 'Mussolini', 'Ronald', 'Reagan', 'Bible', 'Bible', 'Niether', 'Jim', 'Jones', 'David', 'Koresh', 'Isaiah', 'Nostradamus', 'Jeff']
# ['Cindy', 'Tittle', 'Moore', 'BubbleJet', 'HP', 'Article', 'Reply', 'Cindy', 'Tittle', 'Moore', 'Nntp', 'THAT', 'SLOW', 'Hope', 'Cindy', 'Tittle', 'Moore', 'Irvine', 'CA']
# ['Allen', 'Tobias', 'CONVEX', 'Computer', 'Corporation', 'Richardson', 'CONVEX', 'Computer', 'Corp', 'CONVEX', 'EDU', 'EDU', 'Washington', 'DC', 'Beltway', 'Snot', 'Society', 'Kid', 'Cheap']
# ['Hugh', 'X11R5', 'INMOS', 'Limited', 'Bristol', 'UK', 'Lines', 'X11R5', 'Refresh', 'Please', 'Hugh', 'McIntyre', 'INMOS', 'Ltd', 'X11R5']
# ['Marc', 'Anderson', 'Colorado', 'Boulder', 'Lines', 'Nntp', 'Charles', 'D', 'Hanan', 'Herzog']
# ['COM', 'Joe', 'Keane', 'FBI', 'Reply', 'Object', 'Technology', 'Moon', 'EDU', 'Tim', 'Cuffel', 'America', 'CPU', 'Joe', 'Keane']
# ['_Ward', 'BMUG', 'Inc', 'TI', 'Same', 'FirstClass', 'BBS', 'BMUG', 'BMUG']
# ['Richard', 'McDougald', 'Tennessee', 'Lines', 'Knight', 'Blue', 'Knight', 'Yury', 'German', 'Pei', 'Hsieh', 'FAQ', 'Autodesk', 'Amiga', 'FAQ', 'Please', 'IFF', 'Amiga', 'Hijaak', 'Hijaak', 'CrossDos', 'Targa', 'Hijaak', 'Photography', 'Center', 'Univ', 'Tenn', 'CERTAINLY', 'University', 'Tennessee']
# ['Article', 'C5DE05A0', 'Reply', 'Cubs', 'DL', 'Harkey', 'Delino', 'Deshields', 'John', 'Wetteland', 'Expos', 'Pomona']
# ['Greg', 'NASA', 'Lewis', 'Research', 'Center', 'Ohio', 'Lines', 'NNTP', 'News', 'Robert', 'McDonald', 'Toyland', 'SCOTT', 'McRib', 'McChicken', 'Debbie', 'Does', 'Cheap', 'Beta', 'Greg', 'BEST', 'VIDEO', 'Magazine', 'Nov']
# ['Steve', 'Manes', 'FAA', 'FARs', 'DWI', 'DWI', 'New', 'York', 'Bruce', 'Clarke']
# ['Eerik', 'Ames', 'IA', 'Lines', 'Jean', 'Noel', 'Moyne', 'OWI', 'OMVI', 'OMVI', 'Harris', 'Street', 'Ames', 'Ia']
# ['Wayne', 'Smith', 'SCSI', 'Organization', 'John', 'P', 'Robarts', 'Research', 'Institute', 'London', 'Ontario', 'Nntp', 'NewsSoftware', 'Mike', 'Schwartz', 'Michael', 'Smith', 'IDE', 'ISA', 'SCSI', 'SCSI', 'DMA', 'IDE', 'DMA', 'DMA', 'DMA', 'DMA', 'SCSI', 'DOS', 'DOS', 'SCSI', 'IDE', 'SCSI', 'SCSI', 'IDE', 'UNIX', 'SCSI']
# ['Lee', 'Reynolds', 'Organization', 'Ludus', 'Associates', 'Incorporated', 'Magitronic', 'Has', 'Lee']
# ['COM', 'Clayton', 'Cramer', 'Petaluma', 'CA', 'Lines', 'Dan', 'Lack', 'Clayton']
# ['Peter', 'Organization', 'Clarkson', 'University', 'Lines', 'Nntp', 'Peter', 'Pundy', 'IIci', 'Answer', 'Amiga', 'SCO', 'Sun', 'UNIX', 'MS', 'ROM', 'Apple', 'Pete', 'Documentation', 'Enable', 'Software']
# ['James', 'Nntp', 'Inc', 'Jody', 'Levine', 'Ryan', 'Cousineau', 'Levine', 'Ontario', 'Harley', 'Davidson', 'Cray', 'Research', 'Inc', 'Mpls', 'Henny', 'Youngman', 'My']
# ['V2110A', 'TEMPLE', 'Richard', 'Hoenes', 'Nntp', 'Isreali', 'Hey', 'Wayne', 'Richard']
# ['Ralph', 'Buttigieg', 'Gate', 'Craig', 'Keithley', 'Titan', 'IV', 'Shuttle', 'Centaur', 'LEV', 'US', 'Joint', 'ESA', 'NASA', 'US', 'Hmmm', 'Anyone', 'Anyone', 'Zurbrin', 'Compact', 'Moon', 'Direct', 'Ralph', 'VULCAN', 'WORLD', 'Sydney', 'Australia']
# ['David', 'Macintosh', 'Organization', 'David']
# ['SHADOW', 'Optical', 'Raytracing', 'Package', 'Reply', 'SERC', 'Daresbury', 'Laboratory', 'UK', 'Lines', 'NNTP', 'SHADOW', 'SHADOW', 'Anyone', 'Thanks', 'Gary', 'SERC', 'Daresbury', 'Lab']
# ['Thomas', 'SCSI', 'Brookline', 'MA', 'Lines', 'Mark', 'Jackson', 'COM', 'COM', 'Mike', 'Figueroa', 'Future', 'Domain', 'Adaptec', 'FDISK', 'DOS', 'ODD', 'FDISK', 'SCSI']
# ['Sean', 'Oliver', 'MIND', 'LINK', 'British', 'Columbia', 'Canada', 'Lines', 'British', 'Columbia', 'Canada', 'Rogers', 'Cable', 'Does', 'Sean', 'Oliver', 'MINDLINK', 'BBS']
# ['Indiana', 'University', 'Lines', 'HOLFELTZ', 'Aaron', 'Bryce', 'Cardenas', 'Answer', 'Christ', 'Jesus', 'Jesus', 'Joe', 'Fisher']
# ['BrockU', 'Tim', 'Ciceran', 'Brock', 'University', 'Catharines', 'Ontario', 'TIN', 'Aldus', 'Photostyler', 'Aldus', 'BrockU']
# ['Andrew', 'Duthie', 'Organization', 'Michigan', 'ITD', 'Consulting', 'Support', 'NNTP', 'Jay', 'Scott', 'Andrew', 'Duthie']
# ['PETCH', 'Chuck', 'Verse', 'Lines', 'Lord', 'Himself', 'Heaven', 'Christ']
# ['Phil', 'Organization', 'Southwestern', 'Louisiana', 'Lines', 'Ethan', 'Bradford', 'Walker', 'Andrew', 'John', 'Oort', 'Oort', 'Clouds', 'Oort', 'Alpha', 'Oort', 'Cloud', 'Kupier', 'Belt', 'Heck', 'Phil', 'Fraering', 'Repo']
# ['Michael', 'Nntp', 'XXMessage', 'A7FFA130BA038ECA', 'XXDate']
# ['COM', 'Brenda', 'Bowden', 'NNTP', 'Does', 'Brenda']
# ['Nntp', 'Reply', 'Motorola', 'PL4', 'Lines', 'Mac', 'Mac', 'FAQ', 'Someone', 'Sorry', 'Motorola', '______', 'Greg', 'Berryman', 'Texas', 'USA', 'GLB', 'Motorola']
# ['Brian', 'Tao', 'Krillean', 'Photography', 'Organization', 'MuGS', 'Research', 'Alexander', 'P', 'Reply', 'Alexander', 'P', 'Kirlian', 'ANYTHING', 'History', 'Brian', 'Tao', 'Node', 'BBS', 'FREE', 'University', 'Toronto']
# ['Research', 'Computing', 'Activities', 'Lines', 'Reply', 'LIONESS', 'NNTP', 'Brian']
# ['Books', 'Organization', 'School', 'Computer', 'Science', 'Carnegie', 'Mellon', 'Pittsburgh', 'PA', 'Lines', 'NNTP', 'Reply', 'Paine', 'Reason', 'Nanci']
# ['INescn', 'Rui', 'Picas', 'NNTP']
# ['Derek', 'PCTools', 'Doesn', 'PCTools', 'Harvey', 'Mudd', 'College', 'Claremont', 'Ami', 'PCTools', 'Cache', 'Ami', 'Pro', 'AMIPRO', 'EXE', 'AMIPROUI', 'Ami', 'Pro', 'BTW', 'PCTools', 'RAM', 'OEM', 'PLEASE', 'Derek']
# ['Harold_Brooks', 'Spanky', 'Organization', 'Huckabay', 'Kiteball', 'Campaign', 'Committee', 'Lines', 'William', 'Pollak', 'Bucs', 'Drabek', 'Tommy', 'Prince', 'Simmons', 'Tom', 'Pagnozzi', 'Geez', 'Dal', 'Ted', 'Pagnozzi', 'Prince', 'Pagnozzi', 'Louisville', 'Nichols', 'Catcher', 'Defense', 'Ted', 'Pagnozzi', 'BTW', 'Cardinal', 'Pagnozzi', 'Harold', 'Harold', 'Brooks', 'Norman', 'Bavasi', 'Dal', 'Maxvill', 'Florida', 'NL', 'East']
# ['Karl', 'Dussik', 'Organization', 'James', 'Moss', 'Christianity', 'Lord', 'Bible', 'Bible', 'Hannibal', 'Bible', 'Needless', 'Love', 'Christ', 'God', 'Christ', 'Karl', 'Dussik']
# ['Organization', 'Washington', 'University', 'Brad', 'Thone', 'NETNEWS', 'Brad', 'Thone', 'Systems', 'Consultant', 'Systems', 'Service', 'Enterprises', 'St', 'Louis', 'MO']
# ['Peter', 'Bruce', 'Harper', 'Ulf', 'Samuellsson', 'Organization', 'NNTP', 'helpiMontreal', 'Canadiens', 'Denis', 'Savard', 'Montreal', 'Thanx', 'Pete', 'Baby', 'Lady', 'U_HARPER', 'COME', 'Skid', 'Row']
# ['Kris', 'Schludermann', 'Nntp', 'Super', 'Collider', 'Laboratory', 'Lines', 'Jonathan', 'Pulsar', 'SE', 'Please']
# ['Organization', 'Toronto', 'Chemistry', 'Department', 'Lines', 'Urban', 'True', 'Mark']
# ['Energy', 'Conservation', 'Wastful', 'Study', 'Finds', 'Nntp', 'Energy', 'Conservation', 'Wastful', 'Study', 'Finds', 'Washington', 'Clinton', 'Energy', 'Cato', 'Institute', 'Jerry', 'Taylor', 'Cato', 'United', 'States', 'Japan', 'Energy', 'Market', 'GNP', 'DSM', 'Taylor', 'Efficiency', 'Case', 'Against', 'Policy', 'Analysis', 'Cato', 'Institute', 'Washington', 'Cato', 'Washington', 'Cato', 'Institute', 'Founded', 'Cato', 'Institute', 'American', 'Institute', 'Cato', 'American', 'Colonies', 'American', 'Revolution', 'Cato', 'Institute', 'Books', 'Social', 'Security', 'Cato', 'Journal', 'Cato', 'Institute', 'Institute', 'Internal', 'Revenue', 'Code', 'Cato', 'Washington']
# ['Baden', 'MOSFET', 'TIPC2701N', 'TI', '_________________________________________________', 'Inspiration', 'Bari', 'Winnipeg']
# ['David', 'Sugar', 'Drexel', 'University', 'Phila', 'Does', 'Dave', 'Sugar']
# ['CHEN', 'XIA', 'Printshop', 'Deluxe', 'Norton', 'Desktop', 'News', 'Nntp']
# ['Jake', 'Livni', 'Israeli', 'Expansion', 'Redundancy', 'Department', 'Lines', 'Jake', 'Livni', 'George', 'Bush', 'American', 'New', 'York', 'Jimmy', 'Carter']
# ['Mohammad', 'Razi', 'Khan', 'Mosques', 'Double', 'Flint', 'MI', 'Lines', 'NNTP', 'Nizam', 'Arain', 'Mark', 'Ira', 'Kaufman', 'Israel', 'Arab', 'Israel', 'Western', 'Islam', 'Islam', 'Muslim', 'XXX', 'Islam', 'Muslim', 'Khan']
# ['UUCP', 'Serdar', 'Argic', 'Reply', 'UUCP', 'Serdar', 'Argic', 'Leonard', 'Ramsden', 'Hartill', 'Bobbs', 'Merrill', 'Company', 'Indianapolis', 'Armenian', 'Muslim', 'Tartars', 'Serdar', 'Argic', 'Turks', 'Ohanus', 'Appressian', 'Soviet', 'Armenia', 'Turkish', 'Sahak', 'Melkonian']
# ['Brian', 'Ceccarelli', 'Tucson', 'AZ', 'Brian', 'Kendig', 'Brian', 'Brian', 'Gain', 'Bible', 'Jesus', 'Bible', 'Jesus', 'Solomon', 'Jesus', 'John', 'John', 'Son', 'Father', 'Brian', 'Paul', 'Paul', 'God', 'Brian', 'Paul', 'Jesus', 'Jesus', 'Peter', 'Jesus', 'Peter', 'Peter', 'Jesus', 'Zeus', 'Zeus', 'Zeus', 'Brian', 'Ceccarelli']
# ['Tzu', 'Andrea', 'Su', 'Article', 'Ohio', 'State', 'University', 'Lines', 'Nntp', 'Sorry', 'Does', 'Computer', 'Shoppers', 'Tze', 'Su']
# ['Vic', 'Kulikauskas', 'Hell', 'SDA', 'Lewis']
# ...
# ['Hrivnak', 'METROPOLITAN', 'TORONTO', 'Georgia', 'Institute', 'Technology', 'Lines', 'Steve', 'Lee', 'Duh', 'Leafs', 'Sheesh', 'SKINS', 'Does', 'Mike', 'Patton', 'Faith', 'No', 'More', 'Mike', 'Friedman', 'Hrivnak']
# ['Jim', 'Haynes', 'Organization', 'California', 'Santa', 'Cruz', 'Lines', 'NNTP', 'Part', 'Meredith', 'Willson', 'Music']
# ['Dave', 'Medin', 'Reply', 'Huntsville', 'AL', 'Lines', 'Mark', 'Zenier', 'Michael', 'D', 'Brendan', 'Jones', 'Magnavox', 'Don', 'Superglue', 'Dave', 'Medin', 'Huntsville']
# ['DC', 'Organization', 'NNTP', 'James', 'Davis', 'Nicoll']
# ['VEAL', 'David', 'Veal', 'CLINTON', 'Clipper', 'Tennessee', 'Division', 'Clinton', 'HQ', 'White', 'House', 'Clipper', 'Rev', 'Access', 'No', 'David', 'Veal', 'Univ', 'Tenn', 'Cont', 'Education', 'Info', 'Group', 'PA146008', 'Weird', 'Al']
# ['Tim', 'Osburn', 'Northwest', 'Nexus', 'Inc', 'NNTP', 'Bellevue', 'Washington']
# ['John', 'Cwikla', 'Pixmaps', 'Nntp', 'Wolfram', 'Research', 'Inc', 'Colormap', 'Pixmap', 'Colormap', 'TIA', 'John', 'John', 'Cwikla', 'Wolfram', 'Research', 'Inc']
# ['Stephan', 'Jaeger', 'Stephan', 'Unox', 'Bastelladen', 'Lines', 'Technical', 'University', 'Karlsruhe', 'Stephan', 'Jaeger', 'Contact', 'Stephan', 'Jaeger', 'Rheinstr', 'D']
# ['PARSIFAL', 'Brad', 'Pierce', 'Richard', 'Wilson', 'Logica', 'Industry', 'Ltd']
# ['Chris', 'Hand', 'Layout', 'Program', 'Organization', 'Leicester', 'UK', 'Lines', 'TIN', 'CSEE', 'PADS', 'PADS', 'PCB', 'Chris', 'Chris', 'Hand', 'Lecturer', 'Gateway', 'Fax', 'UK', 'IBM']
# ['Ehud', 'Oentung', 'GLUE', 'University', 'Maryland', 'College', 'Park', 'Lines', 'NNTP', 'MFM', 'Ehud']
# ['Bill', 'Conner', 'Nntp', 'TIN', 'ICO', 'COM', 'Robert', 'Beauchaine', 'Patrick', 'BAPTISM', 'AT', 'BIRTH']
# ['_Benson', 'NNTP']
# ['George', 'NMSU', 'Andrew', 'Molitor', 'Fearless', 'Leaders', 'Clipper', 'Clipper', 'Clipper']
# ['Steven', 'Bellovin', 'Clipper', 'Dwight', 'Tuinstra', 'General', 'Emergency', 'Associate', 'Assistant']
# ['Nntp', 'Informatics', 'University', 'Oslo', 'Norway', 'Lines', 'NEVER', 'America', 'America', 'Norway', 'Norway', 'Hitler', 'WW2', 'Germany', 'Change', 'Waco', 'Waco', 'BATF', 'Child', 'Thomas', 'Parsli']
# ['Oren', 'Haber', 'Schaim', 'Nntp', 'Alex', 'Mou', 'Soak', 'Don', 'Vaseline', 'USP', 'USP', 'AND', 'Don', 'Oren', 'Haber', 'Schaim']
# ['Texas', 'Instruments', 'Inc', 'Lines', 'DC', 'Martian', 'Landing', 'DC', 'NASA', 'Ames', 'Dryden', 'McCall']
# ['Ted', 'Rypma', 'BubbleJet', 'HP', 'Nntp', 'TIN', 'BJ', 'BJ', 'ZyXEL', 'VGA', 'RS232', 'DeskJet', 'Ted', 'Ontario']
# ['Steve', 'Birnbaum', 'Israelis', 'Reply', 'Steve', 'Birnbaum', 'National', 'Capital', 'Freenet', 'Lines', 'Policy', 'Research', 'Israel', 'Europe', 'Arab', 'Arab', 'Israel', 'Israel', 'Arab', 'Arabs', 'Israel', 'Israel', 'Israel', 'Israeli', 'Arabs', 'Israeli', 'Arabs', 'Arab', 'Israel', 'Israeli', 'Israel', 'Israel', 'Israel', 'Haifa', 'Jewish', 'Sabbath', 'Israel', 'Israel', 'NOT', 'Rabbis', 'Steve']
# ['Daniel', 'Drucker', 'Article', 'NNTP', 'Daniel', 'Drucker']
# ['Martin', 'Lewitt', 'Article', 'Sandia', 'Park', 'NM', 'Lines', 'Vida', 'Morkunas', 'Alas', 'Please', 'Martin', 'Lewitt', 'My', 'Domain', 'COM', 'P']
# ['ICO', 'COM', 'Robert', 'Beauchaine', 'John', 'Johnson', 'Christian', 'Matthew', 'Jesus', 'Nazareth', 'Matthew', 'New', 'Testament', 'Jesus', 'Immanuel', 'Joseph', 'Jesus', 'Ahaz', 'Judah', 'Rezin', 'Syria', 'Pekah', 'Israel', 'Jerusalem', 'Judah', 'David', 'Ahaz', 'Judah', 'Isaiah', 'Ahaz', 'Ahaz', 'Isaiah', 'Sheol', 'Ahaz', 'Isaiah', 'David', 'Immanuel', 'Hebrew', 'Messiah', 'Jesus', 'Matthew', 'Jesus', 'Immanuel', 'Christianity', 'Jesus', 'Egypt', 'Jesus', 'Bethlehem', 'Matthew', 'Egypt', 'Jesus', 'Moses', 'Herod', 'Herod', 'Israel', 'Matthew', 'Hosea', 'Israel', 'Egypt', 'Jesus', 'Matthew', 'Rachel', 'Jesus', 'Egypt', 'Matthew', 'Herod', 'Matthew', 'Jeremiah', 'Ramah', 'Israel', 'Sargon', 'Assyria', 'Rachel', 'Israel', 'Ephraim', 'Manasseh', 'Rachel', 'Hebrews', 'Egyptian', 'Leah', 'Rachel', 'Jesus', 'Bethlehem', 'Rachel', 'Bethlehem', 'Ephrath', 'Bethlehem', 'Herod', 'Bible', 'Herod', 'Herod', 'Jesus', 'Egypt', 'Matthew', 'Jesus', 'Matthew', 'Jeremiah', 'Assyrian', 'Empire', 'Rachel', 'Matthew', 'Nazarene', 'Egypt', 'Joseph', 'Nazareth', 'Nazarene', 'Matthew', 'Nazarenes', 'Old', 'Testament', 'Judges', 'Samson', 'Israel', 'Philistines', 'Jesus', 'Matthew', 'Isaiah', 'Isaiah', 'Christian', 'Isaiah', 'Israel', 'Jehovah', 'Jewish', 'Israel', 'Israel', 'Isaiah', 'Jesus', 'Isaiah', 'Jesus', 'Jesus', 'Israel', 'Matthew', 'Silent', 'Messiah', 'Jesus', 'Gentiles', 'Isaiah', 'Matthew', 'Jesus', 'Jesus', 'Israel', 'Judaic', 'Christologic', 'Gentiles', 'Torah', 'Jehovah', 'Jesus', 'Matthew', 'Jonah', 'Son', 'Saturdays', 'Sundays', 'Jesus', 'Jesus', 'Jesus', 'Jesus', 'Jesus', 'Matthew', 'Jesus', 'Matthew', 'Isaiah', 'Israel', 'Assyria', 'Isaiah', 'Israel', 'Isaiah', 'Israel', 'Solomon', 'David', 'Isaiah', 'Israel', 'Isaiah', 'Matthew', 'Isaiah', 'Jesus', 'Isaiah', 'Matthew', 'Matthew', 'Jesus', 'Matthew', 'Psalms', 'Matthew', 'Isaiah', 'Matthew', 'Old', 'Jesus', 'Jesus', 'Jesus', 'Psalms', 'Matthew', 'Matthew', 'Christians', 'Matthew', 'Little', 'Faith', 'Jesus', 'Mexico', 'Jesus', 'Jehovah', 'Christian', 'Atheist', 'Jesus', 'Rides', 'Jewish', 'Jesus', 'Jerusalem', 'Lo', 'Matthew', 'Jesus', 'Matthew', 'Mark', 'Jesus', 'Zechariah', 'Matthew', 'Christ', 'Jerusalem', 'Jesus', 'Matthew', 'Matthew', 'Jesus', 'AND', 'Matthew', 'Jesus', 'Matthew', 'Matthew', 'YHVH', 'David', 'LORD', 'Jesus', 'Davidic', 'Christian', 'Christian', 'Jesus', 'David', 'David', 'Jesus', 'Jesus', 'YHVH', 'YHVH', 'Zion', 'Rule', 'Melchizedek', 'Christian', 'Hebrew', 'Adoni', 'David', 'David', 'David', 'David', 'David', 'David', 'David', 'David', 'David', 'David', 'David', 'David', 'Matthew', 'Matthew', 'Mark', 'Jesus', 'Matthew', 'Pharisees', 'Jesus', 'Matthew', 'Pharisees', 'Moses', 'Jesus', 'Matthew', 'John', 'John', 'Jesus', 'Abraham', 'Moses', 'David', 'Abraham', 'Jesus', 'Abraham', 'Abraham', 'Jesus', 'Christian', 'Old', 'John', 'Potter', 'Jesus', 'Jerusalem', 'Judas', 'Iscariot', 'Matthew', 'Jeremiah', 'Israel', 'Old', 'Matthew', 'Matthew', 'YHVH', 'YHVH', 'Judah', 'Israel', 'Matthew', 'Hebrew', 'Zechariah', 'Matthew', 'Matthew', 'Matthew', 'Zechariah', 'Judas', 'Zechariah', 'Night', 'Bible', 'Matthew', 'New', 'Testament', 'Matthew', 'Wine', 'Vinegar', 'Jesus', 'Jesus', 'Roman', 'Jesus', 'Jesus', 'Matthew', 'Psalms', 'Jesus', 'David', 'Jesus', 'Jesus', 'Jesus', 'Matthew', 'Jesus', 'Jesus', 'Jesus', 'Jesus', 'David', 'YHVH', 'Jesus', 'Jesus', 'Jesus', 'David', 'Jesus', 'Jesus', 'Jesus', 'YHVH', 'Jesus', 'Holy', 'YHVH', 'Christian', 'Hebrew', 'Hebrew', 'Christian', 'Christian', 'Jesus', 'Jesus', 'David', 'Matthew', 'Jesus', 'Christian', 'New', 'Testament', 'Jesus', 'John', 'Jesus', 'Scripture', 'Prophet', 'Zechariah', 'Israel', 'Jerusalem', 'Judah', 'YHVH', 'Judah', 'Jerusalem', 'Judah', 'John', 'Matthew', 'Matthew', 'John', 'Jesus', 'Jesus', 'Mark', 'Jesus', 'Israel', 'Jesus', 'Jesus', 'Isaiah', 'Jesus', 'Mark', 'Mark', 'Luke', 'Mark', 'Jesus', 'Luke', 'Jesus', 'Luke', 'Luke', 'Mark', 'Luke', 'Jesus', 'New', 'Testament', 'Jesus', 'Jesus', 'Daniel', 'Judea', 'S ...
# ['Dan', 'Hartung', 'WACO', 'QUIZ', 'Impress', 'Win', 'Organization', 'Chinet', 'Public', 'Access', 'UNIX', 'Lines', 'Waco', 'Quiz', 'BATF', 'Think', 'Heck', 'Hope', 'MORE', 'FBI', 'FBI', 'UC', 'FBI', 'Flimsy', 'Count', 'Feel', 'Koresh', 'Pace', 'Daniel', 'Hartung', 'Rotaract']
# ['DOS6', 'EMM386', 'Nntp', 'Centre', 'Stephen', 'Mark', 'Sanderson', 'Stephen', 'Mark', 'Sanderson', 'DOS6', 'EMM386', 'DOS', 'BOOT', 'QEMM', 'BOOT', 'Sorry', 'Phillip']
# ['David', 'Peterschmidt', 'COM4', 'Lines', 'Nntp', 'Reply', 'Inc', 'Mike', 'Uchima', 'COM4', 'ATI', 'Ultrapro', 'COM4', 'COM1', 'COM3', 'COM3', 'COM4', 'MSD', 'IRQ', 'IRQs', 'COM3', 'COM4', 'COM3', 'COM4', 'BOCA', 'BOCA', 'COM1', 'COM2', 'COM3', 'COM4', 'Gateway', 'COM4', 'RAM', 'ATI', 'Graphics', 'Ultra', 'COM4', 'COM1', 'Dave', 'Peterschmidt']
# ['Brian', 'Keith', 'Michalk', 'University', 'Texas', 'Austin', 'Lines', 'NNTP', 'David', 'Lubbock', 'Texas', 'Dallas', 'Houston', 'Dallas', 'Houston', 'Lubbock']
# ['Fact', 'Fiction', 'Lines', 'Nntp', 'OSU', 'College', 'Osteopathic', 'Medicine', 'David', 'Rind', 'Annals', 'Internal', 'Medicine', 'David', 'Rind', 'David', 'Gordon', 'Rubenfeld', 'Medline', 'Lactobacillus', 'Gordon', 'Lactobacillus', 'Lactobacillus', 'EDTA', 'Marty']
# ['Steve', 'Bunis', 'Chicago', 'Organization', 'Inc', 'Reply', 'NNTP', 'Rider', 'Rally', 'Knoxville', 'Chicago', 'Indiana', 'Kentucky', 'Knoxville', 'Knoxville', 'Rally', 'Blue', 'Ridge', 'Parkway', 'West', 'Va', 'Marlington', 'Petersburg', 'Pennsylvania', 'New', 'York', 'Chicago', 'Enjoy', 'Sun', 'Microsystems', 'ST1100', 'Itasca', 'IL', 'KZ650', 'ARE', 'APRIL']
# ['Ryan', 'Cousineau', 'Reply', 'Ryan', 'Cousineau', 'Vancouver', 'B', 'Niels', 'Mikkel', 'Michelsen', 'NMM', 'NMM', 'BMW', 'NMM', 'NMM', 'NMM', 'NMM', 'NMM', 'BDI', 'HST', 'V32', 'BC', 'Canada', 'Easy', 'Access', 'Low', 'Rates', 'Friendly', 'Sysop']
# ['Ron', 'Baalke', 'Pluto', 'Mission', 'Organization', 'NNTP', 'News', 'Earth', 'Cassini', 'Saturn', 'Pluto', 'Fast', 'Pluto', 'Flyby', 'Orbit', 'Pluto', 'Pluto', '___', '_____', 'Telos', 'New', 'Zealand']
# ['Wun', 'Chun', 'Chau', 'Nntp', 'MFM', 'FD']
# ['Nicholas', 'Nntp', 'SyQuest', 'LARD']
# ['Jonathan', 'Bruce', 'Hacker', 'Article', 'California', 'Institute', 'Technology', 'Pasadena', 'Lines', 'NNTP', 'Devil', 'Reincarnate', 'LESS', 'DRL', 'DRL', 'ROM', 'Caltech', 'Pasadena', 'CA', 'IBM', 'OS2']
# ['Organization', 'Notre', 'Dame', 'Univ', 'RVESTERM', 'CAMDEN', 'Mark', 'Balboni']
# ['Mark', 'Baker', 'Reply', 'Mark', 'Baker', 'National', 'Capital', 'Freenet', 'Lines', 'Michael', 'Covington', 'Terrance', 'Heath', 'God', 'Mark', 'Baker', 'Lewis', 'Jerusalem']
# ['Andrew', 'Kriger', 'Organization', 'Amherst', 'MA', 'Lines', 'NNTP', 'Clipper', 'Chip', 'Andrew', 'Hampshire', 'College', 'Benjamin', 'Franklin']
# ['AtlantaGA', 'COM', 'Mark', 'Wilson', 'NCR', 'Engineering', 'GA', 'Distribution', 'COM', 'Steven', 'Clinton', 'Reagan', 'Which', 'Wilson', 'Mark', 'Wilson']
# ['Reply', 'Sniper', 'Lines', 'AJv', 'Jon', 'Meyer', 'COM', 'Peter', 'Hampe', 'Clinton', 'Illegal', 'Somalia', 'Everybody', 'ReaganBushLegacy', 'Yep', 'Been', 'Reagan', 'Somalia', 'Reagan', 'Band', 'Aid', 'How', 'Much', 'Which', 'Soviet', 'Gonzo', 'Station', 'WHICH', 'COMedy', 'COMedy', 'Wild']
# ['Steve', 'Lamont', 'Organization', 'Calif', 'NNTP', 'CWRU', 'Morton', 'Steve', 'Lamont', 'Comsymp', 'Los', 'Alamos', 'SAD', 'WIT', 'Steve', 'Lamont', 'SciViGuy', 'San', 'Diego', 'Microscopy', 'Bumper']
# ['Caleb', 'Guess', 'TIN', 'Pens', 'ESPN', 'TV']
# ['Peter', 'Trei', 'Passwords', 'Nntp', 'MITRE', 'Corporation', 'Kenneth', 'Ng', 'Peter', 'Trei', 'Peanuts', 'LAPD', 'LAPD', 'California', 'Oliver', 'North', 'Ollie', 'US', 'Senate', 'Senate', 'Peter', 'Trei']
# ['University', 'British', 'Columbia', 'Lines', 'NNTP', 'Ville', 'V', 'Walveranta', 'WinJet', 'Eden', 'Prairie', 'MN', 'WinJet', 'LaserJet', 'WinJet', 'US', 'Canada']
# ['ColoState', 'Basil', 'Hamdan', 'Hezbollah', 'Reply', 'Nntp', 'Colorado', 'State', 'University', 'Lines', 'Shai', 'Israeli', 'South', 'Lebanon', 'Hizollah', 'South', 'Lebanon', 'Israel', 'Hizbollah', 'Amal', 'Hizbollah', 'Hizbollah', 'Israel', 'Israel', 'North', 'Lebanon', 'SLA', 'SLA', 'Israeli', 'Israel', 'Lebanese', 'Israeli', 'Israel', 'Lebanese', 'Syrian', 'Northern', 'Israel', 'Syrian', 'Lebanese', 'Hizbollah', 'Israel', 'Lebanese', 'Lebanon', 'Syrian', 'Israel', 'Hmm', 'Syria', 'Syria', 'Lebanon', 'Northern', 'Israel', 'Israeli', 'Syria', 'Israel', 'Lebanon', 'Syria', 'Lebanese', 'Isareli', 'CANNOT', 'Shai', 'MA']
# ['Chris', 'Wooff', 'OLE', 'SPSS', 'Nntp', 'University', 'Liverpool', 'TIN', 'SPSS', 'SPSS', 'REQ', 'DAT', 'SPSS', 'OLE', 'Chris', 'Wooff']
# ['David', 'Young', 'MIT', 'Media', 'Laboratory', 'Lines', 'XCreateColormap', 'dialogShell', 'XmNdialogStyle', 'applicationShell', 'dialogShell']
# ['Matthew', 'Dorsai', 'Grey', 'Captains', 'Lines', 'NNTP', 'Richard', 'Boeing', 'Technology', 'Atlanta', 'Georgia']
# ['Clinton', 'ACME', 'Products', 'Lines', 'Francis', 'Akoto', 'Clintons', 'Anglo', 'Irish', 'Italian', 'Brett', 'Sean', '_The', 'White', 'Plague_', 'Frank', 'Herbert']
# ['Charley', 'Wingate', 'Hence', 'Yep', 'Jesus', 'THOSE', 'Anyone', 'God']
# ['Original', 'Sin', 'Organization', 'Western', 'Kentucky', 'University', 'Bowling', 'Green', 'KY', 'Lines', 'Christ', 'Spirit', 'Mike']
# ['ROGOSCHP', 'Uregina', 'Regina', 'Lines', 'Mac', 'LC', 'III', 'Mac', 'LC']
# ['Cyclone', 'NEEDED', 'Nntp', 'Ohio', 'State', 'University', 'Lines', 'Connie', 'Cyclone', 'Tempest', 'Anything', 'Shawn', 'MacWeek']
# ['Ted', 'Frank', 'Reply', 'Chicago', 'Lines', 'David', 'Smith', 'Granted']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-97afda94f2c6> in <module>()
#      16     doc = [nltk.pos_tag(sent) for sent in doc]
#      17     for s in doc:
# ---> 18         chunx = ne_chunk(s, binary=True)
#      19         for chunk in chunx:
#      20             if hasattr(chunk, 'label'):
#
# ~/.venvs/isaac/lib/python3.6/site-packages/nltk/chunk/__init__.py in ne_chunk(tagged_tokens, binary)
#     175         chunker_pickle = _MULTICLASS_NE_CHUNKER
#     176     chunker = load(chunker_pickle)
# --> 177     return chunker.parse(tagged_tokens)
#     178
#     179 def ne_chunk_sents(tagged_sentences, binary=False):
#
# ~/.venvs/isaac/lib/python3.6/site-packages/nltk/chunk/named_entity.py in parse(self, tokens)
#     121         Each token should be a pos-tagged word
#     122         """
# --> 123         tagged = self._tagger.tag(tokens)
#     124         tree = self._tagged_to_parse(tagged)
#     125         return tree
#
# ~/.venvs/isaac/lib/python3.6/site-packages/nltk/tag/sequential.py in tag(self, tokens)
#      61         tags = []
#      62         for i in range(len(tokens)):
# ---> 63             tags.append(self.tag_one(tokens, i, tags))
#      64         return list(zip(tokens, tags))
#      65
#
# ~/.venvs/isaac/lib/python3.6/site-packages/nltk/tag/sequential.py in tag_one(self, tokens, index, history)
#      81         tag = None
#      82         for tagger in self._taggers:
# ---> 83             tag = tagger.choose_tag(tokens, index, history)
#      84             if tag is not None:
#      85                 break
#
# ~/.venvs/isaac/lib/python3.6/site-packages/nltk/tag/sequential.py in choose_tag(self, tokens, index, history)
#     636         # higher than that cutoff first; otherwise, return None.
#     637         if self._cutoff_prob is None:
# --> 638             return self._classifier.classify(featureset)
#     639
#     640         pdist = self._classifier.prob_classify(featureset)
#
# ~/.venvs/isaac/lib/python3.6/site-packages/nltk/classify/maxent.py in classify(self, featureset)
#     145
#     146     def classify(self, featureset):
# --> 147         return self.prob_classify(featureset).max()
#     148
#     149     def prob_classify(self, featureset):
#
# ~/.venvs/isaac/lib/python3.6/site-packages/nltk/classify/maxent.py in prob_classify(self, featureset)
#     166         # Normalize the dictionary to give a probability distribution
#     167         return DictionaryProbDist(prob_dict, log=self._logarithmic,
# --> 168                                   normalize=True)
#     169
#     170     def explain(self, featureset, columns=4):
#
# ~/.venvs/isaac/lib/python3.6/site-packages/nltk/probability.py in __init__(self, prob_dict, log, normalize)
#     647                              'before it can be normalized.')
#     648             if log:
# --> 649                 value_sum = sum_logs(list(self._prob_dict.values()))
#     650                 if value_sum <= _NINF:
#     651                     logp = math.log(1.0/len(prob_dict), 2)
#
# ~/.venvs/isaac/lib/python3.6/site-packages/nltk/probability.py in sum_logs(logs)
#    2164
#    2165 def sum_logs(logs):
# -> 2166     return (reduce(add_logs, logs[1:], logs[0]) if len(logs) != 0 else _NINF)
#    2167
#    2168 ##//////////////////////////////////////////////////////
#
# KeyboardInterrupt:

# %% [markdown]
# ## Summary
# - We loaded the 1993 Newsgroups dataset and split it into train/test sets
# - We preprocessed the raw text using various Vectorisers arranged in Pipelines
# - We used Multinomial Naive Bayes to classify the articles
# - We used 5-fold cross validation to check our performance
# - We made some optimisations and tested on a held-out test set
# - We (optionally) played with named entity recognition to see if that would help
