# %%
# %pylab inline
# %matplotlib inline

print(__doc__)

import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_olivetti_faces
from sklearn.utils.validation import check_random_state

from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor

import keras

# Load the faces datasets
data = fetch_olivetti_faces()
targets = data.target

n_faces = 20
choices = np.random.choice(targets, size=n_faces)
data = data.images.reshape((len(data.images), -1))

print(data.shape)
print(data[0])


# train = data[targets < 30]
# test = data[targets >= 30]  # Test on independent people

train = data[~choices]
test = data[choices]  # Test on independent people
print(choices)

# Test on a subset of people
# rng = check_random_state(666)
# face_ids = rng.randint(test.shape[0], size=(n_faces, ))
# test = test[face_ids, :]

print(data.shape)
n_pixels = data.shape[1]
# Upper half of the faces
X_train = train[:, :(n_pixels + 1) // 2]
X_test = test[:, :(n_pixels + 1) // 2]
# Lower half of the faces
y_train = train[:, n_pixels // 2:]
y_test = test[:, n_pixels // 2:]


keras_nn = keras.Sequential([
    keras.layers.Dense(100, input_shape=(2048,), activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(2048, activation="linear") # linear output for regression
])

keras_nn.compile(optimizer='adam',
                  loss='mse', # use mean-squared error for regressin problems
                )

keras_nn.fit(X_train, y_train, epochs=100)

# Fit estimators
ESTIMATORS = {
#     "Extra trees": ExtraTreesRegressor(n_estimators=10, max_features=32,
#                                        random_state=0),
    "Random Forest": RandomForestRegressor(),
    "KN'bours": KNeighborsRegressor(),
    "Linear regression": LinearRegression(),
    "Ridge": RidgeCV(),
    "SklearnNN": MLPRegressor(learning_rate="adaptive", hidden_layer_sizes=(100,100), activation="relu"),
    "KerasNN": keras_nn
#     "SVR": SVR()
}

y_test_predict = dict()
for name, estimator in ESTIMATORS.items():
    if name != "KerasNN":
        estimator.fit(X_train, y_train)
    y_test_predict[name] = estimator.predict(X_test)

# Plot the completed faces
image_shape = (64, 64)

n_cols = 1 + len(ESTIMATORS)
plt.figure(figsize=(2. * n_cols, 2.26 * n_faces))
plt.suptitle("Face completion with multi-output estimators", size=16)

for i in range(n_faces):
    true_face = np.hstack((X_test[i], y_test[i]))

    if i:
        sub = plt.subplot(n_faces, n_cols, i * n_cols + 1)
    else:
        sub = plt.subplot(n_faces, n_cols, i * n_cols + 1,
                          title="true faces")

    sub.axis("off")
    sub.imshow(true_face.reshape(image_shape),
               cmap=plt.cm.gray,
               interpolation="nearest")

    for j, est in enumerate(ESTIMATORS):
        completed_face = np.hstack((X_test[i], y_test_predict[est][i]))

        if i:
            sub = plt.subplot(n_faces, n_cols, i * n_cols + 2 + j)

        else:
            sub = plt.subplot(n_faces, n_cols, i * n_cols + 2 + j,
                              title=est)

        sub.axis("off")
        sub.imshow(completed_face.reshape(image_shape),
                   cmap=plt.cm.gray,
                   interpolation="nearest")

plt.show()

# %%
# %pylab inline
# %matplotlib inline

print(__doc__)

import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_olivetti_faces
from sklearn.utils.validation import check_random_state

from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor

import keras
from keras.wrappers.scikit_learn import KerasRegressor
from keras.callbacks import EarlyStopping

# Load the faces datasets
data = fetch_olivetti_faces()
targets = data.target

n_faces = 20
choices = np.random.choice(targets, size=n_faces)
data = data.images.reshape((len(data.images), -1))

print(data.shape)
print(data[0])

train = data[~choices]
test = data[choices]  # Test on independent people
print(choices)

print(data.shape)
n_pixels = data.shape[1]
# Upper half of the faces
X_train = train[:, :(n_pixels + 1) // 2]
X_test = test[:, :(n_pixels + 1) // 2]
# Lower half of the faces
y_train = train[:, n_pixels // 2:]
y_test = test[:, n_pixels // 2:]


es = EarlyStopping(monitor="loss", patience=5, restore_best_weights=True)
keras_nn2x100 = keras.Sequential([
    keras.layers.Dense(100, input_shape=(2048,), activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(2048, activation="linear") # linear output for regression
])
keras_nn2x100.compile(optimizer='adam',
                  loss='mse', # use mean-squared error for regression problems
                )
keras_nn2x100.fit(X_train, y_train, epochs=1000, verbose=2, callbacks=[es])

keras_nn3x100 = keras.Sequential([
    keras.layers.Dense(100, input_shape=(2048,), activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(2048, activation="linear") # linear output for regression
])
keras_nn3x100.compile(optimizer='adam',
                  loss='mse', # use mean-squared error for regression problems
                )
keras_nn3x100.fit(X_train, y_train, epochs=1000, verbose=0, callbacks=[es])

keras_nn2x1000 = keras.Sequential([
    keras.layers.Dense(1000, input_shape=(2048,), activation="relu"),
    keras.layers.Dense(1000, activation="relu"),
    keras.layers.Dense(2048, activation="linear") # linear output for regression
])

keras_nn2x1000.compile(optimizer='adam',
                  loss='mse', # use mean-squared error for regression problems
                )
keras_nn2x1000.fit(X_train, y_train, epochs=1000, verbose=0, callbacks=[es])


# Fit estimators
ESTIMATORS = {
    "S 2x100": MLPRegressor(learning_rate="adaptive", hidden_layer_sizes=(100,100), activation="relu"),
    "K 2x100": keras_nn2x100,
    "S 3x100": MLPRegressor(learning_rate="adaptive", hidden_layer_sizes=(100,100,100), activation="relu"),
    "K 3x100": keras_nn3x100,
    "S 2x1000": MLPRegressor(learning_rate="adaptive", hidden_layer_sizes=(1000,1000), activation="relu"),
    "K 2x1000": keras_nn2x1000
}

y_test_predict = dict()
for name, estimator in ESTIMATORS.items():
    if name[0] != "K":
        estimator.fit(X_train, y_train)
    y_test_predict[name] = estimator.predict(X_test)

# Plot the completed faces
image_shape = (64, 64)

n_cols = 1 + len(ESTIMATORS)
plt.figure(figsize=(2. * n_cols, 2.26 * n_faces))
plt.suptitle("Face completion with multi-output estimators", size=16)

for i in range(n_faces):
    true_face = np.hstack((X_test[i], y_test[i]))

    if i:
        sub = plt.subplot(n_faces, n_cols, i * n_cols + 1)
    else:
        sub = plt.subplot(n_faces, n_cols, i * n_cols + 1,
                          title="true faces")

    sub.axis("off")
    sub.imshow(true_face.reshape(image_shape),
               cmap=plt.cm.gray,
               interpolation="nearest")

    for j, est in enumerate(ESTIMATORS):
        completed_face = np.hstack((X_test[i], y_test_predict[est][i]))

        if i:
            sub = plt.subplot(n_faces, n_cols, i * n_cols + 2 + j)

        else:
            sub = plt.subplot(n_faces, n_cols, i * n_cols + 2 + j,
                              title=est)

        sub.axis("off")
        sub.imshow(completed_face.reshape(image_shape),
                   cmap=plt.cm.gray,
                   interpolation="nearest")

plt.show()
